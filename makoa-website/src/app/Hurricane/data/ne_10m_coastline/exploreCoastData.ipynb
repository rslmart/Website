# %%
# Import necessary modules
import geopandas as gpd

# %%
# Set filepath
fp = "./ne_10m_coastline.shp"
# Read file using gpd.read_file()
data = gpd.read_file(fp)
type(data)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
print(data.head(10))
# Out:
#   featurecla  scalerank  min_zoom  \
# 0  Coastline          0       0.0
# 1  Coastline          0       0.0
# 2  Coastline          6       5.0
# 3  Coastline          0       0.0
# 4  Coastline          0       0.0
# 5  Coastline          6       5.0
# 6  Coastline          5       3.0
# 7  Coastline          5       3.0
# 8  Coastline          6       6.0
# 9  Coastline          6       5.0
#
#                                             geometry
# 0  LINESTRING (59.91603 -67.40049, 59.67856 -67.3...
# 1  LINESTRING (-51.73062 -82.06260, -52.18688 -82...
# 2  LINESTRING (166.13697 -50.86435, 166.10711 -50...
# 3  LINESTRING (-56.66832 -36.73642, -56.66487 -36...
# 4  LINESTRING (-51.07939 3.49209, -51.09648 3.449...
# 5  LINESTRING (-80.75935 -33.76678, -80.74889 -33...
# 6  LINESTRING (-78.78897 -33.60906, -78.80675 -33...
# 7  LINESTRING (-109.23160 -27.09246, -109.24185 -...
# 8  LINESTRING (163.98512 -20.04762, 163.97511 -20...
# ...

# %%
data.plot()
# Out:
# <AxesSubplot: >

# %%
michealTrackPoints = [{"id": "AL172000MICHAEL", "year": 2000, "month": 10, "day": 15, "hours": 12, "minutes": 0, "date_time": "2000-10-15 12:00:00", "record_type": "", "status": "SD", "latitude": 30.0, "longitude": -71.2, "wind": 30, "pressure": 1007, "ACE": 0.09}, {"id": "AL172000MICHAEL", "year": 2000, "month": 10, "day": 15, "hours": 18, "minutes": 0, "date_time": "2000-10-15 18:00:00", "record_type": "", "status": "SD", "latitude": 30.0, "longitude": -71.5, "wind": 30, "pressure": 1006, "ACE": 0.18}, {"id": "AL172000MICHAEL", "year": 2000, "month": 10, "day": 16, "hours": 0, "minutes": 0, "date_time": "2000-10-16 00:00:00", "record_type": "", "status": "SS", "latitude": 29.9, "longitude": -71.8, "wind": 35, "pressure": 1005, "ACE": 0.3025}, {"id": "AL172000MICHAEL", "year": 2000, "month": 10, "day": 16, "hours": 6, "minutes": 0, "date_time": "2000-10-16 06:00:00", "record_type": "", "status": "SS", "latitude": 29.9, "longitude": -71.9, "wind": 35, "pressure": 1005, "ACE": 0.425}, {"id": "AL172000MICHAEL", "year": 2000, "month": 10, "day": 16, "hours": 12, "minutes": 0, "date_time": "2000-10-16 12:00:00", "record_type": "", "status": "SS", "latitude": 29.7, "longitude": -71.7, "wind": 35, "pressure": 1005, "ACE": 0.5475}, {"id": "AL172000MICHAEL", "year": 2000, "month": 10, "day": 16, "hours": 18, "minutes": 0, "date_time": "2000-10-16 18:00:00", "record_type": "", "status": "SS", "latitude": 29.8, "longitude": -71.4, "wind": 35, "pressure": 1004, "ACE": 0.67}, {"id": "AL172000MICHAEL", "year": 2000, "month": 10, "day": 17, "hours": 0, "minutes": 0, "date_time": "2000-10-17 00:00:00", "record_type": "", "status": "TS", "latitude": 29.9, "longitude": -71.1, "wind": 35, "pressure": 1003, "ACE": 0.7925}, {"id": "AL172000MICHAEL", "year": 2000, "month": 10, "day": 17, "hours": 6, "minutes": 0, "date_time": "2000-10-17 06:00:00", "record_type": "", "status": "TS", "latitude": 29.8, "longitude": -71.0, "wind": 45, "pressure": 1000, "ACE": 0.995}, {"id": "AL172000MICHAEL", "year": 2000, "month": 10, "day": 17, "hours": 12, "minutes": 0, "date_time": "2000-10-17 12:00:00", "record_type": "", "status": "TS", "latitude": 29.8, "longitude": -70.9, "wind": 55, "pressure": 995, "ACE": 1.2975}, {"id": "AL172000MICHAEL", "year": 2000, "month": 10, "day": 17, "hours": 18, "minutes": 0, "date_time": "2000-10-17 18:00:00", "record_type": "", "status": "HU", "latitude": 30.1, "longitude": -70.9, "wind": 65, "pressure": 988, "ACE": 1.72}, {"id": "AL172000MICHAEL", "year": 2000, "month": 10, "day": 18, "hours": 0, "minutes": 0, "date_time": "2000-10-18 00:00:00", "record_type": "", "status": "HU", "latitude": 30.4, "longitude": -70.9, "wind": 65, "pressure": 988, "ACE": 2.1425}, {"id": "AL172000MICHAEL", "year": 2000, "month": 10, "day": 18, "hours": 6, "minutes": 0, "date_time": "2000-10-18 06:00:00", "record_type": "", "status": "HU", "latitude": 30.8, "longitude": -70.8, "wind": 65, "pressure": 986, "ACE": 2.565}, {"id": "AL172000MICHAEL", "year": 2000, "month": 10, "day": 18, "hours": 12, "minutes": 0, "date_time": "2000-10-18 12:00:00", "record_type": "", "status": "HU", "latitude": 31.5, "longitude": -70.4, "wind": 65, "pressure": 984, "ACE": 2.9875}, {"id": "AL172000MICHAEL", "year": 2000, "month": 10, "day": 18, "hours": 18, "minutes": 0, "date_time": "2000-10-18 18:00:00", "record_type": "", "status": "HU", "latitude": 32.6, "longitude": -69.5, "wind": 70, "pressure": 979, "ACE": 3.4775}, {"id": "AL172000MICHAEL", "year": 2000, "month": 10, "day": 19, "hours": 0, "minutes": 0, "date_time": "2000-10-19 00:00:00", "record_type": "", "status": "HU", "latitude": 34.2, "longitude": -67.8, "wind": 75, "pressure": 983, "ACE": 4.04}, {"id": "AL172000MICHAEL", "year": 2000, "month": 10, "day": 19, "hours": 6, "minutes": 0, "date_time": "2000-10-19 06:00:00", "record_type": "", "status": "HU", "latitude": 36.3, "longitude": -65.5, "wind": 65, "pressure": 986, "ACE": 4.4625}, {"id": "AL172000MICHAEL", "year": 2000, "month": 10, "day": 19, "hours": 12, "minutes": 0, "date_time": "2000-10-19 12:00:00", "record_type": "", "status": "HU", "latitude": 39.8, "longitude": -61.6, "wind": 75, "pressure": 979, "ACE": 5.025}, {"id": "AL172000MICHAEL", "year": 2000, "month": 10, "day": 19, "hours": 18, "minutes": 0, "date_time": "2000-10-19 18:00:00", "record_type": "", "status": "HU", "latitude": 44.0, "longitude": -58.5, "wind": 85, "pressure": 965, "ACE": 5.7475}, {"id": "AL172000MICHAEL", "year": 2000, "month": 10, "day": 20, "hours": 0, "minutes": 0, "date_time": "2000-10-20 00:00:00", "record_type": "", "status": "EX", "latitude": 48.0, "longitude": -56.5, "wind": 75, "pressure": 966, "ACE": 6.31}, {"id": "AL172000MICHAEL", "year": 2000, "month": 10, "day": 20, "hours": 6, "minutes": 0, "date_time": "2000-10-20 06:00:00", "record_type": "", "status": "EX", "latitude": 50.0, "longitude": -56.0, "wind": 70, "pressure": 966, "ACE": 6.8}, {"id": "AL172000MICHAEL", "year": 2000, "month": 10, "day": 20, "hours": 12, "minutes": 0, "date_time": "2000-10-20 12:00:00", "record_type": "", "status": "EX", "latitude": 51.0, "longitude": -53.5, "wind": 65, "pressure": 968, "ACE": 7.2225}, {"id": "AL172000MICHAEL", "year": 2000, "month": 10, "day": 20, "hours": 18, "minutes": 0, "date_time": "2000-10-20 18:00:00", "record_type": "", "status": "EX", "latitude": 52.0, "longitude": -50.5, "wind": 60, "pressure": 970, "ACE": 7.5825}]
