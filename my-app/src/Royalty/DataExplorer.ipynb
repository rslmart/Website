# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import json
import utils
import importlib

# %%
with open('royaltree.json', 'r') as file:
    data = json.load(file)
data
# Out:
# {'/wiki/Charlemagne': {'id': '/wiki/Charlemagne',
#   'name': 'Charlemagne',
#   'title': '/wiki/Holy_Roman_Emperor',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/f/fb/Charlemagne_denier_Mayence_812_814.jpg/225px-Charlemagne_denier_Mayence_812_814.jpg',
#   'birthDate': '0747-04-02T00:00:00',
#   'birthPlace': '/wiki/Li%C3%A8ge',
#   'deathDate': '0814-01-28T00:00:00',
#   'deathPlace': '/wiki/Francia',
#   'spouseList': ['/wiki/Desiderata_of_the_Lombards',
#    '/wiki/Hildegard_of_the_Vinzgau',
#    '/wiki/Fastrada',
#    '/wiki/Luitgard_(Frankish_queen)'],
#   'issueList': ['/wiki/Pepin_the_Hunchback',
#    '/wiki/Charles_the_Younger',
#    '/wiki/Pepin_of_Italy',
#    '/wiki/Louis_the_Pious'],
#   'dynasty': '/wiki/Carolingian_dynasty',
#   'father': '/wiki/Pepin_the_Short',
#   'mother': '/wiki/Bertrada_of_Laon',
#   'religion': '/wiki/Chalcedonian_Christianity'},
#  '/wiki/Charles_the_Younger': {'id': '/wiki/Charles_the_Younger',
#   'name': 'Charles the Younger',
#   'title': '/wiki/King_of_the_Franks',
#   'picture': None,
#   'birthDate': '0772-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0811-12-04T00:00:00',
#   'deathPlace': None,
#   'dynasty': '/wiki/Carolingian',
#   'father': '/wiki/Charlemagne',
#   'mother': '/wiki/Hildegard_of_the_Vinzgau'},
#  '/wiki/Pepin_the_Short': {'id': '/wiki/Pepin_the_Short',
#   'name': 'Pepin the Short',
#   'title': '/wiki/King_of_the_Franks',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/6/64/PippinImperialChronicleCorpusChristiCollegeMS373Fol14.jpg/220px-PippinImperialChronicleCorpusChristiCollegeMS373Fol14.jpg',
#   'birthDate': '0714-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0768-09-24T00:00:00',
#   'deathPlace': '/wiki/Saint-Denis,_Seine-Saint-Denis',
#   'spouseList': ['/wiki/Bertrada_of_Laon'],
#   'issueList': [],
#   'dynasty': '/wiki/Carolingian',
#   'father': '/wiki/Charles_Martel',
#   'mother': '/wiki/Rotrude_of_Hesbaye',
#   'religion': '/wiki/Chalcedonian_Christianity'},
#  '/wiki/Bertrada_of_Laon': {'id': '/wiki/Bertrada_of_Laon',
#   'name': 'Bertrada of Laon',
#   'title': 'Queen consort of the Franks',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/a/a6/Bertrada_of_Laon_Jardin_du_Luxembourg.jpg/220px-Bertrada_of_Laon_Jardin_du_Luxembourg.jpg',
#   'birthDate': '0710-01-01T00:00:00',
#   'birthPlace': '/wiki/Laon',
#   'deathDate': '0783-01-01T00:00:00',
#   'deathPlace': '/wiki/Choisy-au-Bac',
#   'spouseList': ['/wiki/Pepin_the_Short'],
#   'issueList': ['/wiki/Charlemagne',
#    '/wiki/Carloman_I',
#    '/wiki/Gisela,_Abbess_of_Chelles'],
#   'father': '/wiki/Charibert_of_Laon',
#   'religion': '/wiki/Roman_Catholicism'},
#  '/wiki/Hildegard_of_the_Vinzgau': {'id': '/wiki/Hildegard_of_the_Vinzgau',
#   'name': 'Hildegard of the Vinzgau',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/b/b9/Hildegard_1499.jpg/220px-Hildegard_1499.jpg',
#   'birthDate': '0754-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0783-01-01T00:00:00',
#   'deathPlace': '/wiki/Thionville',
#   'spouseList': ['/wiki/Charlemagne'],
#   'issueList': [],
#   'dynasty': 'Udalriching',
#   'father': '/wiki/Gerold_of_Vinzgau',
#   'mother': 'Emma of Alemannia'},
#  '/wiki/Gisela,_Abbess_of_Chelles': {'id': '/wiki/Gisela,_Abbess_of_Chelles',
#   'name': 'Gisela, Abbess of Chelles'},
#  '/wiki/Pepin_of_Italy': {'id': '/wiki/Pepin_of_Italy',
#   'name': 'Pepin of Italy',
#   'title': '/wiki/King_of_Italy',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/8/87/P%C3%A9pin_d%27Italie.jpg/220px-P%C3%A9pin_d%27Italie.jpg',
#   'birthDate': '0777-01-01T00:00:00',
#   'birthPlace': '/wiki/Milan',
#   'deathDate': '0810-07-08T00:00:00',
#   'deathPlace': None,
#   'issueList': ['/wiki/Bernard_of_Italy'],
#   'father': '/wiki/Charlemagne',
#   'mother': '/wiki/Hildegard_of_the_Vinzgau'},
#  '/wiki/Pepin_the_Hunchback': {'id': '/wiki/Pepin_the_Hunchback',
#   'name': 'Pepin the Hunchback',
#   'picture': None,
#   'birthDate': '0768-01-01T00:00:00',
#   'birthPlace': '/wiki/Francia',
#   'deathDate': '0811-01-01T00:00:00',
#   'deathPlace': '/wiki/Pr%C3%BCm',
#   'dynasty': '/wiki/Carolingian_dynasty',
#   'father': '/wiki/Charlemagne',
#   'mother': '/wiki/Himiltrude'},
#  '/wiki/Luitgard_(Frankish_queen)': {'id': '/wiki/Luitgard_(Frankish_queen)',
#   'name': 'Luitgard (Frankish queen)',
#   'title': '/wiki/List_of_Frankish_queens',
#   'picture': None,
#   'deathDate': '0800-06-04T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/Charlemagne']},
#  '/wiki/Rotrude_of_Hesbaye': {'id': '/wiki/Rotrude_of_Hesbaye',
#   'name': 'Rotrude of Hesbaye',
#   'picture': None,
#   'deathDate': '0724-01-01T00:00:00',
#   'deathPlace': None,
#   'issueList': ['/wiki/Carloman_(mayor_of_the_palace)',
#    '/wiki/Pepin_the_Short',
#    '/wiki/Hiltrud',
#    '/wiki/Auda_of_France']},
#  '/wiki/Charles_Martel': {'id': '/wiki/Charles_Martel',
#   'name': 'Charles Martel',
#   'title': '/wiki/Duke_and_Prince_of_the_Franks',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/f/f2/Charles_Martel_01.jpg/220px-Charles_Martel_01.jpg',
#   'birthDate': '0676-08-23T00:00:00',
#   'birthPlace': '/wiki/Herstal',
#   'deathDate': '0741-10-22T00:00:00',
#   'deathPlace': '/wiki/Quierzy',
#   'spouseList': ['/wiki/Rotrude_of_Hesbaye'],
#   'issueList': ['/wiki/Carloman_(mayor_of_the_palace)',
#    '/wiki/Pepin_the_Short',
#    '/wiki/Grifo_(noble)',
#    '/wiki/Bernard,_son_of_Charles_Martel',
#    '/wiki/Hieronymus,_son_of_Charles_Martel',
#    '/wiki/Remigius_of_Rouen',
#    '/wiki/Hiltrud',
#    '/wiki/Auda_of_France'],
#   'house': '/wiki/Arnulfings',
#   'father': '/wiki/Pepin_of_Herstal',
#   'mother': '/wiki/Alpaida',
#   'religion': '/wiki/Roman_Catholicism'},
#  '/wiki/Grifo_(noble)': {'id': '/wiki/Grifo_(noble)', 'name': 'Grifo (noble)'},
#  '/wiki/Pepin_of_Herstal': {'id': '/wiki/Pepin_of_Herstal',
#   'name': 'Pepin of Herstal',
#   'title': '/wiki/Duke_and_Prince_of_the_Franks',
#   'picture': None,
#   'birthDate': '0635-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0714-12-16T00:00:00',
#   'deathPlace': '/wiki/Jupille-sur-Meuse',
#   'spouseList': ['/wiki/Plectrude'],
#   'issueList': [],
#   'house': '/wiki/Arnulfings',
#   'father': '/wiki/Ansegisel',
#   'mother': '/wiki/Begga'},
#  '/wiki/Begga': {'id': '/wiki/Begga',
#   'name': 'Begga',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/6/62/Begga_de_landen.jpg/150px-Begga_de_landen.jpg',
#   'birthDate': '0613-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0693-12-17T00:00:00',
#   'deathPlace': None},
#  '/wiki/Bernard,_son_of_Charles_Martel': {'id': '/wiki/Bernard,_son_of_Charles_Martel',
#   'name': 'Bernard, son of Charles Martel'},
#  '/wiki/Gerold_of_Vinzgau': {'id': '/wiki/Gerold_of_Vinzgau',
#   'name': 'Gerold of Vinzgau',
#   'title': 'Count in Kraichgau and Anglachgau',
#   'picture': None,
#   'birthDate': '0725-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0799-01-01T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['Emma of Alemannia']},
#  '/wiki/Bernard_of_Italy': {'id': '/wiki/Bernard_of_Italy',
#   'name': 'Bernard of Italy',
#   'title': '/wiki/King_of_Italy',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Frontispiece%2C_St._Paul_im_Lavanttal%2C_Stiftsbibliothek%2C_Cod._4-1.jpg/220px-Frontispiece%2C_St._Paul_im_Lavanttal%2C_Stiftsbibliothek%2C_Cod._4-1.jpg',
#   'birthDate': '0797-01-01T00:00:00',
#   'birthPlace': '/wiki/Vermandois',
#   'deathDate': '0818-04-17T00:00:00',
#   'deathPlace': '/wiki/Aachen',
#   'issueList': [],
#   'house': '/wiki/Carolingian',
#   'father': '/wiki/Pepin_of_Italy'},
#  '/wiki/Remigius_of_Rouen': {'id': '/wiki/Remigius_of_Rouen',
#   'name': 'Remigius of Rouen'},
#  '/wiki/Fastrada': {'id': '/wiki/Fastrada',
#   'name': 'Fastrada',
#   'title': '/wiki/List_of_Frankish_queens',
#   'picture': None,
#   'birthDate': '0765-01-01T00:00:00',
#   'birthPlace': '/wiki/Ingelheim',
#   'deathDate': '0794-08-10T00:00:00',
#   'deathPlace': '/wiki/Frankfurt',
#   'spouseList': ['/wiki/Charlemagne'],
#   'issueList': ['/wiki/Theodrada'],
#   'father': 'East Frankish Count Rudolph',
#   'mother': 'Aeda',
#   'religion': '/wiki/Catholic_Church'},
#  '/wiki/Louis_the_Pious': {'id': '/wiki/Louis_the_Pious',
#   'name': 'Louis the Pious',
#   'title': '/wiki/Holy_Roman_Emperor',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Ludwik_I_Pobo%C5%BCny.jpg/220px-Ludwik_I_Pobo%C5%BCny.jpg',
#   'birthDate': '0778-04-16T00:00:00',
#   'birthPlace': '/wiki/Chasseneuil-du-Poitou',
#   'deathDate': '0840-06-20T00:00:00',
#   'deathPlace': '/wiki/Ingelheim',
#   'spouseList': [],
#   'issueList': ['/wiki/Lothair_I',
#    '/wiki/Pepin_I_of_Aquitaine',
#    '/wiki/Louis_the_German',
#    '/wiki/Gisela,_daughter_of_Louis_the_Pious',
#    '/wiki/Charles_the_Bald'],
#   'house': '/wiki/Carolingian',
#   'father': '/wiki/Charlemagne',
#   'mother': '/wiki/Hildegard_of_the_Vinzgau',
#   'religion': '/wiki/Chalcedonian_Christianity'},
#  '/wiki/Hieronymus,_son_of_Charles_Martel': {'id': '/wiki/Hieronymus,_son_of_Charles_Martel',
#   'name': 'Hieronymus, son of Charles Martel'},
#  '/wiki/Lothair_I': {'id': '/wiki/Lothair_I',
#   'name': 'Lothair I',
#   'title': '/wiki/Holy_Roman_Emperor',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/f/fb/Lothar_I.jpg/220px-Lothar_I.jpg',
#   'birthDate': '0795-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0855-09-29T00:00:00',
#   'deathPlace': '/wiki/Pr%C3%BCm',
#   'issueList': [],
#   'house': '/wiki/Carolingians',
#   'father': '/wiki/Louis_the_Pious',
#   'mother': '/wiki/Ermengarde_of_Hesbaye'},
#  '/wiki/Desiderata_of_the_Lombards': {'id': '/wiki/Desiderata_of_the_Lombards',
#   'name': 'Desiderata of the Lombards',
#   'title': '/wiki/List_of_Frankish_queens',
#   'picture': None,
#   'spouseList': ['/wiki/Charlemagne'],
#   'father': '/wiki/Desiderius',
#   'mother': '/wiki/Ansa,_Queen_of_the_Lombards'},
#  '/wiki/Carloman_I': {'id': '/wiki/Carloman_I',
#   'name': 'Carloman I',
#   'title': '/wiki/King_of_the_Franks',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/8/88/Denier_sous_Carloman_Ier.jpg/220px-Denier_sous_Carloman_Ier.jpg',
#   'birthDate': '0751-06-28T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0771-12-04T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/Gerberga,_wife_of_Carloman_I'],
#   'issueList': [],
#   'house': '/wiki/Carolingian_dynasty',
#   'father': '/wiki/Pepin_the_Short',
#   'mother': '/wiki/Bertrada_of_Laon'},
#  '/wiki/Charibert_of_Laon': {'id': '/wiki/Charibert_of_Laon',
#   'name': 'Charibert of Laon'},
#  '/wiki/Hiltrud': {'id': '/wiki/Hiltrud', 'name': 'Hiltrud'},
#  '/wiki/Alpaida': {'id': '/wiki/Alpaida',
#   'name': 'Alpaida',
#   'picture': None,
#   'birthDate': '0654-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0714-01-01T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/Pepin_of_Herstal']},
#  '/wiki/Plectrude': {'id': '/wiki/Plectrude', 'name': 'Plectrude'},
#  '/wiki/Himiltrude': {'id': '/wiki/Himiltrude',
#   'name': 'Himiltrude',
#   'picture': None,
#   'birthDate': '0742-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0780-01-01T00:00:00',
#   'deathPlace': None,
#   'issueList': []},
#  '/wiki/Ansegisel': {'id': '/wiki/Ansegisel',
#   'name': 'Ansegisel',
#   'picture': None,
#   'birthDate': '0602-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0679-01-01T00:00:00',
#   'deathPlace': None,
#   'father': '/wiki/Arnulf_of_Metz'},
#  '/wiki/Desiderius': {'id': '/wiki/Desiderius',
#   'name': 'Desiderius',
#   'title': '/wiki/King_of_the_Lombards',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/d/da/Tremisse_di_Re_Desiderio%2C_Dominio_Longobardo.jpg/220px-Tremisse_di_Re_Desiderio%2C_Dominio_Longobardo.jpg',
#   'birthDate': '0720-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0786-01-01T00:00:00',
#   'deathPlace': None,
#   'issueList': [],
#   'house': '/wiki/List_of_kings_of_the_Lombards'},
#  '/wiki/Ermengarde_of_Hesbaye': {'id': '/wiki/Ermengarde_of_Hesbaye',
#   'name': 'Ermengarde of Hesbaye',
#   'title': '/wiki/Carolingian_empress',
#   'picture': None,
#   'birthDate': '0778-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0818-01-01T00:00:00',
#   'deathPlace': '/wiki/Angers',
#   'spouseList': ['/wiki/Louis_the_Pious'],
#   'issueList': [],
#   'house': '/wiki/Hesbaye',
#   'father': '/wiki/Ingerman,_Count_of_Hesbaye',
#   'mother': 'Rotrude'},
#  '/wiki/Louis_the_German': {'id': '/wiki/Louis_the_German',
#   'name': 'Louis the German',
#   'title': '/wiki/King_of_East_Francia',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/2/28/Ludwig_der_Deutsche.jpg/220px-Ludwig_der_Deutsche.jpg',
#   'birthDate': '0806-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0876-08-28T00:00:00',
#   'deathPlace': '/wiki/Frankfurt_am_Main',
#   'spouseList': ['/wiki/Hemma'],
#   'issueList': [],
#   'dynasty': '/wiki/Carolingian',
#   'father': '/wiki/Louis_the_Pious',
#   'mother': '/wiki/Ermengarde_of_Hesbaye'},
#  '/wiki/Carloman_(mayor_of_the_palace)': {'id': '/wiki/Carloman_(mayor_of_the_palace)',
#   'name': 'Carloman (mayor of the palace)',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/e/e4/Charles_Martel_divise_le_royaume_entre_P%C3%A9pin_et_Carloman.jpg/220px-Charles_Martel_divise_le_royaume_entre_P%C3%A9pin_et_Carloman.jpg',
#   'birthDate': '0713-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0754-08-17T00:00:00',
#   'deathPlace': '/wiki/Vienne,_Is%C3%A8re'},
#  '/wiki/Auda_of_France': {'id': '/wiki/Auda_of_France',
#   'name': 'Auda of France'},
#  '/wiki/Pepin_I_of_Aquitaine': {'id': '/wiki/Pepin_I_of_Aquitaine',
#   'name': 'Pepin I of Aquitaine'},
#  '/wiki/Gerberga,_wife_of_Carloman_I': {'id': '/wiki/Gerberga,_wife_of_Carloman_I',
#   'name': 'Gerberga, wife of Carloman I'},
#  '/wiki/Ansa,_Queen_of_the_Lombards': {'id': '/wiki/Ansa,_Queen_of_the_Lombards',
#   'name': 'Ansa, Queen of the Lombards',
#   'title': 'Queen consort of the Lombards',
#   'picture': None,
#   'deathDate': '0774-01-01T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/Desiderius'],
#   'issueList': []},
#  '/wiki/Charles_the_Bald': {'id': '/wiki/Charles_the_Bald',
#   'name': 'Charles the Bald',
#   'title': '/wiki/Holy_Roman_Emperor',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/4/40/Biblioth%C3%A8que_nationale_de_France_-_Bible_de_Vivien_Ms._Latin_1_folio_423r_d%C3%A9tail_Le_comte_Vivien_offre_le_manuscrit_de_la_Bible_faite_%C3%A0_l%27abbaye_de_Saint-Martin_de_Tours_%C3%A0_Charles_le_Chauve.jpg/220px-thumbnail.jpg',
#   'birthDate': '0823-01-01T00:00:00',
#   'birthPlace': '/wiki/Frankfurt',
#   'deathDate': '0877-10-06T00:00:00',
#   'deathPlace': '/wiki/Brides-les-Bains',
#   'spouseList': ['/wiki/Ermentrude_of_Orl%C3%A9ans'],
#   'issueList': ['/wiki/Judith_of_Flanders',
#    '/wiki/Louis_the_Stammerer',
#    '/wiki/Charles_the_Child',
#    '/wiki/Lothair_the_Lame',
#    '/wiki/Carloman,_son_of_Charles_the_Bald',
#    '/wiki/Rothilde'],
#   'house': '/wiki/Carolingian',
#   'father': '/wiki/Louis_the_Pious',
#   'mother': '/wiki/Judith_of_Bavaria_(died_843)'},
#  '/wiki/Charles_the_Child': {'id': '/wiki/Charles_the_Child',
#   'name': 'Charles the Child'},
#  '/wiki/Rothilde': {'id': '/wiki/Rothilde',
#   'name': 'Rothilde',
#   'picture': None,
#   'birthDate': '0871-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0928-01-01T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/Roger,_Count_of_Maine'],
#   'issueList': [],
#   'house': '/wiki/Carolingian',
#   'father': '/wiki/Charles_the_Bald',
#   'mother': '/wiki/Richilde_of_Provence'},
#  '/wiki/Roger,_Count_of_Maine': {'id': '/wiki/Roger,_Count_of_Maine',
#   'name': 'Roger, Count of Maine',
#   'title': '/wiki/Count_of_Maine',
#   'picture': None,
#   'deathDate': '0900-01-01T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/Rothilde'],
#   'issueList': []},
#  '/wiki/Theodrada': {'id': '/wiki/Theodrada',
#   'name': 'Theodrada',
#   'title': 'Abbess of Argenteuil',
#   'picture': None,
#   'birthDate': '0784-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0844-01-01T00:00:00',
#   'deathPlace': None,
#   'father': '/wiki/Charlemagne',
#   'mother': '/wiki/Fastrada'},
#  '/wiki/Gisela,_daughter_of_Louis_the_Pious': {'id': '/wiki/Gisela,_daughter_of_Louis_the_Pious',
#   'name': 'Gisela, daughter of Louis the Pious',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/c/c7/%C3%89vrard_et_sa_Femme_Gis%C3%A8le_%C3%A0_Cysoing.jpg/200px-%C3%89vrard_et_sa_Femme_Gis%C3%A8le_%C3%A0_Cysoing.jpg',
#   'birthDate': '0820-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0863-01-01T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/Eberhard_of_Friuli']},
#  '/wiki/Eberhard_of_Friuli': {'id': '/wiki/Eberhard_of_Friuli',
#   'name': 'Eberhard of Friuli'},
#  '/wiki/Ermentrude_of_Orl%C3%A9ans': {'id': '/wiki/Ermentrude_of_Orl%C3%A9ans',
#   'name': 'Ermentrude of Orléans',
#   'title': '/wiki/List_of_Queens_and_Empresses_of_France',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/a/a4/Ermentruda_kralovna.jpg/220px-Ermentruda_kralovna.jpg',
#   'birthDate': '0823-09-27T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0869-10-06T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/Charles_the_Bald'],
#   'issueList': ['/wiki/Judith_of_Flanders',
#    '/wiki/Louis_the_Stammerer',
#    '/wiki/Charles_the_Child',
#    '/wiki/Carloman,_son_of_Charles_the_Bald'],
#   'dynasty': 'Udalriching',
#   'father': '/wiki/Odo_I,_Count_of_Orl%C3%A9ans',
#   'mother': '/wiki/Engeltrude_de_F%C3%A9zensac'},
#  '/wiki/Engeltrude_de_F%C3%A9zensac': {'id': '/wiki/Engeltrude_de_F%C3%A9zensac',
#   'name': 'Engeltrude de Fézensac',
#   'title': '/wiki/List_of_consorts_of_Orl%C3%A9ans',
#   'picture': None,
#   'birthDate': '0799-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0853-01-01T00:00:00',
#   'deathPlace': None,
#   'issueList': [],
#   'father': '/wiki/Leuthard_I_of_Paris',
#   'mother': 'Grimhilda'},
#  '/wiki/Lothair_the_Lame': {'id': '/wiki/Lothair_the_Lame',
#   'name': 'Lothair the Lame'},
#  '/wiki/Louis_the_Stammerer': {'id': '/wiki/Louis_the_Stammerer',
#   'name': 'Louis the Stammerer',
#   'title': '/wiki/List_of_French_monarchs',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/a/ad/Denier_sous_Louis_II_dit_le_B%C3%A8gue.jpg/220px-Denier_sous_Louis_II_dit_le_B%C3%A8gue.jpg',
#   'birthDate': '0846-11-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0879-04-10T00:00:00',
#   'deathPlace': '/wiki/Compi%C3%A8gne',
#   'spouseList': [],
#   'issueList': [],
#   'dynasty': '/wiki/Carolingian',
#   'father': '/wiki/Charles_the_Bald',
#   'mother': '/wiki/Ermentrude_of_Orl%C3%A9ans'},
#  '/wiki/Carloman,_son_of_Charles_the_Bald': {'id': '/wiki/Carloman,_son_of_Charles_the_Bald',
#   'name': 'Carloman, son of Charles the Bald'},
#  '/wiki/Ingerman,_Count_of_Hesbaye': {'id': '/wiki/Ingerman,_Count_of_Hesbaye',
#   'name': 'Ingerman, Count of Hesbaye'},
#  '/wiki/Hemma': {'id': '/wiki/Hemma',
#   'name': 'Hemma',
#   'title': '/wiki/List_of_Frankish_queens',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/3/34/Hemma.jpg/220px-Hemma.jpg',
#   'birthDate': '0803-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0876-01-01T00:00:00',
#   'deathPlace': '/wiki/Regensburg',
#   'spouseList': ['/wiki/Louis_the_German'],
#   'issueList': [],
#   'house': '/wiki/House_of_Welf',
#   'father': '/wiki/Welf_(father_of_Judith)',
#   'mother': '/wiki/Hedwig_of_Bavaria'},
#  '/wiki/Judith_of_Flanders': {'id': '/wiki/Judith_of_Flanders',
#   'name': 'Judith of Flanders',
#   'title': '/wiki/Queen_consort_of_Wessex',
#   'picture': None,
#   'birthDate': '0844-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0879-01-01T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/%C3%86thelwulf,_King_of_Wessex'],
#   'issueList': [],
#   'dynasty': '/wiki/Carolingian_dynasty',
#   'father': '/wiki/Charles_the_Bald',
#   'mother': '/wiki/Ermentrude_of_Orl%C3%A9ans'},
#  '/wiki/Welf_(father_of_Judith)': {'id': '/wiki/Welf_(father_of_Judith)',
#   'name': 'Welf (father of Judith)',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/b/b5/Welf_I..jpg/220px-Welf_I..jpg',
#   'birthDate': '0776-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0825-01-01T00:00:00',
#   'deathPlace': None,
#   'issueList': ['/wiki/Judith_of_Bavaria_(died_843)',
#    '/wiki/Conrad_I,_Count_of_Auxerre',
#    '/wiki/Rudolph,_Count_of_Ponthieu',
#    '/wiki/Hemma']},
#  '/wiki/Judith_of_Bavaria_(died_843)': {'id': '/wiki/Judith_of_Bavaria_(died_843)',
#   'name': 'Judith of Bavaria (died 843)',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/e/eb/Wgt_Stifterb%C3%BCchlein_11v.jpg/220px-Wgt_Stifterb%C3%BCchlein_11v.jpg',
#   'birthDate': '0797-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0843-01-01T00:00:00',
#   'deathPlace': '/wiki/Tours',
#   'spouseList': ['/wiki/Louis_the_Pious'],
#   'issueList': [],
#   'house': '/wiki/Elder_House_of_Welf',
#   'father': '/wiki/Welf_(father_of_Judith)',
#   'mother': '/wiki/Hedwig_of_Bavaria'},
#  '/wiki/Odo_I,_Count_of_Orl%C3%A9ans': {'id': '/wiki/Odo_I,_Count_of_Orl%C3%A9ans',
#   'name': 'Odo I, Count of Orléans',
#   'title': '/wiki/Count_of_Orl%C3%A9ans',
#   'picture': None,
#   'deathDate': '0834-05-25T00:00:00',
#   'deathPlace': None,
#   'issueList': [],
#   'father': '/wiki/Adrian,_Count_of_Orl%C3%A9ans',
#   'mother': 'Waldrada (possibly)'},
#  '/wiki/Arnulf_of_Metz': {'id': '/wiki/Arnulf_of_Metz',
#   'name': 'Arnulf of Metz',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/7/78/Saint_Arnould.jpg/250px-Saint_Arnould.jpg',
#   'birthDate': '0582-01-01T00:00:00',
#   'birthPlace': '/wiki/Lay-Saint-Christophe',
#   'deathDate': '0643-01-01T00:00:00',
#   'deathPlace': '/wiki/Remiremont'},
#  '/wiki/Richilde_of_Provence': {'id': '/wiki/Richilde_of_Provence',
#   'name': 'Richilde of Provence',
#   'title': '/wiki/List_of_Holy_Roman_empresses',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/3/37/Louis_II_le_B%C3%A8gue_recevant_les_Regalia_%28Richilde_of_Provence_crop%29.jpg/150px-Louis_II_le_B%C3%A8gue_recevant_les_Regalia_%28Richilde_of_Provence_crop%29.jpg',
#   'birthDate': '0845-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0910-06-02T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/Charles_the_Bald'],
#   'issueList': [],
#   'house': '/wiki/Bivinids',
#   'father': '/wiki/Bivin_of_Gorze'},
#  '/wiki/Bivin_of_Gorze': {'id': '/wiki/Bivin_of_Gorze',
#   'name': 'Bivin of Gorze'},
#  '/wiki/Leuthard_I_of_Paris': {'id': '/wiki/Leuthard_I_of_Paris',
#   'name': 'Leuthard I of Paris'},
#  '/wiki/Rudolph,_Count_of_Ponthieu': {'id': '/wiki/Rudolph,_Count_of_Ponthieu',
#   'name': 'Rudolph, Count of Ponthieu',
#   'picture': None,
#   'deathDate': '0866-01-01T00:00:00',
#   'deathPlace': None,
#   'issueList': [],
#   'father': '/wiki/Welf_(father_of_Judith)',
#   'mother': '/wiki/Hedwig_of_Bavaria'},
#  '/wiki/Hedwig_of_Bavaria': {'id': '/wiki/Hedwig_of_Bavaria',
#   'name': 'Hedwig of Bavaria',
#   'picture': None,
#   'birthDate': '0778-01-01T00:00:00',
#   'birthPlace': '/wiki/Alamannia',
#   'deathDate': '0835-01-01T00:00:00',
#   'deathPlace': '/wiki/Bavaria',
#   'issueList': ['/wiki/Judith_of_Bavaria_(died_843)',
#    '/wiki/Conrad_I,_Count_of_Auxerre',
#    '/wiki/Rudolph,_Count_of_Ponthieu',
#    '/wiki/Hemma'],
#   'father': '/wiki/Isambart',
#   'mother': '/wiki/Thiedrada'},
#  '/wiki/%C3%86thelwulf,_King_of_Wessex': {'id': '/wiki/%C3%86thelwulf,_King_of_Wessex',
#   'name': 'Æthelwulf, King of Wessex',
#   'title': '/wiki/King_of_Wessex',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/d/d6/%C3%86thelwulf_-_MS_Royal_14_B_VI.jpg/220px-%C3%86thelwulf_-_MS_Royal_14_B_VI.jpg',
#   'deathDate': '0858-01-13T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/Osburh'],
#   'issueList': ['/wiki/%C3%86thelstan_of_Kent',
#    '/wiki/%C3%86thelswith',
#    '/wiki/%C3%86thelbald,_King_of_Wessex',
#    '/wiki/%C3%86thelberht,_King_of_Wessex',
#    '/wiki/%C3%86thelred_I_of_Wessex',
#    '/wiki/Alfred_the_Great'],
#   'house': '/wiki/House_of_Wessex',
#   'father': '/wiki/Ecgberht,_King_of_Wessex'},
#  '/wiki/Thiedrada': {'id': '/wiki/Thiedrada', 'name': 'Thiedrada'},
#  '/wiki/Conrad_I,_Count_of_Auxerre': {'id': '/wiki/Conrad_I,_Count_of_Auxerre',
#   'name': 'Conrad I, Count of Auxerre'},
#  '/wiki/Isambart': {'id': '/wiki/Isambart', 'name': 'Isambart'},
#  '/wiki/Ecgberht,_King_of_Wessex': {'id': '/wiki/Ecgberht,_King_of_Wessex',
#   'name': 'Ecgberht, King of Wessex',
#   'title': '/wiki/King_of_Wessex',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/8/83/Egbert_-_MS_Royal_14_B_V.jpg/220px-Egbert_-_MS_Royal_14_B_V.jpg',
#   'birthDate': '0771-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0839-01-01T00:00:00',
#   'deathPlace': None,
#   'issueList': [],
#   'house': '/wiki/House_of_Wessex',
#   'father': '/wiki/Ealhmund_of_Kent'},
#  '/wiki/%C3%86thelberht,_King_of_Wessex': {'id': '/wiki/%C3%86thelberht,_King_of_Wessex',
#   'name': 'Æthelberht, King of Wessex',
#   'title': '/wiki/King_of_Wessex',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/8/81/%C3%86thelberht_-_MS_Royal_14_B_VI.jpg/220px-%C3%86thelberht_-_MS_Royal_14_B_VI.jpg',
#   'deathDate': '0865-01-01T00:00:00',
#   'deathPlace': None,
#   'house': '/wiki/House_of_Wessex',
#   'father': '/wiki/%C3%86thelwulf,_King_of_Wessex',
#   'mother': '/wiki/Osburh'},
#  '/wiki/Adrian,_Count_of_Orl%C3%A9ans': {'id': '/wiki/Adrian,_Count_of_Orl%C3%A9ans',
#   'name': 'Adrian, Count of Orléans',
#   'title': '/wiki/Count_of_Orl%C3%A9ans',
#   'picture': None,
#   'birthDate': '0755-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0821-01-01T00:00:00',
#   'deathPlace': None,
#   'issueList': ['/wiki/Odo_I,_Count_of_Orl%C3%A9ans',
#    '/wiki/Waldrada_of_Worms'],
#   'father': '/wiki/Gerold_of_Vinzgau',
#   'mother': 'Emma of Alemannia'},
#  '/wiki/Ealhmund_of_Kent': {'id': '/wiki/Ealhmund_of_Kent',
#   'name': 'Ealhmund of Kent'},
#  '/wiki/Alfred_the_Great': {'id': '/wiki/Alfred_the_Great',
#   'name': 'Alfred the Great',
#   'title': '/wiki/King_of_the_West_Saxons',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/8/8b/Alfred_the_Great_silver_coin.jpg/220px-Alfred_the_Great_silver_coin.jpg',
#   'birthDate': '0848-01-01T00:00:00',
#   'birthPlace': '/wiki/Wantage',
#   'deathDate': '0899-10-26T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/Ealhswith'],
#   'issueList': ['/wiki/%C3%86thelfl%C3%A6d',
#    '/wiki/Edward_the_Elder',
#    '/wiki/%C3%86thelgifu,_Abbess_of_Shaftesbury',
#    '/wiki/%C3%86lfthryth,_Countess_of_Flanders',
#    '/wiki/%C3%86thelweard_(son_of_Alfred)'],
#   'house': '/wiki/House_of_Wessex',
#   'father': '/wiki/%C3%86thelwulf,_King_of_Wessex',
#   'mother': '/wiki/Osburh'},
#  '/wiki/%C3%86thelgifu,_Abbess_of_Shaftesbury': {'id': '/wiki/%C3%86thelgifu,_Abbess_of_Shaftesbury',
#   'name': 'Æthelgifu, Abbess of Shaftesbury'},
#  '/wiki/%C3%86thelstan_of_Kent': {'id': '/wiki/%C3%86thelstan_of_Kent',
#   'name': 'Æthelstan of Kent'},
#  '/wiki/%C3%86lfthryth,_Countess_of_Flanders': {'id': '/wiki/%C3%86lfthryth,_Countess_of_Flanders',
#   'name': 'Ælfthryth, Countess of Flanders',
#   'title': '/wiki/List_of_countesses_of_Flanders_by_marriage',
#   'picture': None,
#   'birthDate': '0877-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0929-06-07T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/Baldwin_II,_Margrave_of_Flanders'],
#   'issueList': [],
#   'house': '/wiki/House_of_Wessex',
#   'father': '/wiki/Alfred_the_Great',
#   'mother': '/wiki/Ealhswith'},
#  '/wiki/%C3%86thelweard_(son_of_Alfred)': {'id': '/wiki/%C3%86thelweard_(son_of_Alfred)',
#   'name': 'Æthelweard (son of Alfred)'},
#  '/wiki/Baldwin_II,_Margrave_of_Flanders': {'id': '/wiki/Baldwin_II,_Margrave_of_Flanders',
#   'name': 'Baldwin II, Margrave of Flanders',
#   'title': '/wiki/Margrave_of_Flanders',
#   'picture': None,
#   'birthDate': '0865-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0918-01-01T00:00:00',
#   'deathPlace': None,
#   'issueList': ['/wiki/Arnulf_I,_Count_of_Flanders',
#    '/wiki/Adelolf,_Count_of_Boulogne'],
#   'father': '/wiki/Baldwin_I,_Margrave_of_Flanders',
#   'mother': '/wiki/Judith_of_Flanders'},
#  '/wiki/%C3%86thelred_I_of_Wessex': {'id': '/wiki/%C3%86thelred_I_of_Wessex',
#   'name': 'Æthelred I of Wessex',
#   'title': '/wiki/King_of_Wessex',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/0/0f/%C3%86thelred_-_MS_Royal_14_B_VI.jpg/220px-%C3%86thelred_-_MS_Royal_14_B_VI.jpg',
#   'birthDate': '0845-01-01T00:00:00',
#   'birthPlace': '/wiki/Wessex',
#   'deathDate': '0871-01-01T00:00:00',
#   'deathPlace': None,
#   'issueList': ['/wiki/%C3%86thelhelm', '/wiki/%C3%86thelwold_%C3%A6theling'],
#   'house': '/wiki/House_of_Wessex',
#   'father': '/wiki/%C3%86thelwulf,_King_of_Wessex',
#   'mother': '/wiki/Osburh'},
#  '/wiki/Edward_the_Elder': {'id': '/wiki/Edward_the_Elder',
#   'name': 'Edward the Elder',
#   'title': '/wiki/King_of_the_Anglo-Saxons',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/4/4e/Edward_the_Elder_-_MS_Royal_14_B_VI.jpg/250px-Edward_the_Elder_-_MS_Royal_14_B_VI.jpg',
#   'birthDate': '0874-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0924-01-01T00:00:00',
#   'deathPlace': '/wiki/Farndon,_Cheshire',
#   'spouseList': ['/wiki/Ecgwynn',
#    '/wiki/%C3%86lffl%C3%A6d_(wife_of_Edward_the_Elder)',
#    '/wiki/Eadgifu_of_Kent'],
#   'issueList': ['/wiki/%C3%86thelstan',
#    '/wiki/Edith_of_Polesworth',
#    '/wiki/%C3%86lfweard_of_Wessex',
#    '/wiki/Edwin_(son_of_Edward_the_Elder)',
#    '/wiki/Eadgifu_of_Wessex',
#    '/wiki/Eadhild',
#    '/wiki/Eadgyth',
#    '/wiki/Edmund_I',
#    '/wiki/Eadred',
#    '/wiki/Eadburh_of_Winchester'],
#   'house': '/wiki/House_of_Wessex',
#   'father': '/wiki/Alfred_the_Great',
#   'mother': '/wiki/Ealhswith'},
#  '/wiki/Ealhswith': {'id': '/wiki/Ealhswith',
#   'name': 'Ealhswith',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/c/c9/Queen_Ealhswith.png',
#   'deathDate': '0902-12-05T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/Alfred_the_Great'],
#   'issueList': ['/wiki/%C3%86thelfl%C3%A6d',
#    '/wiki/Edward_the_Elder',
#    '/wiki/%C3%86thelgifu,_Abbess_of_Shaftesbury',
#    '/wiki/%C3%86lfthryth,_Countess_of_Flanders',
#    '/wiki/%C3%86thelweard_(son_of_Alfred)'],
#   'father': '/wiki/%C3%86thelred_Mucel',
#   'mother': 'Eadburh'},
#  '/wiki/Osburh': {'id': '/wiki/Osburh',
#   'name': 'Osburh',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/9/9b/Queen_Osburga_reads_for_her_son%2C_Alfred.gif/220px-Queen_Osburga_reads_for_her_son%2C_Alfred.gif',
#   'spouseList': ['/wiki/%C3%86thelwulf,_King_of_Wessex'],
#   'issueList': ['/wiki/%C3%86thelstan_of_Kent',
#    '/wiki/%C3%86thelswith',
#    '/wiki/%C3%86thelbald,_King_of_Wessex',
#    '/wiki/%C3%86thelberht,_King_of_Wessex',
#    '/wiki/%C3%86thelred_I_of_Wessex',
#    '/wiki/Alfred_the_Great'],
#   'father': 'Oslac'},
#  '/wiki/Eadgifu_of_Kent': {'id': '/wiki/Eadgifu_of_Kent',
#   'name': 'Eadgifu of Kent',
#   'title': '/wiki/Queen_consort_of_the_Anglo-Saxons',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/8/8b/Picture_of_Queen_Ediva_in_Canterbury_Cathedral_%28detail%29.png/220px-Picture_of_Queen_Ediva_in_Canterbury_Cathedral_%28detail%29.png',
#   'birthDate': '0902-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0968-01-01T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/Edward_the_Elder'],
#   'issueList': ['/wiki/Edmund_I',
#    '/wiki/Eadred',
#    '/wiki/Eadburh_of_Winchester'],
#   'father': 'Sigehelm'},
#  '/wiki/%C3%86thelfl%C3%A6d': {'id': '/wiki/%C3%86thelfl%C3%A6d',
#   'name': 'Æthelflæd',
#   'title': '/wiki/List_of_monarchs_of_Mercia',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/3/34/%C3%86thelfl%C3%A6d_as_depicted_in_the_cartulary_of_Abingdon_Abbey.png',
#   'birthDate': '0870-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0918-06-12T00:00:00',
#   'deathPlace': '/wiki/Tamworth,_Staffordshire',
#   'issueList': [],
#   'house': '/wiki/House_of_Wessex',
#   'father': '/wiki/Alfred_the_Great',
#   'mother': '/wiki/Ealhswith'},
#  '/wiki/%C3%86thelswith': {'id': '/wiki/%C3%86thelswith',
#   'name': 'Æthelswith'},
#  '/wiki/%C3%86thelwold_%C3%A6theling': {'id': '/wiki/%C3%86thelwold_%C3%A6theling',
#   'name': 'Æthelwold ætheling'},
#  '/wiki/%C3%86lffl%C3%A6d_(wife_of_Edward_the_Elder)': {'id': '/wiki/%C3%86lffl%C3%A6d_(wife_of_Edward_the_Elder)',
#   'name': 'Ælfflæd (wife of Edward the Elder)',
#   'picture': None,
#   'spouseList': ['/wiki/Edward_the_Elder'],
#   'issueList': ['/wiki/%C3%86lfweard_of_Wessex',
#    '/wiki/Edwin_(son_of_Edward_the_Elder)',
#    '/wiki/Eadgifu_of_Wessex',
#    '/wiki/Eadhild',
#    '/wiki/Eadgyth'],
#   'father': 'Æthelhelm'},
#  '/wiki/%C3%86thelstan': {'id': '/wiki/%C3%86thelstan',
#   'name': 'Æthelstan',
#   'title': '/wiki/King_of_the_Anglo-Saxons',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/6/68/Athelstan_%28cropped%29.jpg/220px-Athelstan_%28cropped%29.jpg',
#   'birthDate': '0894-01-01T00:00:00',
#   'birthPlace': '/wiki/Wessex',
#   'deathDate': '0939-10-27T00:00:00',
#   'deathPlace': '/wiki/Gloucester',
#   'house': '/wiki/House_of_Wessex',
#   'father': '/wiki/Edward_the_Elder',
#   'mother': '/wiki/Ecgwynn'},
#  '/wiki/Adelolf,_Count_of_Boulogne': {'id': '/wiki/Adelolf,_Count_of_Boulogne',
#   'name': 'Adelolf, Count of Boulogne',
#   'picture': None,
#   'deathDate': '0933-11-13T00:00:00',
#   'deathPlace': None,
#   'issueList': [],
#   'father': '/wiki/Baldwin_II,_Margrave_of_Flanders',
#   'mother': '/wiki/%C3%86lfthryth,_Countess_of_Flanders'},
#  '/wiki/Waldrada_of_Worms': {'id': '/wiki/Waldrada_of_Worms',
#   'name': 'Waldrada of Worms',
#   'picture': None,
#   'spouseList': ['/wiki/Robert_III,_Count_of_Worms'],
#   'issueList': [],
#   'house': 'Udalriching',
#   'father': '/wiki/Adrian,_Count_of_Orl%C3%A9ans',
#   'mother': 'Waldrada of Autun'},
#  '/wiki/Eadgyth': {'id': '/wiki/Eadgyth',
#   'name': 'Eadgyth',
#   'title': '/wiki/Queen_consort_of_Germany',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/c/c1/Edita_250.jpg/220px-Edita_250.jpg',
#   'birthDate': '0910-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0946-01-01T00:00:00',
#   'deathPlace': '/wiki/Magdeburg',
#   'spouseList': ['/wiki/Otto_the_Great'],
#   'issueList': [],
#   'house': '/wiki/House_of_Wessex',
#   'father': '/wiki/Edward_the_Elder',
#   'mother': '/wiki/%C3%86lffl%C3%A6d_(wife_of_Edward_the_Elder)'},
#  '/wiki/Edith_of_Polesworth': {'id': '/wiki/Edith_of_Polesworth',
#   'name': 'Edith of Polesworth',
#   'picture': None,
#   'birthDate': None,
#   'birthPlace': None,
#   'deathDate': None,
#   'deathPlace': None},
#  '/wiki/Eadburh_of_Winchester': {'id': '/wiki/Eadburh_of_Winchester',
#   'name': 'Eadburh of Winchester',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/f/fd/Edburgah_of_Winchester.png',
#   'birthDate': '0921-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0951-06-15T00:00:00',
#   'deathPlace': None},
#  '/wiki/Eadgifu_of_Wessex': {'id': '/wiki/Eadgifu_of_Wessex',
#   'name': 'Eadgifu of Wessex',
#   'title': '/wiki/List_of_Frankish_queens',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/b/b9/Eadgifu_of_England_ludvik4_mini.jpg',
#   'deathDate': '0951-01-01T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/Charles_the_Simple'],
#   'issueList': [],
#   'house': '/wiki/House_of_Wessex',
#   'father': '/wiki/Edward_the_Elder',
#   'mother': '/wiki/%C3%86lffl%C3%A6d_(wife_of_Edward_the_Elder)'},
#  '/wiki/%C3%86thelred_Mucel': {'id': '/wiki/%C3%86thelred_Mucel',
#   'name': 'Æthelred Mucel'},
#  '/wiki/Eadred': {'id': '/wiki/Eadred',
#   'name': 'Eadred',
#   'title': '/wiki/King_of_the_English',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/7/77/Eadred_-_MS_Royal_14_B_VI.jpg/220px-Eadred_-_MS_Royal_14_B_VI.jpg',
#   'birthDate': '0923-01-01T00:00:00',
#   'birthPlace': '/wiki/Wessex',
#   'deathDate': '0955-11-23T00:00:00',
#   'deathPlace': '/wiki/Frome',
#   'house': '/wiki/House_of_Wessex',
#   'father': '/wiki/Edward_the_Elder',
#   'mother': '/wiki/Eadgifu_of_Kent'},
#  '/wiki/Ecgwynn': {'id': '/wiki/Ecgwynn',
#   'name': 'Ecgwynn',
#   'picture': None,
#   'spouseList': ['/wiki/Edward_the_Elder'],
#   'issueList': ['/wiki/%C3%86thelstan', '/wiki/Edith_of_Polesworth']},
#  '/wiki/Otto_the_Great': {'id': '/wiki/Otto_the_Great',
#   'name': 'Otto the Great',
#   'title': '/wiki/Holy_Roman_Emperor',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/8/82/Siegel_Otto_I_Posse.JPG/220px-Siegel_Otto_I_Posse.JPG',
#   'birthDate': '0912-11-23T00:00:00',
#   'birthPlace': '/wiki/Wallhausen,_Saxony-Anhalt',
#   'deathDate': '0973-05-07T00:00:00',
#   'deathPlace': '/wiki/Memleben',
#   'spouseList': ['/wiki/Eadgyth'],
#   'issueList': ['/wiki/William_(archbishop_of_Mainz)',
#    '/wiki/Liutgard_of_Saxony_(died_953)',
#    '/wiki/Liudolf,_Duke_of_Swabia',
#    '/wiki/Matilda,_Abbess_of_Quedlinburg',
#    '/wiki/Otto_II,_Holy_Roman_Emperor'],
#   'dynasty': '/wiki/Ottonian',
#   'father': '/wiki/Henry_the_Fowler',
#   'mother': '/wiki/Matilda_of_Ringelheim'},
#  '/wiki/Edmund_I': {'id': '/wiki/Edmund_I',
#   'name': 'Edmund I',
#   'title': '/wiki/King_of_the_English',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/a/a3/Edmund_I_-_MS_Royal_14_B_VI.jpg/220px-Edmund_I_-_MS_Royal_14_B_VI.jpg',
#   'birthDate': '0920-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0946-05-26T00:00:00',
#   'deathPlace': '/wiki/Pucklechurch',
#   'spouseList': ['/wiki/%C3%86lfgifu_of_Shaftesbury'],
#   'issueList': ['/wiki/Eadwig', '/wiki/Edgar,_King_of_England'],
#   'house': '/wiki/House_of_Wessex',
#   'father': '/wiki/Edward_the_Elder',
#   'mother': '/wiki/Eadgifu_of_Kent'},
#  '/wiki/Liutgard_of_Saxony_(died_953)': {'id': '/wiki/Liutgard_of_Saxony_(died_953)',
#   'name': 'Liutgard of Saxony (died 953)',
#   'title': '/wiki/List_of_consorts_of_Lorraine',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/3/3c/Luitgarda_of_Saxony.jpg',
#   'birthDate': '0932-01-01T00:00:00',
#   'birthPlace': '/wiki/Magdeburg',
#   'deathDate': '0953-11-18T00:00:00',
#   'deathPlace': '/wiki/Mainz',
#   'spouseList': ['/wiki/Conrad,_Duke_of_Lorraine'],
#   'issueList': [],
#   'dynasty': '/wiki/Ottonian_dynasty',
#   'father': '/wiki/Otto_the_Great',
#   'mother': '/wiki/Eadgyth'},
#  '/wiki/%C3%86thelhelm': {'id': '/wiki/%C3%86thelhelm',
#   'name': 'Æthelhelm',
#   'picture': None,
#   'deathDate': '0890-01-01T00:00:00',
#   'deathPlace': None,
#   'house': '/wiki/House_of_Wessex',
#   'father': '/wiki/%C3%86thelred_I_of_Wessex',
#   'mother': '/wiki/Wulfthryth_of_Wessex'},
#  '/wiki/%C3%86thelbald,_King_of_Wessex': {'id': '/wiki/%C3%86thelbald,_King_of_Wessex',
#   'name': 'Æthelbald, King of Wessex',
#   'title': '/wiki/King_of_Wessex',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/f/f7/%C3%86thelbald_-_MS_Royal_14_B_VI.jpg/220px-%C3%86thelbald_-_MS_Royal_14_B_VI.jpg',
#   'deathDate': '0860-01-01T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/Judith_of_Flanders'],
#   'house': '/wiki/House_of_Wessex',
#   'father': '/wiki/%C3%86thelwulf,_King_of_Wessex',
#   'mother': '/wiki/Osburh'},
#  '/wiki/Conrad,_Duke_of_Lorraine': {'id': '/wiki/Conrad,_Duke_of_Lorraine',
#   'name': 'Conrad, Duke of Lorraine',
#   'title': '/wiki/List_of_rulers_of_Lorraine',
#   'picture': None,
#   'birthDate': '0922-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0955-01-01T00:00:00',
#   'deathPlace': '/wiki/Augsburg',
#   'issueList': [],
#   'father': '/wiki/Werner_V_(Salian)',
#   'mother': 'Hicha of Swabia'},
#  '/wiki/Wulfthryth_of_Wessex': {'id': '/wiki/Wulfthryth_of_Wessex',
#   'name': 'Wulfthryth of Wessex',
#   'title': '/wiki/List_of_Wessex_consorts',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/3/37/Charter_S_340_-_list_of_witnesses.jpg/220px-Charter_S_340_-_list_of_witnesses.jpg',
#   'birthDate': '0868-01-01T00:00:00',
#   'birthPlace': '/wiki/Floruit',
#   'spouseList': ['/wiki/%C3%86thelred_I_of_Wessex'],
#   'issueList': []},
#  '/wiki/Charles_the_Simple': {'id': '/wiki/Charles_the_Simple',
#   'name': 'Charles the Simple',
#   'title': '/wiki/List_of_French_monarchs',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/0/0c/Denier_sous_Charles_III_le_Simple.jpg/220px-Denier_sous_Charles_III_le_Simple.jpg',
#   'birthDate': '0879-09-17T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0929-10-07T00:00:00',
#   'deathPlace': '/wiki/P%C3%A9ronne,_Somme',
#   'spouseList': ['/wiki/Frederuna'],
#   'issueList': [],
#   'dynasty': '/wiki/Carolingian',
#   'father': '/wiki/Louis_the_Stammerer',
#   'mother': '/wiki/Adelaide_of_Paris'},
#  '/wiki/Werner_V_(Salian)': {'id': '/wiki/Werner_V_(Salian)',
#   'name': 'Werner V (Salian)',
#   'title': 'Count',
#   'picture': None,
#   'birthDate': '0899-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0935-01-01T00:00:00',
#   'deathPlace': None,
#   'father': 'presumably Werner IV',
#   'mother': 'presumably Oda'},
#  '/wiki/Eadhild': {'id': '/wiki/Eadhild',
#   'name': 'Eadhild',
#   'picture': None,
#   'birthDate': None,
#   'birthPlace': None,
#   'deathDate': '0937-01-01T00:00:00',
#   'deathPlace': None,
#   'father': '/wiki/Edward_the_Elder',
#   'mother': '/wiki/%C3%86lffl%C3%A6d_(wife_of_Edward_the_Elder)'},
#  '/wiki/Edwin_(son_of_Edward_the_Elder)': {'id': '/wiki/Edwin_(son_of_Edward_the_Elder)',
#   'name': 'Edwin (son of Edward the Elder)',
#   'picture': None,
#   'deathDate': '0933-01-01T00:00:00',
#   'deathPlace': None,
#   'house': '/wiki/House_of_Wessex',
#   'father': '/wiki/Edward_the_Elder',
#   'mother': '/wiki/%C3%86lffl%C3%A6d_(wife_of_Edward_the_Elder)'},
#  '/wiki/Baldwin_I,_Margrave_of_Flanders': {'id': '/wiki/Baldwin_I,_Margrave_of_Flanders',
#   'name': 'Baldwin I, Margrave of Flanders'},
#  '/wiki/Edgar,_King_of_England': {'id': '/wiki/Edgar,_King_of_England',
#   'name': 'Edgar, King of England',
#   'title': '/wiki/King_of_England',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/7/78/Edgar_-_MS_Royal_14_B_VI.jpg/220px-Edgar_-_MS_Royal_14_B_VI.jpg',
#   'birthDate': '0943-01-01T00:00:00',
#   'birthPlace': '/wiki/Kingdom_of_England',
#   'deathDate': '0975-07-08T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/Wulfthryth_of_Wilton',
#    '/wiki/%C3%86lfthryth_(wife_of_Edgar)'],
#   'issueList': ['/wiki/Edward_the_Martyr',
#    '/wiki/Edith_of_Wilton',
#    '/wiki/%C3%86thelred_the_Unready'],
#   'house': '/wiki/House_of_Wessex',
#   'father': '/wiki/Edmund_I',
#   'mother': '/wiki/%C3%86lfgifu_of_Shaftesbury'},
#  '/wiki/Arnulf_I,_Count_of_Flanders': {'id': '/wiki/Arnulf_I,_Count_of_Flanders',
#   'name': 'Arnulf I, Count of Flanders',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/5/57/Arnulf_Flandry_941.jpg/220px-Arnulf_Flandry_941.jpg',
#   'birthDate': '0893-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0965-03-27T00:00:00',
#   'deathPlace': None,
#   'issueList': [],
#   'father': '/wiki/Baldwin_II,_Margrave_of_Flanders',
#   'mother': '/wiki/%C3%86lfthryth,_Countess_of_Flanders'},
#  '/wiki/%C3%86lfweard_of_Wessex': {'id': '/wiki/%C3%86lfweard_of_Wessex',
#   'name': 'Ælfweard of Wessex',
#   'title': '/wiki/King_of_Wessex',
#   'picture': None,
#   'birthDate': '0902-01-01T00:00:00',
#   'birthPlace': '/wiki/Wessex',
#   'deathDate': '0924-08-02T00:00:00',
#   'deathPlace': '/wiki/Oxford',
#   'house': '/wiki/House_of_Wessex',
#   'father': '/wiki/Edward_the_Elder',
#   'mother': '/wiki/%C3%86lffl%C3%A6d_(wife_of_Edward_the_Elder)',
#   'religion': '/wiki/Catholic_Church'},
#  '/wiki/Henry_the_Fowler': {'id': '/wiki/Henry_the_Fowler',
#   'name': 'Henry the Fowler',
#   'title': '/wiki/King_of_East_Francia',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/e/ea/Siegel_Heinrich_I_Posse.JPG/220px-Siegel_Heinrich_I_Posse.JPG',
#   'birthDate': '0876-07-07T00:00:00',
#   'birthPlace': '/wiki/Memleben',
#   'deathDate': '0936-07-02T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/Hatheburg_of_Merseburg'],
#   'issueList': ['/wiki/Thankmar',
#    '/wiki/Hedwig_of_Saxony',
#    '/wiki/Otto_the_Great',
#    '/wiki/Gerberga_of_Saxony',
#    '/wiki/Henry_I,_Duke_of_Bavaria',
#    '/wiki/Bruno_the_Great'],
#   'dynasty': '/wiki/Ottonian_dynasty',
#   'father': '/wiki/Otto_I,_Duke_of_Saxony',
#   'mother': '/wiki/Hedwig_of_Babenberg',
#   'religion': '/wiki/Chalcedonian_Christianity'},
#  '/wiki/William_(archbishop_of_Mainz)': {'id': '/wiki/William_(archbishop_of_Mainz)',
#   'name': 'William (archbishop of Mainz)',
#   'title': 'Archbishop of Mainz',
#   'picture': None,
#   'birthDate': '0929-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0968-03-02T00:00:00',
#   'deathPlace': None},
#  '/wiki/Liudolf,_Duke_of_Swabia': {'id': '/wiki/Liudolf,_Duke_of_Swabia',
#   'name': 'Liudolf, Duke of Swabia',
#   'title': '/wiki/Duke_of_Swabia',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/f/fc/Liudolf_of_Swabia_and_his_wife_Ida.jpg/220px-Liudolf_of_Swabia_and_his_wife_Ida.jpg',
#   'birthDate': '0930-01-01T00:00:00',
#   'birthPlace': '/wiki/Magdeburg',
#   'deathDate': '0957-01-01T00:00:00',
#   'deathPlace': '/wiki/Pombia',
#   'issueList': [],
#   'father': '/wiki/Otto_the_Great',
#   'mother': '/wiki/Eadgyth'},
#  '/wiki/Eadwig': {'id': '/wiki/Eadwig',
#   'name': 'Eadwig',
#   'title': '/wiki/King_of_England',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/0/0a/Eadwig_-_MS_Royal_14_B_VI.jpg/220px-Eadwig_-_MS_Royal_14_B_VI.jpg',
#   'birthDate': '0940-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0959-10-01T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/%C3%86lfgifu_(wife_of_Eadwig)'],
#   'house': '/wiki/House_of_Wessex',
#   'father': '/wiki/Edmund_I',
#   'mother': '/wiki/%C3%86lfgifu_of_Shaftesbury'},
#  '/wiki/Henry_I,_Duke_of_Bavaria': {'id': '/wiki/Henry_I,_Duke_of_Bavaria',
#   'name': 'Henry I, Duke of Bavaria',
#   'title': '/wiki/List_of_rulers_of_Bavaria',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/3/38/Henry_I%2C_Duke_of_Bavaria.jpg',
#   'birthDate': '0919-01-01T00:00:00',
#   'birthPlace': '/wiki/Nordhausen,_Thuringia',
#   'deathDate': '0955-11-01T00:00:00',
#   'deathPlace': '/wiki/P%C3%B6hlde_Abbey',
#   'spouseList': ['/wiki/Judith,_Duchess_of_Bavaria'],
#   'issueList': [],
#   'dynasty': '/wiki/Ottonian_dynasty',
#   'father': '/wiki/Henry_the_Fowler',
#   'mother': '/wiki/Matilda_of_Ringelheim'},
#  '/wiki/Edward_the_Martyr': {'id': '/wiki/Edward_the_Martyr',
#   'name': 'Edward the Martyr',
#   'title': '/wiki/King_of_the_English',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/e/e3/Edward_the_Martyr_-_MS_Royal_14_B_VI.jpg/220px-Edward_the_Martyr_-_MS_Royal_14_B_VI.jpg',
#   'birthDate': '0962-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0978-03-18T00:00:00',
#   'deathPlace': '/wiki/Corfe_Castle_(village)',
#   'house': '/wiki/House_of_Wessex',
#   'father': '/wiki/Edgar,_King_of_England',
#   'mother': '/wiki/Wulfthryth_of_Wilton'},
#  '/wiki/Frederuna': {'id': '/wiki/Frederuna',
#   'name': 'Frederuna',
#   'title': '/wiki/Queen_consort_of_France',
#   'picture': None,
#   'birthDate': '0887-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0917-01-01T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/Charles_the_Simple'],
#   'issueList': [],
#   'father': '/wiki/Dietrich_of_Ringelheim',
#   'mother': 'Gisela of Lotharingia'},
#  '/wiki/Robert_III,_Count_of_Worms': {'id': '/wiki/Robert_III,_Count_of_Worms',
#   'name': 'Robert III, Count of Worms',
#   'picture': None,
#   'birthDate': '0800-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0834-01-01T00:00:00',
#   'deathPlace': None,
#   'issueList': [],
#   'father': '/wiki/Robert_II,_Count_of_Hesbaye'},
#  '/wiki/%C3%86thelred_the_Unready': {'id': '/wiki/%C3%86thelred_the_Unready',
#   'name': 'Æthelred the Unready',
#   'title': '/wiki/King_of_the_English',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/b/b3/Ethelred_the_Unready.jpg/220px-Ethelred_the_Unready.jpg',
#   'birthDate': '0966-01-01T00:00:00',
#   'birthPlace': '/wiki/Kingdom_of_England',
#   'deathDate': '1016-04-23T00:00:00',
#   'deathPlace': '/wiki/London',
#   'spouseList': ['/wiki/%C3%86lfgifu_of_York', '/wiki/Emma_of_Normandy'],
#   'issueList': ['/wiki/%C3%86thelstan_%C3%86theling',
#    '/wiki/Edmund_Ironside',
#    '/wiki/Eadred_%C3%86theling',
#    '/wiki/Eadwig_%C3%86theling',
#    '/wiki/Edward_the_Confessor',
#    '/wiki/Alfred_Aetheling',
#    '/wiki/Godgifu_(daughter_of_%C3%86thelred_the_Unready)'],
#   'house': '/wiki/House_of_Wessex',
#   'father': '/wiki/Edgar,_King_of_England',
#   'mother': '/wiki/%C3%86lfthryth_(wife_of_Edgar)'},
#  '/wiki/Eadred_%C3%86theling': {'id': '/wiki/Eadred_%C3%86theling',
#   'name': 'Eadred Ætheling',
#   'picture': None,
#   'deathDate': '1012-01-01T00:00:00',
#   'deathPlace': None,
#   'house': '/wiki/House_of_Wessex',
#   'father': '/wiki/%C3%86thelred_the_Unready',
#   'mother': '/wiki/%C3%86lfgifu_of_York'},
#  '/wiki/Otto_II,_Holy_Roman_Emperor': {'id': '/wiki/Otto_II,_Holy_Roman_Emperor',
#   'name': 'Otto II, Holy Roman Emperor',
#   'title': '/wiki/Holy_Roman_Emperor',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Otto_II_%28HRE%29.jpg/220px-Otto_II_%28HRE%29.jpg',
# ...
#   'title': '/wiki/Earl_of_Hereford',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/d/dc/Elizabeth_from_Rhuddlan.jpg',
#   'birthDate': '1282-08-07T00:00:00',
#   'birthPlace': '/wiki/Rhuddlan_Castle',
#   'deathDate': '1316-05-05T00:00:00',
#   'deathPlace': '/wiki/Quendon',
#   'spouseList': ['/wiki/John_I,_Count_of_Holland'],
#   'issueList': [],
#   'house': '/wiki/House_of_Plantagenet',
#   'father': '/wiki/Edward_I_of_England',
#   'mother': '/wiki/Eleanor_of_Castile'},
#  '/wiki/Bertha_of_Milan': {'id': '/wiki/Bertha_of_Milan',
#   'name': 'Bertha of Milan'},
#  '/wiki/Conrad_IV_of_Germany': {'id': '/wiki/Conrad_IV_of_Germany',
#   'name': 'Conrad IV of Germany',
#   'title': '/wiki/List_of_German_monarchs',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/2/2d/Conrad_4_of_Germany.jpg/220px-Conrad_4_of_Germany.jpg',
#   'birthDate': '1228-04-25T00:00:00',
#   'birthPlace': '/wiki/Andria',
#   'deathDate': '1254-05-21T00:00:00',
#   'deathPlace': '/wiki/Lavello',
#   'spouseList': ['/wiki/Elisabeth_of_Bavaria,_Queen_of_Germany'],
#   'issueList': [],
#   'house': '/wiki/Hohenstaufen',
#   'father': '/wiki/Frederick_II,_Holy_Roman_Emperor',
#   'mother': '/wiki/Isabella_II_of_Jerusalem',
#   'religion': '/wiki/Catholic_Church'},
#  '/wiki/Joan_of_Brittany,_Baroness_of_Drayton': {'id': '/wiki/Joan_of_Brittany,_Baroness_of_Drayton',
#   'name': 'Joan of Brittany, Baroness of Drayton'},
#  '/wiki/Kunigunde_of_Altdorf': {'id': '/wiki/Kunigunde_of_Altdorf',
#   'name': 'Kunigunde of Altdorf',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/5/5e/Kunigunda_Azzo.jpg/220px-Kunigunda_Azzo.jpg',
#   'birthDate': '1020-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '1054-01-01T00:00:00',
#   'deathPlace': None,
#   'father': '/wiki/Welf_II,_Count_of_Swabia',
#   'mother': '/wiki/Imiza_of_Luxembourg'},
#  '/wiki/Gilbert_de_Clare,_7th_Earl_of_Gloucester': {'id': '/wiki/Gilbert_de_Clare,_7th_Earl_of_Gloucester',
#   'name': 'Gilbert de Clare, 7th Earl of Gloucester',
#   'title': 'Earl of HertfordEarl of GloucesterLord of Glamorgan',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/e/e4/CoA_Gilbert_de_Clare.svg/125px-CoA_Gilbert_de_Clare.svg.png',
#   'birthDate': '1243-09-02T00:00:00',
#   'birthPlace': '/wiki/Christchurch,_Dorset',
#   'deathDate': '1295-12-07T00:00:00',
#   'deathPlace': '/wiki/Monmouth',
#   'issueList': []},
#  '/wiki/Guy_de_Montfort,_Count_of_Nola': {'id': '/wiki/Guy_de_Montfort,_Count_of_Nola',
#   'name': 'Guy de Montfort, Count of Nola',
#   'title': 'Count of Nola',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/2/27/GuyMontfort.jpg/220px-GuyMontfort.jpg',
#   'birthDate': '1244-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '1291-01-01T00:00:00',
#   'deathPlace': None,
#   'issueList': ['/wiki/Anastasia_de_Montfort'],
#   'father': '/wiki/Simon_de_Montfort,_6th_Earl_of_Leicester',
#   'mother': '/wiki/Eleanor_of_England,_Countess_of_Leicester'},
#  '/wiki/Philip_I,_Count_of_Boulogne': {'id': '/wiki/Philip_I,_Count_of_Boulogne',
#   'name': 'Philip I, Count of Boulogne',
#   'title': '/wiki/Jure_uxoris',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/2/22/Philippe_Hurepel.jpg',
#   'birthDate': '1200-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '1235-01-01T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/Matilda_II,_Countess_of_Boulogne'],
#   'issueList': [],
#   'house': '/wiki/House_of_Capet',
#   'father': '/wiki/Philip_II_of_France',
#   'mother': '/wiki/Agnes_of_Merania'},
#  '/wiki/Gaston_VII,_Viscount_of_B%C3%A9arn': {'id': '/wiki/Gaston_VII,_Viscount_of_B%C3%A9arn',
#   'name': 'Gaston VII, Viscount of Béarn'},
#  '/wiki/Gottschalk_(Obotrite_prince)': {'id': '/wiki/Gottschalk_(Obotrite_prince)',
#   'name': 'Gottschalk (Obotrite prince)',
#   'picture': None,
#   'birthDate': None,
#   'birthPlace': None,
#   'deathDate': '1066-06-07T00:00:00',
#   'deathPlace': None},
#  '/wiki/Roger_II_of_Sicily': {'id': '/wiki/Roger_II_of_Sicily',
#   'name': 'Roger II of Sicily',
#   'title': '/wiki/King_of_Sicily#Counts_of_Sicily',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/6/6b/Martorana_Palermo_msu2017-0166.jpg/220px-Martorana_Palermo_msu2017-0166.jpg',
#   'birthDate': '1095-12-22T00:00:00',
#   'birthPlace': '/wiki/Mileto',
#   'deathDate': '1154-02-26T00:00:00',
#   'deathPlace': '/wiki/Palermo',
#   'spouseList': ['/wiki/Elvira_of_Castile,_Queen_of_Sicily'],
#   'issueList': [],
#   'house': '/wiki/House_of_Hauteville',
#   'father': '/wiki/Roger_I_of_Sicily',
#   'mother': '/wiki/Adelaide_del_Vasto',
#   'religion': '/wiki/Roman_Catholicism'},
#  '/wiki/Richard_de_Montfort': {'id': '/wiki/Richard_de_Montfort',
#   'name': 'Richard de Montfort',
#   'title': 'Seigneur of Montfort',
#   'picture': None,
#   'father': '/wiki/Simon_I_de_Montfort',
#   'mother': '/wiki/Agn%C3%A8s_d%27%C3%89vreux'},
#  '/wiki/Rainou_of_Sabran': {'id': '/wiki/Rainou_of_Sabran',
#   'name': 'Rainou of Sabran'},
#  '/wiki/Alix_of_Brittany,_Dame_de_Pontarcy': {'id': '/wiki/Alix_of_Brittany,_Dame_de_Pontarcy',
#   'name': 'Alix of Brittany, Dame de Pontarcy',
#   'title': 'Dame de Pontarcy suo jureCountess of Blois',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/8/83/Alix_bretagne.jpg',
#   'birthDate': '1243-06-06T00:00:00',
#   'birthPlace': '/wiki/Ch%C3%A2teau_de_Suscinio',
#   'deathDate': '1288-08-02T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/John_I,_Count_of_Blois'],
#   'issueList': [],
#   'house': '/wiki/List_of_rulers_of_Brittany#House_of_Dreux',
#   'father': '/wiki/John_I,_Duke_of_Brittany',
#   'mother': '/wiki/Blanche_of_Navarre,_Duchess_of_Brittany'},
#  '/wiki/Ramon_Berenguer_II,_Count_of_Barcelona': {'id': '/wiki/Ramon_Berenguer_II,_Count_of_Barcelona',
#   'name': 'Ramon Berenguer II, Count of Barcelona',
#   'title': '/wiki/Count_of_Barcelona',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/9/9e/Signum-ramon-berenguer-II-barcelona.jpg/120px-Signum-ramon-berenguer-II-barcelona.jpg',
#   'birthDate': '1053-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '1082-12-06T00:00:00',
#   'deathPlace': '/wiki/Sant_Feliu_de_Buixalleu',
#   'spouseList': ['/wiki/Maud_of_Apulia'],
#   'issueList': [],
#   'house': '/wiki/House_of_Barcelona',
#   'father': '/wiki/Ramon_Berenguer_I,_Count_of_Barcelona',
#   'mother': '/wiki/Almodis_of_La_Marche'},
#  '/wiki/Alfonso_X_of_Castile': {'id': '/wiki/Alfonso_X_of_Castile',
#   'name': 'Alfonso X of Castile',
#   'title': '/wiki/King_of_Castile',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/c/ca/Alfonso_X_el_Sabio_en_El_libro_de_los_juegos.jpg/220px-Alfonso_X_el_Sabio_en_El_libro_de_los_juegos.jpg',
#   'birthDate': '1221-11-23T00:00:00',
#   'birthPlace': '/wiki/Toledo,_Spain',
#   'deathDate': '1284-04-04T00:00:00',
#   'deathPlace': '/wiki/Seville',
#   'spouseList': ['/wiki/Violant_of_Aragon'],
#   'issueList': [],
#   'house': '/wiki/Castilian_House_of_Ivrea',
#   'father': '/wiki/Ferdinand_III_of_Castile',
#   'mother': '/wiki/Elisabeth_of_Swabia',
#   'religion': '/wiki/Roman_Catholicism'},
#  '/wiki/Richard_de_Clare,_2nd_Earl_of_Pembroke': {'id': '/wiki/Richard_de_Clare,_2nd_Earl_of_Pembroke',
#   'name': 'Richard de Clare, 2nd Earl of Pembroke',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/1/10/Strongbow.jpg',
#   'birthDate': '1130-01-01T00:00:00',
#   'birthPlace': '/wiki/Tonbridge',
#   'deathDate': '1176-01-01T00:00:00',
#   'deathPlace': '/wiki/Dublin',
#   'spouseList': ['/wiki/Aoife_MacMurrough']},
#  '/wiki/Sancha_of_Le%C3%B3n': {'id': '/wiki/Sancha_of_Le%C3%B3n',
#   'name': 'Sancha of León',
#   'title': '/wiki/Queen_consort_of_Le%C3%B3n',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/7/76/SanchaLeon.jpg',
#   'birthDate': '1018-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '1067-01-01T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/Ferdinand_I_of_Le%C3%B3n'],
#   'issueList': [],
#   'house': '/wiki/Astur-Leonese_dynasty',
#   'father': '/wiki/Alfonso_V_of_Le%C3%B3n',
#   'mother': '/wiki/Elvira_Men%C3%A9ndez_(died_1022)',
#   'religion': '/wiki/Roman_Catholicism'},
#  '/wiki/Astrid_Njalsdotter': {'id': '/wiki/Astrid_Njalsdotter',
#   'name': 'Astrid Njalsdotter'},
#  '/wiki/Constance_of_Burgundy': {'id': '/wiki/Constance_of_Burgundy',
#   'name': 'Constance of Burgundy',
#   'title': '/wiki/List_of_Leonese_consorts',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/4/47/Constan%C3%A7a_de_Borgonha.jpg',
#   'birthDate': '1046-05-08T00:00:00',
#   'birthPlace': None,
#   'deathDate': '1093-01-01T00:00:00',
#   'deathPlace': None,
#   'spouseList': ['/wiki/Alfonso_VI_of_Le%C3%B3n_and_Castile'],
#   'issueList': [],
#   'house': '/wiki/House_of_Burgundy',
#   'father': '/wiki/Robert_I,_Duke_of_Burgundy',
#   'mother': 'Helie de Semur-en-Brionnais'},
#  '/wiki/Gilbert_de_Clare,_5th_Earl_of_Gloucester': {'id': '/wiki/Gilbert_de_Clare,_5th_Earl_of_Gloucester',
#   'name': 'Gilbert de Clare, 5th Earl of Gloucester',
#   'title': '4th Earl of Hertford5th Earl of Gloucester1st Lord of Glamorgan',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Gilbert_de_Clare_illustration.jpg/220px-Gilbert_de_Clare_illustration.jpg',
#   'birthDate': '1180-01-01T00:00:00',
#   'birthPlace': '/wiki/Hertford',
#   'deathDate': '1230-10-25T00:00:00',
#   'deathPlace': '/wiki/Brittany',
#   'spouseList': ['/wiki/Isabel_Marshal'],
#   'issueList': ['/wiki/Richard_de_Clare,_6th_Earl_of_Gloucester',
#    '/wiki/Isabella_of_Gloucester_and_Hertford',
#    '/wiki/Amice_de_Clare'],
#   'father': '/wiki/Richard_de_Clare,_3rd_Earl_of_Hertford',
#   'mother': 'Amice Fitz William, suo jure Countess of Gloucester'},
#  '/wiki/Eva_Marshal': {'id': '/wiki/Eva_Marshal',
#   'name': 'Eva Marshal',
#   'picture': None,
#   'birthDate': '1203-01-01T00:00:00',
#   'birthPlace': '/wiki/Pembroke_Castle',
#   'deathDate': '1246-01-01T00:00:00',
#   'deathPlace': None,
#   'issueList': [],
#   'father': '/wiki/William_Marshal,_1st_Earl_of_Pembroke',
#   'mother': '/wiki/Isabel_de_Clare,_4th_Countess_of_Pembroke'},
#  '/wiki/Amaury_III_de_Montfort': {'id': '/wiki/Amaury_III_de_Montfort',
#   'name': 'Amaury III de Montfort',
#   'title': 'Seigneur of Montfort',
#   'picture': None,
#   'deathDate': '1137-04-19T00:00:00',
#   'deathPlace': None,
#   'issueList': ['/wiki/Amaury_IV_de_Montfort',
#    '/wiki/Simon_III_de_Montfort',
#    '/wiki/Gournay-sur-Marne'],
#   'father': '/wiki/Simon_I_de_Montfort',
#   'mother': "Agnès d'Évreux"},
#  '/wiki/Otto_IV,_Count_of_Burgundy': {'id': '/wiki/Otto_IV,_Count_of_Burgundy',
#   'name': 'Otto IV, Count of Burgundy',
#   'title': '/wiki/Count_of_Burgundy',
#   'picture': None,
#   'birthDate': '1248-01-01T00:00:00',
#   'birthPlace': '/wiki/Ornans',
#   'deathDate': '1303-03-17T00:00:00',
#   'deathPlace': '/wiki/Melun',
#   'spouseList': ['/wiki/Philippa_of_Bar'],
#   'issueList': [],
#   'house': '/wiki/House_of_Ivrea',
#   'father': '/wiki/Hugh,_Count_of_Burgundy',
#   'mother': '/wiki/Adelaide,_Countess_of_Burgundy'},
#  '/wiki/Elisabeth_of_Bavaria,_Queen_of_Germany': {'id': '/wiki/Elisabeth_of_Bavaria,_Queen_of_Germany',
#   'name': 'Elisabeth of Bavaria, Queen of Germany',
#   'title': '/wiki/Queen_consort_of_Germany',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/0/07/Elisabeth_von_Bayern_%281227%E2%80%931273%29.jpg/220px-Elisabeth_von_Bayern_%281227%E2%80%931273%29.jpg',
#   'birthDate': '1227-01-01T00:00:00',
#   'birthPlace': '/wiki/Trausnitz_Castle',
#   'deathDate': '1273-10-09T00:00:00',
#   'deathPlace': '/wiki/Schenna',
#   'spouseList': ['/wiki/Conrad_IV_of_Germany'],
#   'issueList': [],
#   'house': '/wiki/House_of_Wittelsbach',
#   'father': '/wiki/Otto_II,_Duke_of_Bavaria',
#   'mother': '/wiki/Agnes_of_the_Palatinate',
#   'religion': '/wiki/Roman_Catholicism'},
#  '/wiki/Manfred_I_of_Turin': {'id': '/wiki/Manfred_I_of_Turin',
#   'name': 'Manfred I of Turin'},
#  '/wiki/William_IV,_Duke_of_Aquitaine': {'id': '/wiki/William_IV,_Duke_of_Aquitaine',
#   'name': 'William IV, Duke of Aquitaine',
#   'picture': None,
#   'birthDate': '0937-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0994-01-01T00:00:00',
#   'deathPlace': None,
#   'father': '/wiki/William_III,_Duke_of_Aquitaine',
#   'mother': '/wiki/Gerloc'},
#  '/wiki/10)': {'id': '/wiki/10)', 'name': '10)'},
#  '/wiki/Ebalus,_Duke_of_Aquitaine': {'id': '/wiki/Ebalus,_Duke_of_Aquitaine',
#   'name': 'Ebalus, Duke of Aquitaine',
#   'picture': None,
#   'birthDate': '0870-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '0935-01-01T00:00:00',
#   'deathPlace': None,
#   'issueList': [],
#   'father': '/wiki/Ranulf_II_of_Aquitaine',
#   'mother': '?'},
#  '/wiki/Baldwin_V,_Count_of_Hainaut': {'id': '/wiki/Baldwin_V,_Count_of_Hainaut',
#   'name': 'Baldwin V, Count of Hainaut',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/0/06/Baldwin8.jpg/220px-Baldwin8.jpg',
#   'birthDate': '1150-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '1195-01-01T00:00:00',
#   'deathPlace': None,
#   'father': '/wiki/Baldwin_IV,_Count_of_Hainaut',
#   'mother': '/wiki/Alice_of_Namur'},
#  '/wiki/Mahaut_of_Albon': {'id': '/wiki/Mahaut_of_Albon',
#   'name': 'Mahaut of Albon',
#   'picture': None,
#   'birthDate': '1112-01-01T00:00:00',
#   'birthPlace': None,
#   'deathDate': '1148-01-01T00:00:00',
#   'deathPlace': None,
#   'father': '/wiki/Guigues_III_of_Albon',
#   'mother': 'Matilda'},
#  '/wiki/Rudolf_I,_Margrave_of_the_Nordmark': {'id': '/wiki/Rudolf_I,_Margrave_of_the_Nordmark',
#   'name': 'Rudolf I, Margrave of the Nordmark',
#   'title': '/wiki/Margrave_of_the_Nordmark',
#   'picture': None,
#   'deathDate': '1124-12-07T00:00:00',
#   'deathPlace': None,
#   'issueList': ['/wiki/Udo_IV,_Margrave_of_the_Nordmark',
#    '/wiki/Rudolf_II,_Margrave_of_the_Nordmark',
#    '/wiki/Hartwig,_Count_of_Stade',
#    '/wiki/Lutgard_of_Salzwedel'],
#   'father': '/wiki/Lothair_Udo_II,_Margrave_of_the_Nordmark',
#   'mother': '/wiki/Oda_von_Werl'},
#  '/wiki/Arnulf,_Count_of_Holland': {'id': '/wiki/Arnulf,_Count_of_Holland',
#   'name': 'Arnulf, Count of Holland',
#   'title': 'Count in Frisia',
#   'picture': None,
#   'birthDate': '0950-01-01T00:00:00',
#   'birthPlace': '/wiki/Ghent',
#   'deathDate': '0993-01-01T00:00:00',
#   'deathPlace': '/wiki/Winkel_(North_Holland)',
#   'spouseList': ['/wiki/Lutgardis_of_Luxemburg'],
#   'issueList': [],
#   'house': '/wiki/Count_of_Holland',
#   'father': '/wiki/Dirk_II,_Count_of_Holland',
#   'mother': 'Hildegarde of Flanders'},
#  '/wiki/Ferdinand,_Count_of_Flanders': {'id': '/wiki/Ferdinand,_Count_of_Flanders',
#   'name': 'Ferdinand, Count of Flanders',
#   'title': '/wiki/Jure_uxoris',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/6/6d/Fernando_of_Portugal_bouvines.jpg/200px-Fernando_of_Portugal_bouvines.jpg',
#   'birthDate': '1188-02-23T00:00:00',
#   'birthPlace': '/wiki/Coimbra',
#   'deathDate': '1233-07-27T00:00:00',
#   'deathPlace': '/wiki/Noyon',
#   'spouseList': ['/wiki/Joan,_Countess_of_Flanders'],
#   'house': '/wiki/Portuguese_House_of_Burgundy',
#   'father': '/wiki/Sancho_I_of_Portugal',
#   'mother': '/wiki/Dulce_of_Aragon',
#   'religion': '/wiki/Roman_Catholic_Church'},
#  '/wiki/Afonso_I_of_Portugal': {'id': '/wiki/Afonso_I_of_Portugal',
#   'name': 'Afonso I of Portugal',
#   'title': '/wiki/King_of_Portugal',
#   'picture': '//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/D._Afonso_Henriques_-_Compendio_de_cr%C3%B3nicas_de_reyes_%28Biblioteca_Nacional_de_Espa%C3%B1a%29.png/220px-D._Afonso_Henriques_-_Compendio_de_cr%C3%B3nicas_de_reyes_%28Biblioteca_Nacional_de_Espa%C3%B1a%29.png',
#   'birthDate': '1106-01-01T00:00:00',
#   'birthPlace': '/wiki/Guimar%C3%A3es',
#   'deathDate': '1185-12-06T00:00:00',
#   'deathPlace': '/wiki/Coimbra',
#   'spouseList': ['/wiki/Matilda_of_Savoy,_Queen_of_Portugal'],
#   'issueList': [],
#   'house': '/wiki/Portuguese_House_of_Burgundy',
#   'father': '/wiki/Henry,_Count_of_Portugal',
#   'mother': '/wiki/Theresa,_Countess_of_Portugal',
#   'religion': '/wiki/Catholic'},
#  '/wiki/Otto_II,_Duke_of_Bavaria': {'id': '/wiki/Otto_II,_Duke_of_Bavaria',
#   'name': 'Otto II, Duke of Bavaria',
#   'picture': None,
#   'birthDate': '1206-01-01T00:00:00',
#   'birthPlace': '/wiki/Kelheim',
#   'deathDate': '1253-11-29T00:00:00',
#   'deathPlace': '/wiki/Landshut',
#   'issueList': [],
#   'father': '/wiki/Louis_I,_Duke_of_Bavaria',
#   'mother': '/wiki/Ludmilla_of_Bohemia'},
#  ...}

# %%
missingData = {}
fields = ['birthDate', 'birthPlace', 'deathDate', 'deathPlace']
for personId in data:
    for field in fields:
        if field not in data[personId] or not data[personId][field]:
            personMissing = missingData.get(personId, [])
            personMissing.append(field)
            missingData[personId] = personMissing
missingData
# Out:
# {'/wiki/Charles_the_Younger': ['birthPlace', 'deathPlace'],
#  '/wiki/Pepin_the_Short': ['birthPlace'],
#  '/wiki/Hildegard_of_the_Vinzgau': ['birthPlace'],
#  '/wiki/Gisela,_Abbess_of_Chelles': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Pepin_of_Italy': ['deathPlace'],
#  '/wiki/Luitgard_(Frankish_queen)': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Rotrude_of_Hesbaye': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Grifo_(noble)': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Pepin_of_Herstal': ['birthPlace'],
#  '/wiki/Begga': ['birthPlace', 'deathPlace'],
#  '/wiki/Bernard,_son_of_Charles_Martel': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Gerold_of_Vinzgau': ['birthPlace', 'deathPlace'],
#  '/wiki/Remigius_of_Rouen': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Hieronymus,_son_of_Charles_Martel': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Lothair_I': ['birthPlace'],
#  '/wiki/Desiderata_of_the_Lombards': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Carloman_I': ['birthPlace', 'deathPlace'],
#  '/wiki/Charibert_of_Laon': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Hiltrud': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Alpaida': ['birthPlace', 'deathPlace'],
#  '/wiki/Plectrude': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Himiltrude': ['birthPlace', 'deathPlace'],
#  '/wiki/Ansegisel': ['birthPlace', 'deathPlace'],
#  '/wiki/Desiderius': ['birthPlace', 'deathPlace'],
#  '/wiki/Ermengarde_of_Hesbaye': ['birthPlace'],
#  '/wiki/Louis_the_German': ['birthPlace'],
#  '/wiki/Carloman_(mayor_of_the_palace)': ['birthPlace'],
#  '/wiki/Auda_of_France': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Pepin_I_of_Aquitaine': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Gerberga,_wife_of_Carloman_I': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Ansa,_Queen_of_the_Lombards': ['birthDate',
#   'birthPlace',
#   'deathPlace'],
#  '/wiki/Charles_the_Child': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Rothilde': ['birthPlace', 'deathPlace'],
#  '/wiki/Roger,_Count_of_Maine': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Theodrada': ['birthPlace', 'deathPlace'],
#  '/wiki/Gisela,_daughter_of_Louis_the_Pious': ['birthPlace', 'deathPlace'],
#  '/wiki/Eberhard_of_Friuli': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Ermentrude_of_Orl%C3%A9ans': ['birthPlace', 'deathPlace'],
#  '/wiki/Engeltrude_de_F%C3%A9zensac': ['birthPlace', 'deathPlace'],
#  '/wiki/Lothair_the_Lame': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Louis_the_Stammerer': ['birthPlace'],
#  '/wiki/Carloman,_son_of_Charles_the_Bald': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Ingerman,_Count_of_Hesbaye': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Hemma': ['birthPlace'],
#  '/wiki/Judith_of_Flanders': ['birthPlace', 'deathPlace'],
#  '/wiki/Welf_(father_of_Judith)': ['birthPlace', 'deathPlace'],
#  '/wiki/Judith_of_Bavaria_(died_843)': ['birthPlace'],
#  '/wiki/Odo_I,_Count_of_Orl%C3%A9ans': ['birthDate',
#   'birthPlace',
#   'deathPlace'],
#  '/wiki/Richilde_of_Provence': ['birthPlace', 'deathPlace'],
#  '/wiki/Bivin_of_Gorze': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Leuthard_I_of_Paris': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Rudolph,_Count_of_Ponthieu': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/%C3%86thelwulf,_King_of_Wessex': ['birthDate',
#   'birthPlace',
#   'deathPlace'],
#  '/wiki/Thiedrada': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Conrad_I,_Count_of_Auxerre': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Isambart': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Ecgberht,_King_of_Wessex': ['birthPlace', 'deathPlace'],
#  '/wiki/%C3%86thelberht,_King_of_Wessex': ['birthDate',
#   'birthPlace',
#   'deathPlace'],
#  '/wiki/Adrian,_Count_of_Orl%C3%A9ans': ['birthPlace', 'deathPlace'],
#  '/wiki/Ealhmund_of_Kent': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Alfred_the_Great': ['deathPlace'],
#  '/wiki/%C3%86thelgifu,_Abbess_of_Shaftesbury': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/%C3%86thelstan_of_Kent': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/%C3%86lfthryth,_Countess_of_Flanders': ['birthPlace', 'deathPlace'],
#  '/wiki/%C3%86thelweard_(son_of_Alfred)': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Baldwin_II,_Margrave_of_Flanders': ['birthPlace', 'deathPlace'],
#  '/wiki/%C3%86thelred_I_of_Wessex': ['deathPlace'],
#  '/wiki/Edward_the_Elder': ['birthPlace'],
#  '/wiki/Ealhswith': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Osburh': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Eadgifu_of_Kent': ['birthPlace', 'deathPlace'],
#  '/wiki/%C3%86thelfl%C3%A6d': ['birthPlace'],
#  '/wiki/%C3%86thelswith': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/%C3%86thelwold_%C3%A6theling': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/%C3%86lffl%C3%A6d_(wife_of_Edward_the_Elder)': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Adelolf,_Count_of_Boulogne': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Waldrada_of_Worms': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Eadgyth': ['birthPlace'],
#  '/wiki/Edith_of_Polesworth': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Eadburh_of_Winchester': ['birthPlace', 'deathPlace'],
#  '/wiki/Eadgifu_of_Wessex': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/%C3%86thelred_Mucel': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Ecgwynn': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Edmund_I': ['birthPlace'],
#  '/wiki/%C3%86thelhelm': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/%C3%86thelbald,_King_of_Wessex': ['birthDate',
#   'birthPlace',
#   'deathPlace'],
#  '/wiki/Conrad,_Duke_of_Lorraine': ['birthPlace'],
#  '/wiki/Wulfthryth_of_Wessex': ['deathDate', 'deathPlace'],
#  '/wiki/Charles_the_Simple': ['birthPlace'],
#  '/wiki/Werner_V_(Salian)': ['birthPlace', 'deathPlace'],
#  '/wiki/Eadhild': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Edwin_(son_of_Edward_the_Elder)': ['birthDate',
#   'birthPlace',
#   'deathPlace'],
#  '/wiki/Baldwin_I,_Margrave_of_Flanders': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Edgar,_King_of_England': ['deathPlace'],
#  '/wiki/Arnulf_I,_Count_of_Flanders': ['birthPlace', 'deathPlace'],
#  '/wiki/Henry_the_Fowler': ['deathPlace'],
#  '/wiki/William_(archbishop_of_Mainz)': ['birthPlace', 'deathPlace'],
#  '/wiki/Eadwig': ['birthPlace', 'deathPlace'],
#  '/wiki/Edward_the_Martyr': ['birthPlace'],
#  '/wiki/Frederuna': ['birthPlace', 'deathPlace'],
#  '/wiki/Robert_III,_Count_of_Worms': ['birthPlace', 'deathPlace'],
#  '/wiki/Eadred_%C3%86theling': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Gerberga_of_Saxony': ['birthPlace', 'deathPlace'],
#  '/wiki/Matilda,_Abbess_of_Quedlinburg': ['birthPlace'],
#  '/wiki/Adelaide_of_Paris': ['birthPlace', 'deathPlace'],
#  '/wiki/Edith_of_Wilton': ['birthPlace'],
#  '/wiki/Adelaide_I,_Abbess_of_Quedlinburg': ['birthPlace'],
#  '/wiki/%C3%86lfgifu_of_Shaftesbury': ['birthDate',
#   'birthPlace',
#   'deathPlace'],
#  '/wiki/Hedwig_of_Babenberg': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/%C3%86lfthryth_(wife_of_Edgar)': ['birthPlace', 'deathPlace'],
#  '/wiki/Hatheburg_of_Merseburg': ['birthPlace', 'deathPlace'],
#  '/wiki/Wulfthryth_of_Wilton': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/%C3%86thelwald,_Ealdorman_of_East_Anglia': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Otto_I,_Duke_of_Saxony': ['birthPlace'],
#  '/wiki/Thankmar': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/%C3%86lfgifu_(wife_of_Eadwig)': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Judith,_Duchess_of_Bavaria': ['birthPlace'],
#  '/wiki/Dietrich_of_Ringelheim': ['birthPlace', 'deathPlace'],
#  '/wiki/%C3%86thelstan_%C3%86theling': ['birthDate',
#   'birthPlace',
#   'deathPlace'],
#  '/wiki/Matilda_of_Germany,_Countess_Palatine_of_Lotharingia': ['birthPlace',
#   'deathPlace'],
#  '/wiki/Adalard,_Count_of_Paris': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Main_Page': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Godgifu_(daughter_of_%C3%86thelred_the_Unready)': ['birthPlace',
#   'deathPlace'],
#  '/wiki/Hedwig_of_Saxony': ['birthPlace', 'deathPlace'],
#  '/wiki/Judith_of_S%C3%BClichgau': ['birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Eadwig_%C3%86theling': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Bruno_the_Great': ['birthPlace'],
#  '/wiki/Sophia_I,_Abbess_of_Gandersheim': ['birthPlace'],
#  '/wiki/Phokas_(Byzantine_family)': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Gilbert,_Duke_of_Lorraine': ['birthPlace', 'deathPlace'],
#  '/wiki/Ordgar': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Eberhard_of_S%C3%BClichgau': ['birthPlace', 'deathPlace'],
#  '/wiki/Robert_II,_Count_of_Hesbaye': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Alfred_Aetheling': ['birthPlace', 'deathPlace'],
#  '/wiki/Edith_of_Wessex': ['birthPlace', 'deathPlace'],
#  '/wiki/Skleros': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/%C3%86lfgifu_of_York': ['birthPlace', 'deathPlace'],
#  '/wiki/Liudolf,_Duke_of_Saxony': ['birthPlace', 'deathPlace'],
#  '/wiki/Ealdgyth_(wife_of_Edmund_Ironside)': ['birthPlace', 'deathPlace'],
#  '/wiki/Henry,_Margrave_of_the_Franks': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Maud_of_Normandy': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Hawise_of_Normandy': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Sprota': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Wynflaed': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Mauger,_Count_of_Corbeil': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Gunnor': ['birthPlace', 'deathPlace'],
#  '/wiki/Gunhilda_of_Denmark': ['birthPlace', 'deathPlace'],
#  '/wiki/William_I,_Count_of_Eu': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Dillingen_an_der_Donau': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Gisela_(mother_of_Regelinda)': ['birthPlace', 'deathPlace'],
#  '/wiki/Arnulf,_Duke_of_Bavaria': ['birthDate', 'birthPlace'],
#  '/wiki/Tove_of_the_Obotrites': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Mstivoj': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Robert_II_(archbishop_of_Rouen)': ['birthPlace', 'deathPlace'],
#  '/wiki/Harthacnut': ['birthPlace'],
#  '/wiki/Odo_II,_Count_of_Blois': ['birthPlace'],
#  '/wiki/Adelhard_von_Burc': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Reginar_Longneck': ['birthPlace', 'deathPlace'],
#  '/wiki/Tostig_Godwinson': ['birthPlace'],
#  '/wiki/Wulfnoth_Cild': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Harold_Harefoot': ['birthDate', 'birthPlace'],
#  '/wiki/Wulfnoth_Godwinson': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/%C5%9Awi%C4%99tos%C5%82awa': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Leofwine_Godwinson': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Eric_the_Victorious': ['birthPlace', 'deathPlace'],
#  '/wiki/Svein_Knutsson': ['birthPlace'],
#  '/wiki/Herman_I,_Count_Palatine_of_Lotharingia': ['birthDate',
#   'birthPlace',
#   'deathPlace'],
#  '/wiki/Thored': ['birthPlace', 'deathPlace'],
#  '/wiki/%C3%86lfgifu_of_Northampton': ['birthPlace', 'deathPlace'],
#  '/wiki/Luitpold,_Margrave_of_Bavaria': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Gytha_Thorkelsd%C3%B3ttir': ['birthPlace', 'deathPlace'],
#  '/wiki/Mieszko_I': ['birthPlace'],
#  '/wiki/Bertha_of_Burgundy': ['birthPlace', 'deathPlace'],
#  '/wiki/Geoffrey,_Count_of_Eu': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Emma_of_Paris,_Duchess_of_Normandy': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Beatrice_of_Vermandois': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/%C3%86lfhelm_of_York': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Drogo_of_Mantes': ['birthPlace', 'deathPlace'],
#  '/wiki/Richard_II,_Duke_of_Normandy': ['birthDate', 'birthPlace'],
#  '/wiki/Eleanor_of_Normandy': ['birthPlace', 'deathPlace'],
#  '/wiki/Judith_(daughter_of_Eberhard_of_Friuli)': ['birthPlace', 'deathPlace'],
#  '/wiki/Gyrth_Godwinson': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Matilda_of_France': ['birthPlace', 'deathPlace'],
#  '/wiki/Poppa_of_Bayeux': ['deathDate', 'deathPlace'],
#  '/wiki/Harald_Bluetooth': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Bj%C3%B6rn_Eriksson': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Robert_I_of_France': ['birthPlace'],
#  '/wiki/Thyra': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Cunigunde_of_Swabia': ['birthPlace', 'deathPlace'],
#  '/wiki/Odo_I,_Count_of_Blois': ['birthPlace'],
#  '/wiki/Thorgils_Sprakelegg': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Judith_of_Brittany': ['birthPlace', 'deathPlace'],
#  '/wiki/Theobald_I,_Count_of_Blois': ['birthPlace', 'deathPlace'],
#  '/wiki/Theobald_the_Elder': ['birthPlace', 'deathPlace'],
#  '/wiki/Baldwin_IV,_Count_of_Flanders': ['birthPlace', 'deathPlace'],
#  '/wiki/Herleva': ['deathPlace'],
#  '/wiki/Rudolph_III_of_Burgundy': ['birthPlace', 'deathPlace'],
#  '/wiki/Aelis': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Edith_of_Mercia': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Conan_I_of_Rennes': ['birthDate', 'birthPlace'],
#  '/wiki/Sweyn_Godwinson': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Adelaide_of_Tours': ['birthPlace', 'deathPlace'],
#  '/wiki/Robert_the_Strong': ['birthPlace', 'deathPlace'],
#  '/wiki/Estrid_Svendsdatter': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Harald_II_of_Denmark': ['birthPlace', 'deathPlace'],
#  '/wiki/Luitgarde_of_Vermandois': ['birthPlace', 'deathPlace'],
#  '/wiki/Erenfried_II': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Mauger_(archbishop_of_Rouen)': ['deathPlace'],
#  '/wiki/Herbert_II,_Count_of_Vermandois': ['birthPlace', 'deathPlace'],
#  '/wiki/Gilbert,_Count_of_the_Maasgau': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Hugh_the_Abbot': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Siemomys%C5%82': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Papia_of_Envermeu': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Welf_I': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/William_of_Talou': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Adelaide_of_Normandy': ['birthPlace', 'deathPlace'],
#  '/wiki/Oslac_of_York': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Godwin,_son_of_Harold_Godwinson': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Judith_of_Flanders_(died_1095)': ['deathPlace'],
#  '/wiki/Conrad_I_of_Burgundy': ['birthPlace', 'deathPlace'],
#  '/wiki/Gunhild_of_Wessex': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Herbert_I,_Count_of_Vermandois': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Judicael_Berengar': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Bertha_of_Swabia': ['birthPlace', 'deathPlace'],
#  '/wiki/Doubravka_of_Bohemia': ['birthPlace', 'deathPlace'],
#  '/wiki/Alice_of_Normandy': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Herluin_de_Conteville': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Conrad_II,_Duke_of_Transjurane_Burgundy': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Richard_III,_Duke_of_Normandy': ['birthPlace'],
#  '/wiki/Ulf,_son_of_Harold_Godwinson': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Ermengarde-Gerberga_of_Anjou': ['birthPlace', 'deathPlace'],
#  '/wiki/Odo_of_France': ['birthPlace'],
#  '/wiki/%C3%86lfgar,_Earl_of_Mercia': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Edmund,_son_of_Harold_Godwinson': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Berengar_II_of_Neustria': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Gytha_of_Wessex': ['birthPlace', 'deathPlace'],
#  '/wiki/Harold,_son_of_Harold_Godwinson': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Arnulf_II,_Count_of_Flanders': ['birthPlace'],
#  '/wiki/Edith_the_Fair': ['birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Magnus,_son_of_Harold_Godwinson': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Gorm_the_Old': ['birthPlace', 'deathPlace'],
#  '/wiki/Hugh_of_Tours': ['birthPlace'],
#  '/wiki/Rozala_of_Italy': ['birthPlace'],
#  '/wiki/Burchard_II,_Duke_of_Swabia': ['birthPlace', 'deathPlace'],
#  '/wiki/Baldwin_III,_Count_of_Flanders': ['birthPlace', 'deathPlace'],
#  '/wiki/Robert_fitzEdith': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Enguerrand_II,_Count_of_Ponthieu': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Gerloc': ['birthPlace', 'deathPlace'],
#  '/wiki/Liutgard_of_Saxony_(died_885)': ['birthPlace', 'deathPlace'],
#  '/wiki/Adele_of_Vermandois': ['birthPlace'],
#  '/wiki/Lambert_II,_Count_of_Lens': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Adeliza': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Eberhard_I,_Count_of_Bonngau': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Pepin,_Count_of_Vermandois': ['birthPlace', 'deathPlace'],
#  '/wiki/Knut_Dana%C3%A1st': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Matilda_of_Flanders': ['birthPlace', 'deathPlace'],
#  '/wiki/Lestek': ['birthPlace', 'deathPlace'],
#  '/wiki/Fulk_FitzRoy': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Cunigunda_of_Laon': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Reginald_de_Dunstanville,_Earl_of_Cornwall': ['birthPlace',
#   'deathPlace'],
#  '/wiki/Vladimir_II_Monomakh': ['birthPlace'],
#  '/wiki/Th%C3%A9odrate_of_Troyes': ['birthPlace'],
#  '/wiki/Anastasia_of_Byzantium': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Juliane_de_Fontevrault': ['birthPlace', 'deathPlace'],
#  '/wiki/Gilbert_FitzRoy': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Odo,_Count_of_Champagne': ['birthPlace', 'deathPlace'],
#  '/wiki/Stephen_of_Aumale': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Matilda_of_Saxony,_countess_of_Flanders': ['birthPlace'],
#  '/wiki/Richard_of_Lincoln_(illegitimate_son_of_Henry_I_of_England)': ['birthPlace'],
#  '/wiki/Gisela_of_Burgundy': ['birthPlace'],
#  '/wiki/Alice_FitzRoy': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Regelinda_of_Z%C3%BCrich': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Stephen,_Count_of_Blois': ['birthPlace'],
#  '/wiki/Yuri_Dolgorukiy': ['birthPlace', 'deathPlace'],
#  '/wiki/Harthacnut_I_of_Denmark': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Robert_I,_Count_of_Flanders': ['birthPlace', 'deathPlace'],
#  '/wiki/Hermann_Billung': ['birthPlace'],
#  '/wiki/Boleslaus_I,_Duke_of_Bohemia': ['birthPlace', 'deathPlace'],
#  '/wiki/Frederick_of_Luxembourg': ['birthPlace', 'deathPlace'],
#  '/wiki/Rudolph_II_of_Burgundy': ['birthPlace', 'deathPlace'],
#  '/wiki/Constance_of_Normandy': ['deathPlace'],
#  '/wiki/Valtoke_Gormsson': ['birthPlace'],
#  '/wiki/Adele_of_Meaux': ['birthPlace', 'deathPlace'],
#  '/wiki/Matilda_FitzRoy,_Duchess_of_Brittany': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Herman_of_Ename': ['birthPlace', 'deathPlace'],
#  '/wiki/Godfrey_II,_Duke_of_Lower_Lorraine': ['birthPlace', 'deathPlace'],
#  '/wiki/Louis_the_Younger': ['birthPlace'],
#  '/wiki/Gertrude_of_Flanders,_Duchess_of_Lorraine': ['birthPlace',
#   'deathPlace'],
#  '/wiki/Matilda_FitzRoy,_Countess_of_Perche': ['birthPlace', 'deathPlace'],
#  '/wiki/Geoffrey_I,_Count_of_Anjou': ['birthPlace'],
#  '/wiki/Stephen_II_of_Troyes': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Sigfried,_Count_of_the_Ardennes': ['birthPlace', 'deathPlace'],
#  '/wiki/Wedding': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Euphemia_of_Kiev': ['birthDate', 'deathPlace'],
#  '/wiki/Berengar_II_of_Italy': ['birthPlace'],
#  '/wiki/Biagota': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Henry_FitzRoy_(died_1158)': ['birthPlace'],
#  '/wiki/Matilda_FitzRoy,_Abbess_of_Montivilliers': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Godfrey_I,_Count_of_Verdun': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Gisela_of_Friuli': ['birthPlace', 'deathPlace'],
#  '/wiki/Coloman,_King_of_Hungary': ['birthPlace', 'deathPlace'],
#  '/wiki/Robert,_1st_Earl_of_Gloucester': ['birthPlace', 'deathPlace'],
#  '/wiki/Strut-Harald': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Baldwin_VI,_Count_of_Flanders': ['birthPlace', 'deathPlace'],
#  '/wiki/Henry_II,_Duke_of_Bavaria': ['birthPlace'],
#  '/wiki/Guilla_of_Provence': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Burchard_I,_Duke_of_Swabia': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Rudolph_I_of_Burgundy': ['birthPlace', 'deathPlace'],
#  '/wiki/Asbj%C3%B8rn_T%C3%B3kason': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Fulk_II,_Count_of_Anjou': ['birthPlace'],
#  '/wiki/Adalbert_of_Italy': ['birthPlace'],
#  '/wiki/Adela_of_France': ['birthPlace'],
#  '/wiki/G%C3%A9za_I_of_Hungary': ['deathPlace'],
#  '/wiki/Hedwig_of_Nordgau': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Vsevolod_I_of_Kiev': ['birthPlace'],
#  '/wiki/Eric_Bloodaxe': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Bruno_of_Augsburg': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Drahom%C3%ADra': ['birthPlace', 'deathPlace'],
#  '/wiki/Sigurd_Sleva': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Llywelyn_ap_Seisyll': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Alan_IV,_Duke_of_Brittany': ['birthPlace'],
#  '/wiki/Gerberga,_mother_of_Otto-William': ['birthPlace', 'deathPlace'],
#  '/wiki/Bertila_of_Spoleto': ['birthPlace', 'deathPlace'],
#  '/wiki/Felicia_of_Sicily': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/William_FitzRobert,_2nd_Earl_of_Gloucester': ['birthPlace',
#   'deathPlace'],
#  '/wiki/Frederick,_Count_of_Verdun': ['birthPlace', 'deathPlace'],
#  '/wiki/Oda_of_Metz': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Harald_Greycloak': ['birthPlace'],
#  '/wiki/Gisela_of_Hungary': ['birthPlace'],
#  '/wiki/Yaroslav_the_Wise': ['birthPlace'],
#  '/wiki/Siemowit': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Agiorovna_of_Cumans': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Henry_III,_Count_of_Louvain': ['birthDate', 'birthPlace'],
#  '/wiki/Willa_of_Burgundy': ['birthPlace', 'deathPlace'],
#  '/wiki/Theobald_III,_Count_of_Blois': ['birthPlace', 'deathPlace'],
#  '/wiki/Gothelo_I,_Duke_of_Lorraine': ['birthPlace', 'deathPlace'],
#  '/wiki/Viacheslav_I_of_Kiev': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Gertrude_of_Saxony': ['birthPlace', 'deathPlace'],
#  '/wiki/Guttorm_Eirikssen': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Edward_the_Exile': ['birthPlace'],
#  '/wiki/Sibyl_Corbet': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Fulk_I,_Count_of_Anjou': ['birthPlace'],
#  '/wiki/Edgar_%C3%86theling': ['deathPlace'],
#  '/wiki/Piast_the_Wheelwright': ['birthPlace', 'deathPlace'],
#  '/wiki/Vratislaus_I,_Duke_of_Bohemia': ['birthPlace', 'deathPlace'],
#  '/wiki/Richeza_of_Poland,_Queen_of_Hungary': ['birthPlace', 'deathPlace'],
#  '/wiki/Nest_ferch_Rhys': ['birthPlace', 'deathPlace'],
#  '/wiki/Robert_II,_Count_of_Flanders': ['birthPlace'],
#  '/wiki/Stephen,_Viscount_of_G%C3%A9vaudan': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Rogneda_of_Polotsk': ['birthPlace', 'deathPlace'],
#  '/wiki/Hawise,_Duchess_of_Brittany': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Eufemia_of_Constantinople': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Anastasia_of_Kiev': ['birthPlace'],
#  '/wiki/Cunigunde_of_Luxembourg': ['birthPlace', 'deathPlace'],
#  '/wiki/Adalbert_I_of_Ivrea': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Ho%C3%ABl_II,_Duke_of_Brittany': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Vladimir_of_Novgorod': ['birthPlace'],
#  '/wiki/Sophia_(wife_of_G%C3%A9za_I_of_Hungary)': ['birthPlace', 'deathPlace'],
#  '/wiki/Vyacheslav_Yaroslavich': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Guy_of_Ivrea': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Mieszko_II_Lambert': ['birthPlace'],
#  '/wiki/Rzepicha': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Brian_Fitz_Count': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Ragnhild_the_Mighty': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Malcolm_III_of_Scotland': ['birthDate', 'birthPlace'],
#  '/wiki/Suppo_II': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Ragnhild_Eriksdotter': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Mary_of_Scotland,_Countess_of_Boulogne': ['birthPlace', 'deathPlace'],
#  '/wiki/Erling_Eirikssen': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Gudr%C3%B8d_Eiriksson': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Andrew_I_of_Hungary': ['birthPlace'],
#  '/wiki/William_I_of_Provence': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/William_Longesp%C3%A9e,_3rd_Earl_of_Salisbury': ['birthPlace'],
#  '/wiki/Ingegerd_Olofsdotter_of_Sweden': ['deathPlace'],
#  '/wiki/Sviatoslav_II_of_Kiev': ['birthPlace'],
#  '/wiki/Gerald_de_Windsor': ['birthPlace', 'deathPlace'],
#  '/wiki/Ragnfr%C3%B8d_Eirikssen': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Estrid_of_the_Obotrites': ['birthPlace', 'deathPlace'],
#  '/wiki/Solomon,_King_of_Hungary': ['birthPlace'],
#  '/wiki/Anna_Polovetskaya': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Edgar,_King_of_Scotland': ['birthPlace'],
#  '/wiki/Elisiv_of_Kiev': ['birthPlace', 'deathPlace'],
#  '/wiki/Eleanor_of_Aquitaine': ['deathPlace'],
#  '/wiki/Emmo_of_Loon': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Gleb_Svyatoslavich': ['birthPlace'],
#  '/wiki/Vazul': ['birthPlace', 'deathPlace'],
#  '/wiki/Bo%C5%99ivoj_I,_Duke_of_Bohemia': ['birthPlace', 'deathPlace'],
#  '/wiki/Eustace_III,_Count_of_Boulogne': ['birthPlace', 'deathPlace'],
#  '/wiki/Davyd_Sviatoslavich': ['birthDate', 'birthPlace'],
#  '/wiki/Agatha_(wife_of_Edward_the_Exile)': ['birthPlace'],
#  '/wiki/Bernard_II,_Duke_of_Saxony': ['birthPlace', 'deathPlace'],
#  '/wiki/Eremburga_of_Maine': ['birthPlace', 'deathPlace'],
#  '/wiki/Reginald_I,_Count_of_Burgundy': ['birthPlace', 'deathPlace'],
#  '/wiki/Boso,_Margrave_of_Tuscany': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Judith_of_Swabia': ['deathPlace'],
#  '/wiki/Sigurd_Syr': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Robert_of_Vermandois': ['birthPlace', 'deathPlace'],
#  '/wiki/Gamle_Eirikssen': ['birthPlace', 'deathPlace'],
#  '/wiki/Lambert_of_Chalon': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Sudislav': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Henry_II,_Count_of_Louvain': ['birthPlace', 'deathPlace'],
#  '/wiki/Clementia_of_Burgundy': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Ermentrude_of_Roucy': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/%C3%85sta_Gudbrandsdatter': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/G%C3%A9za,_Grand_Prince_of_the_Hungarians': ['birthPlace',
#   'deathPlace'],
#  '/wiki/Adela_of_Flanders': ['birthPlace', 'deathPlace'],
#  '/wiki/Henry_III,_Holy_Roman_Emperor': ['birthPlace'],
#  '/wiki/Aubry_II_de_M%C3%A2con': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Conrad_of_Ivrea': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Bertrade_of_Montfort': ['birthPlace', 'deathPlace'],
#  '/wiki/Cunigunda_of_France': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Sibylla_of_Conversano': ['birthDate', 'birthPlace'],
#  '/wiki/Roger_Borsa': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/B%C3%A9la_I_of_Hungary': ['birthPlace'],
#  '/wiki/Boris_and_Gleb': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/David_I_of_Scotland': ['birthPlace'],
#  '/wiki/Geoffrey_II,_Duke_of_Brittany': ['birthPlace'],
#  '/wiki/Iziaslav_I_of_Kiev': ['birthPlace'],
#  '/wiki/Arnulf_III,_Count_of_Flanders': ['birthPlace'],
#  '/wiki/Geoffrey_(archbishop_of_York)': ['birthPlace'],
#  '/wiki/Fulk_IV,_Count_of_Anjou': ['birthPlace', 'deathPlace'],
#  '/wiki/Geoffrey_Plantagenet,_Count_of_Anjou': ['birthPlace'],
#  '/wiki/Hevelli': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Malusha': ['deathPlace'],
#  '/wiki/Boles%C5%82aw_I_the_Brave': ['birthPlace', 'deathPlace'],
#  '/wiki/Berengaria_of_Navarre': ['birthPlace', 'deathPlace'],
#  '/wiki/Wigeric_of_Lotharingia': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Eustace_II,_Count_of_Boulogne': ['birthPlace', 'deathPlace'],
#  '/wiki/Ethelred_of_Scotland': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Robert_Fitzhamon': ['birthPlace', 'deathPlace'],
#  '/wiki/Eustace_I,_Count_of_Boulogne': ['birthDate',
#   'birthPlace',
#   'deathPlace'],
#  '/wiki/Philippa,_Countess_of_Toulouse': ['birthPlace'],
#  '/wiki/Ida_de_Tosny': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Otto-William,_Count_of_Burgundy': ['birthPlace', 'deathPlace'],
#  '/wiki/Conan_III,_Duke_of_Brittany': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Edmund_of_Scotland': ['birthPlace', 'deathPlace'],
#  '/wiki/Gozlin,_Count_of_Bidgau_and_Methingau': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Baldwin_II,_Count_of_Hainaut': ['birthPlace'],
#  '/wiki/Igor_Yaroslavich': ['birthPlace'],
#  '/wiki/Eilika_of_Schweinfurt': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Maria_Dobroniega_of_Kiev': ['birthPlace', 'deathPlace'],
#  '/wiki/Cho%C5%9Bcisko': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Iziaslav_of_Polotsk': ['deathPlace'],
#  '/wiki/Bernard_I,_Duke_of_Saxony': ['birthPlace'],
#  '/wiki/Grimelda_of_Hungary': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Wyszes%C5%82awa_of_Kiev': ['birthPlace', 'deathPlace'],
#  '/wiki/Walter_FitzOther': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Anne_of_Kiev': ['birthPlace', 'deathPlace'],
#  '/wiki/Cecilia_Knutsdatter': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Mstislav_of_Chernigov': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Ingelger': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/George,_son_of_Andrew_I_of_Hungary': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Cristina_(daughter_of_Edward_the_Exile)': ['birthDate', 'deathPlace'],
#  '/wiki/Richeza_of_Lotharingia': ['birthPlace'],
#  '/wiki/Adelais_of_Amboise': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Ingibiorg_Finnsdottir': ['birthDate'],
#  '/wiki/Beatrice_I,_Abbess_of_Quedlinburg': ['birthPlace', 'deathPlace'],
#  '/wiki/Emnilda': ['birthPlace'],
#  '/wiki/Sancha_of_Castile,_Queen_of_Navarre': ['birthPlace', 'deathPlace'],
#  '/wiki/David_of_Hungary': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Hostiv%C3%ADt': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Lambert_II,_Count_of_Louvain': ['birthDate', 'birthPlace'],
#  '/wiki/Baldwin_II,_Count_of_Boulogne': ['birthDate',
#   'birthPlace',
#   'deathPlace'],
#  '/wiki/Duncan_II_of_Scotland': ['birthPlace', 'deathPlace'],
#  '/wiki/Beth%C3%B3c': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Oleg_I_of_Chernigov': ['birthPlace', 'deathPlace'],
#  '/wiki/Hamelin_de_Warenne,_Earl_of_Surrey': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Sancho_VI_of_Navarre': ['birthPlace'],
#  '/wiki/Olga_of_Kiev': ['deathPlace'],
#  '/wiki/Conrad_II,_Duke_of_Bavaria': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Olof_Sk%C3%B6tkonung': ['birthPlace', 'deathPlace'],
#  '/wiki/Gertrude_of_Poland': ['birthPlace'],
#  '/wiki/Igor_of_Kiev': ['birthPlace'],
#  '/wiki/Cr%C3%ADn%C3%A1n_of_Dunkeld': ['birthDate',
#   'birthPlace',
#   'deathPlace'],
#  '/wiki/Helena_of_Hungary,_Queen_of_Croatia': ['birthDate',
#   'birthPlace',
#   'deathPlace'],
#  '/wiki/Sarolt': ['birthPlace', 'deathPlace'],
#  '/wiki/Family_life_and_children_of_Vladimir_I': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Adelaide_of_Aquitaine': ['birthPlace', 'deathPlace'],
#  '/wiki/Sigrid_the_Haughty': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Agnes_of_Waiblingen': ['birthPlace'],
#  '/wiki/Paul_and_Erlend_Thorfinnsson': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Eupraxia_of_Kiev': ['birthPlace'],
#  '/wiki/W%C5%82adys%C5%82aw_I_Herman': ['birthPlace'],
#  '/wiki/Frederick_II,_Duke_of_Swabia': ['birthPlace'],
#  '/wiki/Garc%C3%ADa_Ram%C3%ADrez_of_Navarre': ['birthPlace'],
#  '/wiki/Lampert_of_Hungary': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Renaud_of_Roucy': ['birthPlace', 'deathPlace'],
#  '/wiki/Alice_of_France': ['birthPlace', 'deathPlace'],
#  '/wiki/Gerberga_of_Lower_Lorraine': ['birthPlace', 'deathPlace'],
#  '/wiki/Tribal_chief': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Elias_I,_Count_of_Maine': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Henry_the_Young_King': ['birthPlace'],
#  '/wiki/Anund_Jacob': ['birthPlace', 'deathPlace'],
#  '/wiki/Mouzalon': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Henry_II,_Duke_of_Austria': ['birthPlace'],
#  '/wiki/Agnes_of_Poitou': ['birthPlace'],
#  '/wiki/Rurik': ['birthDate', 'birthPlace', 'deathDate'],
#  '/wiki/Conrad_of_Babenberg': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Margaret_of_L%27Aigle': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Louis_VII_of_France': ['birthPlace'],
#  '/wiki/William_II,_Duke_of_Apulia': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Astrid_Olofsdotter_of_Sweden': ['birthDate',
#   'birthPlace',
#   'deathPlace'],
#  '/wiki/Ferdinand_II_of_Le%C3%B3n': ['birthPlace'],
#  '/wiki/Judith_of_Hungary': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Ingegerd_Knutsdatter': ['birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Adelaide_of_Hungary': ['birthPlace', 'deathPlace'],
#  '/wiki/Halfdan_the_Black': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Ragnhild_Sigurdsdotter': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Conrad_III_of_Germany': ['birthPlace'],
#  '/wiki/Sancho_III_of_Castile': ['deathPlace'],
#  '/wiki/Ida_of_Lorraine': ['birthPlace', 'deathPlace'],
#  '/wiki/Roman_Svyatoslavich': ['birthPlace', 'deathPlace'],
#  '/wiki/Demetrius_Zvonimir_of_Croatia': ['birthDate', 'birthPlace'],
#  '/wiki/Gontrodo_P%C3%A9rez': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Gertrude_of_Babenberg,_Duchess_of_Bohemia': ['birthPlace'],
#  '/wiki/Finn_%C3%81rnasson': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Rostislav_Vsevolodovich': ['birthPlace', 'deathPlace'],
#  '/wiki/Canute_IV_of_Denmark': ['birthPlace'],
#  '/wiki/Sophia_of_Hungary': ['birthPlace', 'deathPlace'],
#  '/wiki/Geoffrey_II,_Count_of_G%C3%A2tinais': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Conrad_II,_Duke_of_Swabia': ['birthPlace'],
#  '/wiki/Frederick_IV,_Duke_of_Swabia': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Hamo_Dapifer': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Geoffrey,_Count_of_Conversano': ['birthDate',
#   'birthPlace',
#   'deathPlace'],
#  '/wiki/Euphemia_of_Hungary': ['deathPlace'],
#  '/wiki/William_IV,_Count_of_Toulouse': ['birthPlace', 'deathPlace'],
#  '/wiki/Orlam%C3%BCnde': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Fulk_III,_Count_of_Anjou': ['birthPlace'],
#  '/wiki/Gilbert_of_Roucy': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Leopold,_Duke_of_Bavaria': ['birthPlace'],
#  '/wiki/Richilde,_Countess_of_Hainaut': ['birthPlace'],
#  '/wiki/Margaret_of_France,_Queen_of_England_and_Hungary': ['birthPlace'],
#  '/wiki/Bertha_of_Savoy': ['birthPlace'],
#  '/wiki/Margaret_of_Navarre': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Edmund,_2nd_Earl_of_Cornwall': ['deathPlace'],
#  '/wiki/Gisela_of_Swabia': ['birthPlace'],
#  '/wiki/Maud,_Countess_of_Huntingdon': ['birthPlace'],
#  '/wiki/Otto_I,_Count_of_Burgundy': ['birthPlace', 'deathPlace'],
#  '/wiki/Constance,_Duchess_of_Brittany': ['birthPlace'],
#  '/wiki/Adelaide_of_Rheinfelden': ['birthPlace', 'deathPlace'],
#  '/wiki/Richard_FitzRoy': ['birthPlace', 'deathPlace'],
#  '/wiki/%C5%9Awi%C4%99tos%C5%82awa_of_Poland': ['birthPlace'],
#  '/wiki/Ethelreda_(daughter_of_Gospatric)': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Agnes_of_Burgundy,_Duchess_of_Aquitaine': ['birthDate', 'deathPlace'],
#  '/wiki/Henry_of_Speyer': ['birthPlace', 'deathPlace'],
#  '/wiki/Gyula_II': ['birthDate', 'deathDate'],
#  '/wiki/Conrad,_Count_Palatine_of_the_Rhine': ['birthPlace', 'deathPlace'],
#  '/wiki/Agnes_of_Babenberg': ['birthPlace'],
#  '/wiki/John_II,_Duke_of_Brittany': ['birthPlace'],
#  '/wiki/Joan_of_England,_Queen_of_Scotland': ['birthPlace'],
#  '/wiki/Gilbert_of_L%27Aigle': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Almodis_of_La_Marche': ['birthPlace', 'deathPlace'],
#  '/wiki/Frederick_I,_Duke_of_Swabia': ['birthPlace', 'deathPlace'],
#  '/wiki/Judith_of_Babenberg': ['birthPlace', 'deathPlace'],
#  '/wiki/Sancha_of_Castile,_Queen_of_Aragon': ['birthPlace'],
#  '/wiki/Alix,_Duchess_of_Brittany': ['deathPlace'],
#  '/wiki/Margaret_of_Huntingdon,_Duchess_of_Brittany': ['birthPlace',
#   'deathPlace'],
#  '/wiki/Isabella_of_Angoul%C3%AAme': ['birthPlace'],
#  '/wiki/Frederick_V,_Duke_of_Swabia': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Adelaide_of_Savoy,_Duchess_of_Swabia': ['birthPlace', 'deathPlace'],
#  '/wiki/Richeza_of_Berg': ['birthPlace', 'deathPlace'],
#  '/wiki/Ramon_Berenguer_IV,_Count_of_Provence': ['birthPlace'],
#  '/wiki/Blanca_of_Navarre,_Queen_of_Castile': ['deathPlace'],
#  '/wiki/Judith_of_Bavaria,_Duchess_of_Swabia': ['deathDate', 'deathPlace'],
#  '/wiki/Constance_of_B%C3%A9arn': ['birthPlace', 'deathPlace'],
#  '/wiki/Adelaide_of_Maurienne': ['deathPlace'],
#  '/wiki/Aymer,_Count_of_Angoul%C3%AAme': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Edla': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Guigues_I_of_Albon': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Catherine_of_Thouars': ['birthPlace', 'deathPlace'],
#  '/wiki/Peter_I,_Duke_of_Brittany': ['birthPlace', 'deathPlace'],
#  '/wiki/Bretislav_II': ['birthPlace', 'deathPlace'],
#  '/wiki/Henry_IX,_Duke_of_Bavaria': ['birthPlace'],
#  '/wiki/Tancred_of_Hauteville': ['birthPlace', 'deathPlace'],
#  '/wiki/Maria_of_Bohemia': ['birthPlace', 'deathPlace'],
#  '/wiki/Rohese_de_Dover': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Henry_Berengar': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Michael_of_Hungary': ['birthPlace', 'deathPlace'],
#  '/wiki/Judith_of_Hohenstaufen': ['birthPlace', 'deathPlace'],
#  '/wiki/Simon_I_de_Senlis,_Earl_of_Huntingdon-Northampton': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Aimery_I,_Viscount_of_Ch%C3%A2tellerault': ['birthPlace'],
#  '/wiki/Emund_the_Old': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Dangereuse_de_l%27Isle_Bouchard': ['birthPlace', 'deathPlace'],
#  '/wiki/Berthold_I,_Duke_of_Swabia': ['birthPlace', 'deathPlace'],
#  '/wiki/Gospatric,_Earl_of_Northumbria': ['birthDate',
#   'birthPlace',
#   'deathPlace'],
#  '/wiki/Simon_I_de_Montfort': ['deathPlace'],
#  '/wiki/Otto_I_of_Olomouc': ['birthPlace', 'deathPlace'],
#  '/wiki/William_IX,_Duke_of_Aquitaine': ['birthPlace', 'deathPlace'],
#  '/wiki/Gudr%C3%B8d_the_Hunter': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Isabella_of_Lusignan': ['birthPlace', 'deathPlace'],
#  '/wiki/Bertha_of_Rheinfelden': ['birthPlace', 'deathPlace'],
#  '/wiki/Blanche_of_Brittany': ['birthPlace', 'deathPlace'],
#  '/wiki/Thorfinn_the_Mighty': ['birthPlace', 'deathPlace'],
#  '/wiki/Jean_de_la_Fl%C3%A8che': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Ulf_Jarl': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Otto_of_Freising': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Henry_I,_Count_of_Champagne': ['birthPlace'],
#  '/wiki/Henry_I,_Count_of_Berg': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Otto,_Count_of_Savoy': ['birthPlace', 'deathPlace'],
#  '/wiki/Arnulf_III,_Count_of_Boulogne': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Matilda_of_Carinthia': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Simon_de_Montfort_the_Younger': ['birthPlace', 'deathPlace'],
#  '/wiki/Douce_I,_Countess_of_Provence': ['birthPlace', 'deathPlace'],
#  '/wiki/Taksony_of_Hungary': ['birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Mieszko_Kazimierzowic': ['birthPlace', 'deathPlace'],
#  '/wiki/Margaret_of_Artois': ['birthPlace', 'deathPlace'],
#  '/wiki/Edmund_Crouchback': ['birthPlace'],
#  '/wiki/Skoglar_Toste': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Arthur_II,_Duke_of_Brittany': ['birthPlace', 'deathPlace'],
#  '/wiki/Meldred': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Ansel_Marshal': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Joan_of_%C3%89vreux': ['birthPlace'],
#  '/wiki/William_de_Valence,_1st_Earl_of_Pembroke': ['birthPlace',
#   'deathPlace'],
#  '/wiki/Eleanor_of_Brittany_(abbess)': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Henry_of_Scotland': ['birthPlace'],
#  '/wiki/Henry_I_the_Long,_Margrave_of_the_Nordmark': ['birthPlace',
#   'deathPlace'],
#  '/wiki/Sob%C4%9Bslav_I,_Duke_of_Bohemia': ['birthPlace', 'deathPlace'],
#  '/wiki/Garsenda,_Countess_of_Forcalquier': ['birthPlace', 'deathPlace'],
#  '/wiki/Brun_I,_Count_of_Brunswick': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Theobald_V,_Count_of_Blois': ['birthPlace'],
#  '/wiki/Emma_of_Anjou': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Malcolm_II_of_Scotland': ['birthPlace'],
#  '/wiki/William_the_Lion': ['birthPlace'],
#  '/wiki/John_I,_Duke_of_Brittany': ['birthPlace', 'deathPlace'],
#  '/wiki/Robert_II,_Count_of_Dreux': ['birthPlace', 'deathPlace'],
#  '/wiki/Amaury_I_de_Montfort': ['birthPlace', 'deathPlace'],
#  '/wiki/Brunon_de_Roucy': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Adelina_of_Holland': ['birthPlace', 'deathPlace'],
#  '/wiki/Guillaume_de_Montfort_(bishop_of_Paris)': ['birthPlace', 'deathPlace'],
#  '/wiki/Henry,_Count_of_Montescaglioso': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Charles_d%27%C3%89vreux': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Gyda_of_Sweden': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Alice_of_Courtenay': ['birthPlace', 'deathPlace'],
#  '/wiki/William_I_of_Sicily': ['deathPlace'],
#  '/wiki/Cristina_Rodr%C3%ADguez_(noble)': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Otto_IV,_Holy_Roman_Emperor': ['birthPlace'],
#  '/wiki/Gilbert_Marshal,_4th_Earl_of_Pembroke': ['birthPlace', 'deathPlace'],
#  '/wiki/Lukarta_of_Bogen': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Constance_of_Castile': ['birthPlace', 'deathPlace'],
#  '/wiki/Bertha,_Duchess_of_Lorraine': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Sigurd_the_Stout': ['birthDate', 'birthPlace'],
#  '/wiki/Robert_III_of_Artois': ['birthPlace', 'deathPlace'],
#  '/wiki/Adelaide_of_Vohburg': ['birthPlace'],
#  '/wiki/Gertrude_of_Comburg': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Frederick_of_B%C3%BCren': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Gertrude_of_S%C3%BCpplingenburg': ['birthPlace', 'deathPlace'],
#  '/wiki/Joan,_Lady_of_Wales': ['birthPlace', 'deathPlace'],
#  '/wiki/Agnes_of_France,_Byzantine_Empress': ['birthPlace', 'deathPlace'],
#  '/wiki/David,_Earl_of_Huntingdon': ['birthPlace', 'deathPlace'],
#  '/wiki/Blanche_of_Navarre,_Duchess_of_Brittany': ['birthPlace'],
#  '/wiki/Agnes_of_Rheinfelden': ['birthPlace', 'deathPlace'],
#  '/wiki/Ramiro_S%C3%A1nchez': ['birthPlace', 'deathPlace'],
#  '/wiki/Lutgardis_of_Luxemburg': ['birthPlace', 'deathPlace'],
#  '/wiki/Eleanor,_Fair_Maid_of_Brittany': ['birthPlace'],
#  '/wiki/Herman_II,_Duke_of_Swabia': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Alys_of_France,_Countess_of_Vexin': ['birthPlace', 'deathPlace'],
#  '/wiki/Louis_VIII_of_France': ['birthPlace'],
#  '/wiki/Yolande_of_Dreux,_Queen_of_Scotland': ['birthPlace', 'deathPlace'],
#  '/wiki/Peter_of_Barcelona': ['birthPlace', 'deathPlace'],
#  '/wiki/Aymer_de_Valence_(bishop)': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Adelaide_of_Susa': ['deathPlace'],
#  '/wiki/Gertrude_of_Bavaria': ['birthPlace', 'deathPlace'],
#  '/wiki/Matilda_of_Swabia': ['birthPlace', 'deathPlace'],
#  '/wiki/Agnes_de_Baudemont,_Countess_of_Braine': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Hlodvir_Thorfinnsson': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Ulric_Manfred_II_of_Turin': ['birthDate', 'birthPlace'],
#  '/wiki/Agnes_of_Aquitaine,_wife_of_Ramiro_II_of_Aragon': ['birthDate',
#   'birthPlace',
#   'deathPlace'],
#  '/wiki/Louis,_Count_of_%C3%89vreux': ['birthPlace'],
#  '/wiki/%C3%85sa_Haraldsdottir_of_Agder': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Teresa_Fern%C3%A1ndez_de_Traba': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/William_V,_Duke_of_Aquitaine': ['birthPlace', 'deathPlace'],
#  '/wiki/Ramon_Berenguer_III,_Count_of_Provence': ['birthPlace'],
#  '/wiki/Beatrice_I,_Countess_of_Burgundy': ['birthPlace'],
#  '/wiki/Guy_of_Thouars': ['birthDate', 'birthPlace'],
#  '/wiki/Hugh_X_of_Lusignan': ['birthPlace', 'deathPlace'],
#  '/wiki/Vladislaus_I': ['birthPlace', 'deathPlace'],
#  '/wiki/Hugh_XI_of_Lusignan': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Gisela_of_Burgundy,_Marchioness_of_Montferrat': ['birthPlace',
#   'deathPlace'],
#  '/wiki/Stephanie_Alfonso_of_Castile': ['birthPlace', 'deathPlace'],
#  '/wiki/Hermann_I,_Landgrave_of_Thuringia': ['birthPlace'],
#  '/wiki/Lothair_Udo_II,_Margrave_of_the_Nordmark': ['birthPlace',
#   'deathPlace'],
#  '/wiki/Henry_de_Montfort': ['birthPlace'],
#  '/wiki/Matilda_of_Frisia': ['birthDate', 'birthPlace'],
#  '/wiki/Louis_VI_of_France': ['birthPlace'],
#  '/wiki/Olaf_I_of_Denmark': ['birthPlace', 'deathPlace'],
#  '/wiki/Marie_of_Brittany,_Countess_of_Saint-Pol': ['birthPlace',
#   'deathPlace'],
#  '/wiki/Guy_de_Penthi%C3%A8vre': ['birthPlace', 'deathPlace'],
#  '/wiki/Theobald_II,_Count_of_Champagne': ['birthPlace', 'deathPlace'],
#  '/wiki/Rudolf_of_Rheinfelden': ['birthPlace'],
#  '/wiki/Prangarda_of_Canossa': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Hugh_IX_of_Lusignan': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Andrew_III,_Baron_of_Vitr%C3%A9': ['birthPlace', 'deathPlace'],
#  '/wiki/Simon_II_de_Montfort': ['birthPlace', 'deathPlace'],
#  '/wiki/Arthur_I,_Duke_of_Brittany': ['deathPlace'],
#  '/wiki/Ermengarde_de_Beaumont': ['birthPlace'],
#  '/wiki/Emma_of_Blois': ['birthPlace', 'deathPlace'],
#  '/wiki/Sancho,_Count_of_Provence': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Harald_Grenske': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Martha,_Viscountess_of_Marsan': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Matilda_of_Chester,_Countess_of_Huntingdon': ['birthPlace',
#   'deathPlace'],
#  '/wiki/Richeza_of_Poland,_Queen_of_Castile': ['birthPlace', 'deathPlace'],
#  '/wiki/Pons,_Count_of_Toulouse': ['birthPlace'],
#  '/wiki/Sancho_Alf%C3%B3nsez': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Henry_Raspe': ['birthPlace'],
#  '/wiki/Bartholomew_de_L%27Isle_Bouchard': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/William_VIII,_Duke_of_Aquitaine': ['birthPlace'],
#  '/wiki/Maud_Marshal': ['birthPlace', 'deathPlace'],
#  '/wiki/Henry_V,_Count_Palatine_of_the_Rhine': ['birthPlace'],
#  '/wiki/Herman_III,_Duke_of_Swabia': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Aoife_MacMurrough': ['birthPlace', 'deathPlace'],
#  '/wiki/Fernando_Rodr%C3%ADguez_de_Castro': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Gunnhildr_Sveinsd%C3%B3ttir': ['birthDate', 'birthPlace'],
#  '/wiki/Humbert_II,_Count_of_Savoy': ['birthPlace', 'deathPlace'],
#  '/wiki/Louis_II,_Landgrave_of_Thuringia': ['birthPlace'],
#  '/wiki/William_I,_Count_of_Burgundy': ['birthPlace'],
#  '/wiki/Harald_Hen': ['birthPlace', 'deathPlace'],
#  '/wiki/John_III,_Duke_of_Brittany': ['birthPlace'],
#  '/wiki/Jutta_of_Thuringia': ['birthPlace'],
#  '/wiki/Conan_IV,_Duke_of_Brittany': ['birthPlace', 'deathPlace'],
#  '/wiki/Ada_de_Warenne': ['birthPlace', 'deathPlace'],
#  '/wiki/Rudolf_I,_Count_of_Bregenz': ['birthPlace', 'deathPlace'],
#  '/wiki/Marie_of_Artois': ['birthPlace', 'deathPlace'],
#  '/wiki/Wulfhilde_of_Saxony': ['birthPlace'],
#  '/wiki/Beatrice_of_Rethel': ['birthPlace', 'deathPlace'],
#  '/wiki/Agnes_of_the_Palatinate': ['birthPlace', 'deathPlace'],
#  '/wiki/Margaret_of_England,_Duchess_of_Brabant': ['deathPlace'],
#  '/wiki/Otto_I,_Duke_of_Carinthia': ['birthPlace', 'deathPlace'],
#  '/wiki/Menumorut': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Reginald_III,_Count_of_Burgundy': ['birthPlace', 'deathPlace'],
#  '/wiki/Gaston_II,_Count_of_Foix': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Sancha_of_Aragon,_Countess_of_Toulouse': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Margareta_Hasbj%C3%B6rnsdatter': ['birthPlace', 'deathPlace'],
#  '/wiki/Maud_of_Apulia': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Louis_I,_Landgrave_of_Thuringia': ['birthDate',
#   'birthPlace',
#   'deathPlace'],
#  '/wiki/Aveline_de_Forz,_Countess_of_Aumale': ['birthPlace', 'deathPlace'],
#  '/wiki/Robert_I,_Count_of_Dreux': ['birthPlace'],
#  '/wiki/Roger_III_of_Sicily': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Sweyn_Haakonsson': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Judith_of_Schweinfurt': ['birthPlace', 'deathPlace'],
#  '/wiki/Waltheof,_Earl_of_Northumbria': ['birthDate', 'birthPlace'],
#  '/wiki/John_of_Brittany,_Earl_of_Richmond': ['birthPlace'],
#  '/wiki/Gerberga_of_Gleiberg': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Countess_Palatine_Irmengard_of_the_Rhine': ['birthPlace',
#   'deathPlace'],
#  '/wiki/Blanche_of_Burgundy': ['birthPlace', 'deathPlace'],
#  '/wiki/Louis_the_Springer': ['birthPlace', 'deathPlace'],
#  '/wiki/Adelaide_of_Hungary_(d._1140)': ['birthPlace', 'deathPlace'],
#  '/wiki/Enzo_of_Sardinia': ['birthPlace', 'deathPlace'],
#  '/wiki/Henry,_Prince_of_Capua': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Ferdinand_of_Castile_(died_1211)': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Eleanor_of_Castile_(died_1244)': ['birthPlace'],
#  '/wiki/Svend_Tronkr%C3%A6ver': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Philip_of_Artois': ['birthPlace', 'deathPlace'],
#  '/wiki/Sancho_I_of_Portugal': ['deathPlace'],
#  '/wiki/Berengaria_of_Le%C3%B3n': ['birthPlace'],
#  '/wiki/Hedwig_of_Gudensberg': ['birthPlace', 'deathPlace'],
#  '/wiki/Judith_d%27%C3%89vreux': ['birthDate', 'birthPlace'],
#  '/wiki/Reginar_III,_Count_of_Hainaut': ['birthDate'],
#  '/wiki/Sweyn_the_Crusader': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Isaac_II_Angelos': ['birthPlace'],
#  '/wiki/Kenneth_II_of_Scotland': ['birthDate', 'birthPlace'],
#  '/wiki/Kunigunde_of_Bilstein': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Amaury_de_Montfort_(priest)': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/M%C3%B3r_N%C3%AD_Tuathail': ['deathPlace'],
#  '/wiki/Peter_I,_Count_of_Savoy': ['birthPlace', 'deathPlace'],
#  '/wiki/Robert_(son_of_William_I_of_Sicily)': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Marie_of_%C3%89vreux': ['birthPlace', 'deathPlace'],
#  '/wiki/Louis_III,_Landgrave_of_Thuringia': ['birthPlace'],
#  '/wiki/Richenza_of_Northeim': ['birthPlace', 'deathPlace'],
#  '/wiki/Philip_of_France_(1116%E2%80%931131)': ['birthPlace'],
#  '/wiki/Elizabeth_of_Vermandois,_Countess_of_Leicester': ['birthPlace',
#   'deathPlace'],
#  '/wiki/Conrad_of_Thuringia': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Sigrid_Svendsdatter': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Oda_von_Werl': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Zolt%C3%A1n_of_Hungary': ['birthPlace', 'deathPlace'],
#  '/wiki/Engelbert,_Duke_of_Carinthia': ['birthDate', 'birthPlace'],
#  '/wiki/Blanche_of_Navarre,_Countess_of_Champagne': ['birthPlace',
#   'deathPlace'],
#  '/wiki/Garsenda_I_of_Forcalquier': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Philip_of_Castile': ['birthPlace', 'deathPlace'],
#  '/wiki/Humbert_I,_Count_of_Savoy': ['birthPlace'],
#  '/wiki/Ingerid_of_Denmark': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Andrew_II,_Baron_of_Vitr%C3%A9': ['birthPlace', 'deathPlace'],
#  '/wiki/Bertha_of_Milan': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Joan_of_Brittany,_Baroness_of_Drayton': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Kunigunde_of_Altdorf': ['birthPlace', 'deathPlace'],
#  '/wiki/Guy_de_Montfort,_Count_of_Nola': ['birthPlace', 'deathPlace'],
#  '/wiki/Philip_I,_Count_of_Boulogne': ['birthPlace', 'deathPlace'],
#  '/wiki/Gaston_VII,_Viscount_of_B%C3%A9arn': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Gottschalk_(Obotrite_prince)': ['birthDate',
#   'birthPlace',
#   'deathPlace'],
#  '/wiki/Richard_de_Montfort': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Rainou_of_Sabran': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Alix_of_Brittany,_Dame_de_Pontarcy': ['deathPlace'],
#  '/wiki/Ramon_Berenguer_II,_Count_of_Barcelona': ['birthPlace'],
#  '/wiki/Sancha_of_Le%C3%B3n': ['birthPlace', 'deathPlace'],
#  '/wiki/Astrid_Njalsdotter': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/Constance_of_Burgundy': ['birthPlace', 'deathPlace'],
#  '/wiki/Eva_Marshal': ['deathPlace'],
#  '/wiki/Amaury_III_de_Montfort': ['birthDate', 'birthPlace', 'deathPlace'],
#  '/wiki/Manfred_I_of_Turin': ['birthDate',
#   'birthPlace',
#   'deathDate',
#   'deathPlace'],
#  '/wiki/William_IV,_Duke_of_Aquitaine': ['birthPlace', 'deathPlace'],
#  '/wiki/10)': ['birthDate', 'birthPlace', 'deathDate', 'deathPlace'],
#  '/wiki/Ebalus,_Duke_of_Aquitaine': ['birthPlace', 'deathPlace'],
#  '/wiki/Baldwin_V,_Count_of_Hainaut': ['birthPlace', 'deathPlace'],
#  '/wiki/Mahaut_of_Albon': ['birthPlace', 'deathPlace'],
#  '/wiki/Rudolf_I,_Margrave_of_the_Nordmark': ['birthDate',
#   'birthPlace',
#   'deathPlace']}

# %%
def loadInfoBox(wiki_url):
    soup = utils.getWikiPage(wiki_url)
    return soup.find("table", class_="infobox")
loadInfoBox('/wiki/Charlemagne')
# Out:
# <table class="infobox vcard"><tbody><tr><th class="infobox-above fn" colspan="2" style="background-color: #cbe; font-size: 125%">Charlemagne</th></tr><tr><td class="infobox-subheader" colspan="2"><i><a href="/wiki/Holy_Roman_Emperor" title="Holy Roman Emperor">Emperor of the Romans</a></i></td></tr><tr><td class="infobox-image photo" colspan="2"><a class="image" href="/wiki/File:Charlemagne_denier_Mayence_812_814.jpg"><img alt="Charlemagne denier Mayence 812 814.jpg" data-file-height="587" data-file-width="559" decoding="async" height="236" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fb/Charlemagne_denier_Mayence_812_814.jpg/225px-Charlemagne_denier_Mayence_812_814.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fb/Charlemagne_denier_Mayence_812_814.jpg/338px-Charlemagne_denier_Mayence_812_814.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fb/Charlemagne_denier_Mayence_812_814.jpg/450px-Charlemagne_denier_Mayence_812_814.jpg 2x" width="225"/></a><div class="infobox-caption" style="line-height:normal;padding-bottom:0.2em;padding-top:0.2em;">A <a href="/wiki/Denarius" title="Denarius">denarius</a> of Charlemagne dated <abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 812–814</span> with the inscription <span class="square-capitals" lang="la" style="font-family: Cardo, 'Everson Mono', 'GNU Unifont', Junicode; text-transform: uppercase; font-size: 73%;">KAROLVS IMP AVG</span><br/>(<i>Karolus Imperator Augustus</i>)</div></td></tr><tr><th class="infobox-header" colspan="2" style="background-color: #e4dcf6;line-height:normal;padding:0.2em 0.2em"><a class="mw-redirect" href="/wiki/King_of_the_Franks" title="King of the Franks">King of the Franks</a></th></tr><tr><th class="infobox-label" scope="row">Reign</th><td class="infobox-data">9 October 768 – 28 January 814</td></tr><tr><th class="infobox-label" scope="row"><a href="/wiki/Coronation" title="Coronation">Coronation</a></th><td class="infobox-data">9 October 768<br/><a href="/wiki/Noyon" title="Noyon">Noyon</a></td></tr><tr><th class="infobox-label" scope="row">Predecessor</th><td class="infobox-data"><a href="/wiki/Pepin_the_Short" title="Pepin the Short">Pepin the Short</a></td></tr><tr><th class="infobox-label" scope="row">Successor</th><td class="infobox-data"><a href="/wiki/Louis_the_Pious" title="Louis the Pious">Louis the Pious</a></td></tr><tr><th class="infobox-header" colspan="2" style="background-color: #e4dcf6;line-height:normal;padding:0.2em 0.2em"><a class="mw-redirect" href="/wiki/King_of_the_Lombards" title="King of the Lombards">King of the Lombards</a></th></tr><tr><th class="infobox-label" scope="row">Reign</th><td class="infobox-data">10 July 774 – 28 January 814</td></tr><tr><th class="infobox-label" scope="row">Coronation</th><td class="infobox-data">10 July 774<br/><a href="/wiki/Pavia" title="Pavia">Pavia</a></td></tr><tr><th class="infobox-label" scope="row">Predecessor</th><td class="infobox-data"><a href="/wiki/Desiderius" title="Desiderius">Desiderius</a></td></tr><tr><th class="infobox-label" scope="row">Successor</th><td class="infobox-data"><a href="/wiki/Bernard_of_Italy" title="Bernard of Italy">Bernard</a></td></tr><tr><th class="infobox-header" colspan="2" style="background-color: #e4dcf6;line-height:normal;padding:0.2em 0.2em"><a href="/wiki/Holy_Roman_Emperor" title="Holy Roman Emperor">Emperor</a> of the <a href="/wiki/Carolingian_Empire" title="Carolingian Empire">Carolingian Empire</a></th></tr><tr><th class="infobox-label" scope="row">Reign</th><td class="infobox-data">25 December 800 – 28 January 814</td></tr><tr><th class="infobox-label" scope="row">Coronation</th><td class="infobox-data">25 December 800<br/><a href="/wiki/Old_St._Peter%27s_Basilica" title="Old St. Peter's Basilica">Old St. Peter's Basilica</a>, Rome</td></tr><tr><th class="infobox-label" scope="row">Successor</th><td class="infobox-data"><a href="/wiki/Louis_the_Pious" title="Louis the Pious">Louis the Pious</a></td></tr ...
# <ul><li><div style="display: inline-block; line-height: 1.2em; padding: .1em 0;"><a href="/wiki/Desiderata_of_the_Lombards" title="Desiderata of the Lombards">Desiderata</a><br/>(m. <abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 770</span>; annulled 771)</div></li>
# <li><div style="display: inline-block; line-height: 1.2em; padding: .1em 0;"><a class="mw-redirect" href="/wiki/Hildegard_of_Vinzgouw" title="Hildegard of Vinzgouw">Hildegard of Vinzgouw</a><br/>(m. 771; d. 783)</div></li>
# <li><div style="display: inline-block; line-height: 1.2em; padding: .1em 0;"><a href="/wiki/Fastrada" title="Fastrada">Fastrada</a><br/>(m. <abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 783</span>; d. 794)</div></li>
# <li><div style="display: inline-block; line-height: 1.2em; padding: .1em 0;"><a href="/wiki/Luitgard_(Frankish_queen)" title="Luitgard (Frankish queen)">Luitgard</a><br/>(m. <abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 794</span>; d. 800)</div></li></ul>
# </div></td></tr><tr><th class="infobox-label" scope="row"><a href="/wiki/Issue_(genealogy)" title="Issue (genealogy)">Issue</a><br/><span style="font-weight:normal"><i><a href="#Wives,_concubines,_and_children">Among others</a></i></span></th><td class="infobox-data"><link href="mw-data:TemplateStyles:r1126788409" rel="mw-deduplicated-inline-style"/><div class="plainlist">
# <ul><li><a href="/wiki/Pepin_the_Hunchback" title="Pepin the Hunchback">Pepin the Hunchback</a></li>
# <li><a href="/wiki/Charles_the_Younger" title="Charles the Younger">Charles the Younger</a></li>
# <li><a href="/wiki/Pepin_of_Italy" title="Pepin of Italy">Pepin of Italy</a></li>
# <li><a href="/wiki/Louis_the_Pious" title="Louis the Pious">Louis the Pious</a></li></ul>
# </div></td></tr><tr><th class="infobox-label" scope="row"><a href="/wiki/Dynasty" title="Dynasty">Dynasty</a></th><td class="infobox-data"><a href="/wiki/Carolingian_dynasty" title="Carolingian dynasty">Carolingian</a></td></tr><tr><th class="infobox-label" scope="row">Father</th><td class="infobox-data"><a href="/wiki/Pepin_the_Short" title="Pepin the Short">Pepin the Short</a></td></tr><tr><th class="infobox-label" scope="row">Mother</th><td class="infobox-data"><a href="/wiki/Bertrada_of_Laon" title="Bertrada of Laon">Bertrada of Laon</a></td></tr><tr><th class="infobox-label" scope="row">Religion</th><td class="infobox-data"><a href="/wiki/Chalcedonian_Christianity" title="Chalcedonian Christianity">Chalcedonian Christianity</a></td></tr><tr><th class="infobox-label" scope="row"><a href="/wiki/Signum_manus" title="Signum manus">Signum manus</a></th><td class="infobox-data"><a class="image" href="/wiki/File:Karldergrossesignatur.svg" title="Charlemagne's signature"><img alt="Charlemagne's signature" class="notpageimage" data-file-height="225" data-file-width="624" decoding="async" height="45" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a5/Karldergrossesignatur.svg/125px-Karldergrossesignatur.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/a5/Karldergrossesignatur.svg/188px-Karldergrossesignatur.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/a5/Karldergrossesignatur.svg/250px-Karldergrossesignatur.svg.png 2x" width="125"/></a></td></tr></tbody></table>

# %%
missingBirthDate = []
missingBirthPlace = []
missingDeathDate = []
missingDeathPlace = []
for personId in missingData:
    infobox = loadInfoBox(personId)
    if infobox:
        if 'birthDate' in missingData[personId]:
            dateRow = infobox.find("th", text="Born").parent if infobox.find("th", text="Born") else None
            if dateRow:
                missingBirthDate.append(personId)
        if 'birthPlace' in missingData[personId]:
            dateRow = infobox.find("th", text="Born").parent if infobox.find("th", text="Born") else None
            if dateRow:
                missingBirthPlace.append(personId)
        if 'deathDate' in missingData[personId]:
            dateRow = infobox.find("th", text="Died").parent if infobox.find("th", text="Died") else None
            if dateRow:
                missingDeathDate.append(personId)
        if 'deathPlace' in missingData[personId]:
            dateRow = infobox.find("th", text="Died").parent if infobox.find("th", text="Died") else None
            if dateRow:
                missingDeathPlace.append(personId)

# %%
print(missingBirthDate)
print(missingBirthPlace)
print(missingDeathDate)
print(missingDeathPlace)
# Out:
# ['/wiki/Edith_of_Polesworth', '/wiki/Eadhild', '/wiki/%C3%86thelstan_%C3%86theling', '/wiki/Tove_of_the_Obotrites', '/wiki/Euphemia_of_Kiev', '/wiki/Davyd_Sviatoslavich', '/wiki/Boris_and_Gleb', '/wiki/Cristina_(daughter_of_Edward_the_Exile)', '/wiki/Ingibiorg_Finnsdottir', '/wiki/Agnes_of_Burgundy,_Duchess_of_Aquitaine', '/wiki/Gyula_II', '/wiki/Gunnhildr_Sveinsd%C3%B3ttir', '/wiki/Louis_I,_Landgrave_of_Thuringia', '/wiki/Judith_d%27%C3%89vreux', '/wiki/Reginar_III,_Count_of_Hainaut', '/wiki/Gottschalk_(Obotrite_prince)']
# ['/wiki/Charles_the_Younger', '/wiki/Pepin_the_Short', '/wiki/Hildegard_of_the_Vinzgau', '/wiki/Pepin_of_Herstal', '/wiki/Begga', '/wiki/Gerold_of_Vinzgau', '/wiki/Lothair_I', '/wiki/Carloman_I', '/wiki/Alpaida', '/wiki/Himiltrude', '/wiki/Ansegisel', '/wiki/Desiderius', '/wiki/Ermengarde_of_Hesbaye', '/wiki/Louis_the_German', '/wiki/Carloman_(mayor_of_the_palace)', '/wiki/Rothilde', '/wiki/Theodrada', '/wiki/Gisela,_daughter_of_Louis_the_Pious', '/wiki/Ermentrude_of_Orl%C3%A9ans', '/wiki/Engeltrude_de_F%C3%A9zensac', '/wiki/Louis_the_Stammerer', '/wiki/Hemma', '/wiki/Judith_of_Flanders', '/wiki/Welf_(father_of_Judith)', '/wiki/Judith_of_Bavaria_(died_843)', '/wiki/Richilde_of_Provence', '/wiki/Ecgberht,_King_of_Wessex', '/wiki/Adrian,_Count_of_Orl%C3%A9ans', '/wiki/%C3%86lfthryth,_Countess_of_Flanders', '/wiki/Baldwin_II,_Margrave_of_Flanders', '/wiki/Edward_the_Elder', '/wiki/Eadgifu_of_Kent', '/wiki/%C3%86thelfl%C3%A6d', '/wiki/Eadgyth', '/wiki/Edith_of_Polesworth', '/wiki/Eadburh_of_Winchester', '/wiki/Edmund_I', '/wiki/Conrad,_Duke_of_Lorraine', '/wiki/Charles_the_Simple', '/wiki/Werner_V_(Salian)', '/wiki/Eadhild', '/wiki/Arnulf_I,_Count_of_Flanders', '/wiki/William_(archbishop_of_Mainz)', '/wiki/Eadwig', '/wiki/Edward_the_Martyr', '/wiki/Frederuna', '/wiki/Robert_III,_Count_of_Worms', '/wiki/Gerberga_of_Saxony', '/wiki/Matilda,_Abbess_of_Quedlinburg', '/wiki/Adelaide_of_Paris', '/wiki/Edith_of_Wilton', '/wiki/Adelaide_I,_Abbess_of_Quedlinburg', '/wiki/%C3%86lfthryth_(wife_of_Edgar)', '/wiki/Hatheburg_of_Merseburg', '/wiki/Otto_I,_Duke_of_Saxony', '/wiki/Judith,_Duchess_of_Bavaria', '/wiki/Dietrich_of_Ringelheim', '/wiki/%C3%86thelstan_%C3%86theling', '/wiki/Matilda_of_Germany,_Countess_Palatine_of_Lotharingia', '/wiki/Godgifu_(daughter_of_%C3%86thelred_the_Unready)', '/wiki/Hedwig_of_Saxony', '/wiki/Judith_of_S%C3%BClichgau', '/wiki/Bruno_the_Great', '/wiki/Sophia_I,_Abbess_of_Gandersheim', '/wiki/Gilbert,_Duke_of_Lorraine', '/wiki/Eberhard_of_S%C3%BClichgau', '/wiki/Alfred_Aetheling', '/wiki/Edith_of_Wessex', '/wiki/%C3%86lfgifu_of_York', '/wiki/Liudolf,_Duke_of_Saxony', '/wiki/Ealdgyth_(wife_of_Edmund_Ironside)', '/wiki/Gunnor', '/wiki/Gunhilda_of_Denmark', '/wiki/Gisela_(mother_of_Regelinda)', '/wiki/Tove_of_the_Obotrites', '/wiki/Robert_II_(archbishop_of_Rouen)', '/wiki/Harthacnut', '/wiki/Odo_II,_Count_of_Blois', '/wiki/Reginar_Longneck', '/wiki/Tostig_Godwinson', '/wiki/Eric_the_Victorious', '/wiki/Svein_Knutsson', '/wiki/Thored', '/wiki/%C3%86lfgifu_of_Northampton', '/wiki/Gytha_Thorkelsd%C3%B3ttir', '/wiki/Mieszko_I', '/wiki/Bertha_of_Burgundy', '/wiki/Drogo_of_Mantes', '/wiki/Eleanor_of_Normandy', '/wiki/Judith_(daughter_of_Eberhard_of_Friuli)', '/wiki/Matilda_of_France', '/wiki/Robert_I_of_France', '/wiki/Cunigunde_of_Swabia', '/wiki/Odo_I,_Count_of_Blois', '/wiki/Judith_of_Brittany', '/wiki/Theobald_I,_Count_of_Blois', '/wiki/Theobald_the_Elder', '/wiki/Baldwin_IV,_Count_of_Flanders', '/wiki/Rudolph_III_of_Burgundy', '/wiki/Adelaide_of_Tours', '/wiki/Robert_the_Strong', '/wiki/Harald_II_of_Denmark', '/wiki/Luitgarde_of_Vermandois', '/wiki/Herbert_II,_Count_of_Vermandois', '/wiki/Adelaide_of_Normandy', '/wiki/Conrad_I_of_Burgundy', '/wiki/Bertha_of_Swabia', '/wiki/Doubravka_of_Bohemia', '/wiki/Richard_III,_Duke_of_Normandy', '/wiki/Ermengarde-Gerberga_of_Anjou', '/wiki/Odo_of_France', '/wiki/Gytha_of_Wessex', '/wiki/Arnulf_II,_Count_of_Flanders', '/wiki/Edith_the_Fair', '/wiki/Gorm_the_Old', '/wiki/Hugh_of_Tours', '/wiki/Rozala_of_Italy', '/wiki/Burchard_II,_Duke_of_Swabia', '/wiki/Baldwin_III,_Count_of_Flanders', '/wiki/Gerloc', '/wiki/Liutgard_of_Saxony_(died_885)', '/wiki/Adele_of_Vermandois', '/wiki/Pepin,_Count_of_Vermandois', '/wiki/Matilda_of_Flanders', '/wiki/Lestek', '/wiki/Reginald_de_Dunstanville,_Earl_of_Cornwall', '/wiki/Vladimir_II_Monomakh', '/wiki/Th%C3%A9odrate_of_Troyes', '/wiki/Juliane_de_Fontevrault', '/wiki/Odo,_Count_of_Champagne', '/wiki/Matilda_of_Saxony,_countess_of_Flanders', '/wiki/R ...
# ['/wiki/Edith_of_Polesworth', '/wiki/Rurik', '/wiki/Gyula_II', '/wiki/Judith_of_Bavaria,_Duchess_of_Swabia', '/wiki/Taksony_of_Hungary']
# ['/wiki/Charles_the_Younger', '/wiki/Pepin_of_Italy', '/wiki/Luitgard_(Frankish_queen)', '/wiki/Rotrude_of_Hesbaye', '/wiki/Begga', '/wiki/Gerold_of_Vinzgau', '/wiki/Carloman_I', '/wiki/Alpaida', '/wiki/Himiltrude', '/wiki/Ansegisel', '/wiki/Desiderius', '/wiki/Ansa,_Queen_of_the_Lombards', '/wiki/Rothilde', '/wiki/Roger,_Count_of_Maine', '/wiki/Theodrada', '/wiki/Gisela,_daughter_of_Louis_the_Pious', '/wiki/Ermentrude_of_Orl%C3%A9ans', '/wiki/Engeltrude_de_F%C3%A9zensac', '/wiki/Judith_of_Flanders', '/wiki/Welf_(father_of_Judith)', '/wiki/Odo_I,_Count_of_Orl%C3%A9ans', '/wiki/Richilde_of_Provence', '/wiki/Rudolph,_Count_of_Ponthieu', '/wiki/%C3%86thelwulf,_King_of_Wessex', '/wiki/Ecgberht,_King_of_Wessex', '/wiki/%C3%86thelberht,_King_of_Wessex', '/wiki/Adrian,_Count_of_Orl%C3%A9ans', '/wiki/Alfred_the_Great', '/wiki/%C3%86lfthryth,_Countess_of_Flanders', '/wiki/Baldwin_II,_Margrave_of_Flanders', '/wiki/%C3%86thelred_I_of_Wessex', '/wiki/Ealhswith', '/wiki/Eadgifu_of_Kent', '/wiki/Adelolf,_Count_of_Boulogne', '/wiki/Edith_of_Polesworth', '/wiki/Eadburh_of_Winchester', '/wiki/Eadgifu_of_Wessex', '/wiki/%C3%86thelhelm', '/wiki/%C3%86thelbald,_King_of_Wessex', '/wiki/Werner_V_(Salian)', '/wiki/Eadhild', '/wiki/Edwin_(son_of_Edward_the_Elder)', '/wiki/Edgar,_King_of_England', '/wiki/Arnulf_I,_Count_of_Flanders', '/wiki/Henry_the_Fowler', '/wiki/William_(archbishop_of_Mainz)', '/wiki/Eadwig', '/wiki/Frederuna', '/wiki/Robert_III,_Count_of_Worms', '/wiki/Eadred_%C3%86theling', '/wiki/Gerberga_of_Saxony', '/wiki/Adelaide_of_Paris', '/wiki/%C3%86lfgifu_of_Shaftesbury', '/wiki/Hedwig_of_Babenberg', '/wiki/%C3%86lfthryth_(wife_of_Edgar)', '/wiki/Hatheburg_of_Merseburg', '/wiki/Dietrich_of_Ringelheim', '/wiki/%C3%86thelstan_%C3%86theling', '/wiki/Matilda_of_Germany,_Countess_Palatine_of_Lotharingia', '/wiki/Godgifu_(daughter_of_%C3%86thelred_the_Unready)', '/wiki/Hedwig_of_Saxony', '/wiki/Eadwig_%C3%86theling', '/wiki/Gilbert,_Duke_of_Lorraine', '/wiki/Eberhard_of_S%C3%BClichgau', '/wiki/Alfred_Aetheling', '/wiki/Edith_of_Wessex', '/wiki/%C3%86lfgifu_of_York', '/wiki/Liudolf,_Duke_of_Saxony', '/wiki/Ealdgyth_(wife_of_Edmund_Ironside)', '/wiki/Maud_of_Normandy', '/wiki/Hawise_of_Normandy', '/wiki/Gunnor', '/wiki/Gunhilda_of_Denmark', '/wiki/Gisela_(mother_of_Regelinda)', '/wiki/Robert_II_(archbishop_of_Rouen)', '/wiki/Adelhard_von_Burc', '/wiki/Reginar_Longneck', '/wiki/Wulfnoth_Cild', '/wiki/Eric_the_Victorious', '/wiki/Herman_I,_Count_Palatine_of_Lotharingia', '/wiki/Thored', '/wiki/%C3%86lfgifu_of_Northampton', '/wiki/Gytha_Thorkelsd%C3%B3ttir', '/wiki/Bertha_of_Burgundy', '/wiki/Geoffrey,_Count_of_Eu', '/wiki/Drogo_of_Mantes', '/wiki/Eleanor_of_Normandy', '/wiki/Judith_(daughter_of_Eberhard_of_Friuli)', '/wiki/Matilda_of_France', '/wiki/Harald_Bluetooth', '/wiki/Cunigunde_of_Swabia', '/wiki/Judith_of_Brittany', '/wiki/Theobald_I,_Count_of_Blois', '/wiki/Theobald_the_Elder', '/wiki/Baldwin_IV,_Count_of_Flanders', '/wiki/Herleva', '/wiki/Rudolph_III_of_Burgundy', '/wiki/Adelaide_of_Tours', '/wiki/Robert_the_Strong', '/wiki/Harald_II_of_Denmark', '/wiki/Luitgarde_of_Vermandois', '/wiki/Erenfried_II', '/wiki/Mauger_(archbishop_of_Rouen)', '/wiki/Herbert_II,_Count_of_Vermandois', '/wiki/Siemomys%C5%82', '/wiki/Adelaide_of_Normandy', '/wiki/Judith_of_Flanders_(died_1095)', '/wiki/Conrad_I_of_Burgundy', '/wiki/Bertha_of_Swabia', '/wiki/Doubravka_of_Bohemia', '/wiki/Alice_of_Normandy', '/wiki/Ermengarde-Gerberga_of_Anjou', '/wiki/Gytha_of_Wessex', '/wiki/Gorm_the_Old', '/wiki/Burchard_II,_Duke_of_Swabia', '/wiki/Baldwin_III,_Count_of_Flanders', '/wiki/Gerloc', '/wiki/Liutgard_of_Saxony_(died_885)', '/wiki/Adeliza', '/wiki/Pepin,_Count_of_Vermandois', '/wiki/Matilda_of_Flanders', '/wiki/Lestek', '/wiki/Reginald_de_Dunstanville,_Earl_of_Cornwall', '/wiki/Juliane_de_Fontevrault', '/wiki/Odo,_Count_of_Champagne', '/wiki/Regelinda_of_Z%C3%BCrich', '/wiki/Yuri_Dolgorukiy', '/wiki/Robert_I,_Count_of_Flanders', '/wiki/Boleslaus_I,_Duke_of_Bohemia',  ...

# %%
importlib.reload(utils)
for id in missingBirthPlace:
    person = { 'id': id }
    utils.extractDate(loadInfoBox(id), person, birth=True)
    print(person)
# Out:
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1015</span></td></tr>
# {'id': '/wiki/Eustace_II,_Count_of_Boulogne', 'birthDate': datetime.datetime(1015, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1045-1055</span></td></tr>
# {'id': '/wiki/Robert_Fitzhamon', 'birthDate': datetime.datetime(1045, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 1073</td></tr>
# {'id': '/wiki/Philippa,_Countess_of_Toulouse', 'birthDate': datetime.datetime(1073, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 958</span></td></tr>
# {'id': '/wiki/Otto-William,_Count_of_Burgundy', 'birthDate': datetime.datetime(958, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 1070</td></tr>
# {'id': '/wiki/Edmund_of_Scotland', 'birthDate': datetime.datetime(1070, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1056</td></tr>
# {'id': '/wiki/Baldwin_II,_Count_of_Hainaut', 'birthDate': datetime.datetime(1056, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 1036</td></tr>
# {'id': '/wiki/Igor_Yaroslavich', 'birthDate': datetime.datetime(1036, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1012</td></tr>
# {'id': '/wiki/Maria_Dobroniega_of_Kiev', 'birthDate': datetime.datetime(1012, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 950</span></td></tr>
# {'id': '/wiki/Bernard_I,_Duke_of_Saxony', 'birthDate': datetime.datetime(950, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1047?</td></tr>
# {'id': '/wiki/Wyszes%C5%82awa_of_Kiev', 'birthDate': datetime.datetime(1047, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 1030</td></tr>
# {'id': '/wiki/Anne_of_Kiev', 'birthDate': datetime.datetime(1030, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 995/1000</td></tr>
# {'id': '/wiki/Richeza_of_Lotharingia', 'birthDate': datetime.datetime(995, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1037</td></tr>
# {'id': '/wiki/Beatrice_I,_Abbess_of_Quedlinburg', 'birthDate': datetime.datetime(1037, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 970–75</span></td></tr>
# {'id': '/wiki/Emnilda', 'birthDate': datetime.datetime(970, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1139</span></td></tr>
# {'id': '/wiki/Sancha_of_Castile,_Queen_of_Navarre', 'birthDate': datetime.datetime(1139, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 1060<sup class="reference" id="cite_ref-weir_1-2"><a href="#cite_note-weir-1">[1]</a></sup></td></tr>
# {'id': '/wiki/Duncan_II_of_Scotland', 'birthDate': datetime.datetime(1060, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr> 1052</td></tr>
# {'id': '/wiki/Oleg_I_of_Chernigov', 'birthDate': datetime.datetime(1052, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">21 April 1132</td></tr>
# {'id': '/wiki/Sancho_VI_of_Navarre', 'birthDate': datetime.datetime(1132, 4, 21, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 980</td></tr>
# {'id': '/wiki/Olof_Sk%C3%B6tkonung', 'birthDate': datetime.datetime(980, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1025</span></td></tr>
# {'id': '/wiki/Gertrude_of_Poland', 'birthDate': datetime.datetime(1025, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">before 879</td></tr>
# {'id': '/wiki/Igor_of_Kiev', 'birthDate': datetime.datetime(879, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 950</td></tr>
# {'id': '/wiki/Sarolt', 'birthDate': datetime.datetime(950, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 945/952</td></tr>
# {'id': '/wiki/Adelaide_of_Aquitaine', 'birthDate': datetime.datetime(945, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1072</td></tr>
# {'id': '/wiki/Agnes_of_Waiblingen', 'birthDate': datetime.datetime(1072, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">Eupraxia Vsevolodovna<br/>c. 1067</td></tr>
# {'id': '/wiki/Eupraxia_of_Kiev', 'birthDate': datetime.datetime(1067, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 1044<br/>Poland</td></tr>
# {'id': '/wiki/W%C5%82adys%C5%82aw_I_Herman', 'birthDate': datetime.datetime(1044, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1090</td></tr>
# {'id': '/wiki/Frederick_II,_Duke_of_Swabia', 'birthDate': datetime.datetime(1090, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr> 1112</td></tr>
# {'id': '/wiki/Garc%C3%ADa_Ram%C3%ADrez_of_Navarre', 'birthDate': datetime.datetime(1112, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 920</td></tr>
# {'id': '/wiki/Renaud_of_Roucy', 'birthDate': datetime.datetime(920, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">July/August 1150</td></tr>
# {'id': '/wiki/Alice_of_France', 'birthDate': datetime.datetime(1150, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 975</span></td></tr>
# {'id': '/wiki/Gerberga_of_Lower_Lorraine', 'birthDate': datetime.datetime(975, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">28 February 1155<br/>London, England</td></tr>
# {'id': '/wiki/Henry_the_Young_King', 'birthDate': datetime.datetime(1155, 2, 28, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 25 July 1008 or 1010</td></tr>
# {'id': '/wiki/Anund_Jacob', 'birthDate': datetime.datetime(1008, 7, 25, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1107</td></tr>
# {'id': '/wiki/Henry_II,_Duke_of_Austria', 'birthDate': datetime.datetime(1107, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1025</span></td></tr>
# {'id': '/wiki/Agnes_of_Poitou', 'birthDate': datetime.datetime(1025, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1120</td></tr>
# {'id': '/wiki/Louis_VII_of_France', 'birthDate': datetime.datetime(1120, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 1137</td></tr>
# {'id': '/wiki/Ferdinand_II_of_Le%C3%B3n', 'birthDate': datetime.datetime(1137, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr>1080–1085</td></tr>
# {'id': '/wiki/Ingegerd_Knutsdatter', 'birthDate': datetime.datetime(1080, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1040</span></td></tr>
# {'id': '/wiki/Adelaide_of_Hungary', 'birthDate': datetime.datetime(1040, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1093 or 1094</td></tr>
# {'id': '/wiki/Conrad_III_of_Germany', 'birthDate': datetime.datetime(1093, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1040</span></td></tr>
# {'id': '/wiki/Ida_of_Lorraine', 'birthDate': datetime.datetime(1040, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr> 1052</td></tr>
# {'id': '/wiki/Roman_Svyatoslavich', 'birthDate': datetime.datetime(1052, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1118</span></td></tr>
# {'id': '/wiki/Gertrude_of_Babenberg,_Duchess_of_Bohemia', 'birthDate': datetime.datetime(1118, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">?1070</td></tr>
# {'id': '/wiki/Rostislav_Vsevolodovich', 'birthDate': datetime.datetime(1070, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 1042<sup class="reference" id="cite_ref-pajung_1-0"><a href="#cite_note-pajung-1">[1]</a></sup></td></tr>
# {'id': '/wiki/Canute_IV_of_Denmark', 'birthDate': datetime.datetime(1042, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1050</span></td></tr>
# {'id': '/wiki/Sophia_of_Hungary', 'birthDate': datetime.datetime(1050, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">February/March 1172</td></tr>
# {'id': '/wiki/Conrad_II,_Duke_of_Swabia', 'birthDate': datetime.datetime(1172, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1040</span></td></tr>
# {'id': '/wiki/William_IV,_Count_of_Toulouse', 'birthDate': datetime.datetime(1040, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><span class="nickname">Fulk Nerra</span><br/><abbr title="circa">c.</abbr> 987</td></tr>
# {'id': '/wiki/Fulk_III,_Count_of_Anjou', 'birthDate': datetime.datetime(987, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1108</td></tr>
# {'id': '/wiki/Leopold,_Duke_of_Bavaria', 'birthDate': datetime.datetime(1108, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr> 1018</td></tr>
# {'id': '/wiki/Richilde,_Countess_of_Hainaut', 'birthDate': datetime.datetime(1018, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1158</td></tr>
# {'id': '/wiki/Margaret_of_France,_Queen_of_England_and_Hungary', 'birthDate': datetime.datetime(1158, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">21 September 1051</td></tr>
# {'id': '/wiki/Bertha_of_Savoy', 'birthDate': datetime.datetime(1051, 9, 21, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr> 990</td></tr>
# {'id': '/wiki/Gisela_of_Swabia', 'birthDate': datetime.datetime(990, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr> 1072</td></tr>
# {'id': '/wiki/Maud,_Countess_of_Huntingdon', 'birthDate': datetime.datetime(1072, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">Between 1167 and 1171</td></tr>
# {'id': '/wiki/Otto_I,_Count_of_Burgundy', 'birthDate': datetime.datetime(1167, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">circa 1161</td></tr>
# {'id': '/wiki/Constance,_Duchess_of_Brittany', 'birthDate': datetime.datetime(1161, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1065</span><sup class="reference" id="cite_ref-Gale_1-0"><a href="#cite_note-Gale-1">[1]</a></sup></td></tr>
# {'id': '/wiki/Adelaide_of_Rheinfelden', 'birthDate': datetime.datetime(1065, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 1190</td></tr>
# {'id': '/wiki/Richard_FitzRoy', 'birthDate': datetime.datetime(1190, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 1046–1048</td></tr>
# {'id': '/wiki/%C5%9Awi%C4%99tos%C5%82awa_of_Poland', 'birthDate': datetime.datetime(1046, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 970</span></td></tr>
# {'id': '/wiki/Henry_of_Speyer', 'birthDate': datetime.datetime(970, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1135</span></td></tr>
# {'id': '/wiki/Conrad,_Count_Palatine_of_the_Rhine', 'birthDate': datetime.datetime(1135, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 1108/1113</td></tr>
# {'id': '/wiki/Agnes_of_Babenberg', 'birthDate': datetime.datetime(1108, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">3/4 January 1239</td></tr>
# {'id': '/wiki/John_II,_Duke_of_Brittany', 'birthDate': datetime.datetime(1239, 1, 4, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">22 July 1210</td></tr>
# {'id': '/wiki/Joan_of_England,_Queen_of_Scotland', 'birthDate': datetime.datetime(1210, 7, 22, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr> 1020</td></tr>
# {'id': '/wiki/Almodis_of_La_Marche', 'birthDate': datetime.datetime(1020, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1050</span></td></tr>
# {'id': '/wiki/Frederick_I,_Duke_of_Swabia', 'birthDate': datetime.datetime(1050, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">c. late 1110s/1120</td></tr>
# {'id': '/wiki/Judith_of_Babenberg', 'birthDate': datetime.datetime(1120, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">21 September 1154/5</td></tr>
# {'id': '/wiki/Sancha_of_Castile,_Queen_of_Aragon', 'birthDate': datetime.datetime(1154, 9, 21, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1145</td></tr>
# {'id': '/wiki/Margaret_of_Huntingdon,_Duchess_of_Brittany', 'birthDate': datetime.datetime(1145, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1186</span> / <abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1188</span></td></tr>
# {'id': '/wiki/Isabella_of_Angoul%C3%AAme', 'birthDate': datetime.datetime(1186, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">Adelaide<br/><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1050</span></td></tr>
# {'id': '/wiki/Adelaide_of_Savoy,_Duchess_of_Swabia', 'birthDate': datetime.datetime(1050, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1095</span></td></tr>
# {'id': '/wiki/Richeza_of_Berg', 'birthDate': datetime.datetime(1095, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1198</td></tr>
# {'id': '/wiki/Ramon_Berenguer_IV,_Count_of_Provence', 'birthDate': datetime.datetime(1198, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1245-1255</td></tr>
# {'id': '/wiki/Constance_of_B%C3%A9arn', 'birthDate': datetime.datetime(1245, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1201</td></tr>
# {'id': '/wiki/Catherine_of_Thouars', 'birthDate': datetime.datetime(1201, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr> 1187</td></tr>
# {'id': '/wiki/Peter_I,_Duke_of_Brittany', 'birthDate': datetime.datetime(1187, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 1060</td></tr>
# {'id': '/wiki/Bretislav_II', 'birthDate': datetime.datetime(1060, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1075</td></tr>
# {'id': '/wiki/Henry_IX,_Duke_of_Bavaria', 'birthDate': datetime.datetime(1075, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">c. 980</td></tr>
# {'id': '/wiki/Tancred_of_Hauteville', 'birthDate': datetime.datetime(980, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1124</span></td></tr>
# {'id': '/wiki/Maria_of_Bohemia', 'birthDate': datetime.datetime(1124, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 960</td></tr>
# {'id': '/wiki/Michael_of_Hungary', 'birthDate': datetime.datetime(960, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1133/1134</span></td></tr>
# {'id': '/wiki/Judith_of_Hohenstaufen', 'birthDate': datetime.datetime(1133, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1075</span></td></tr>
# {'id': '/wiki/Aimery_I,_Viscount_of_Ch%C3%A2tellerault', 'birthDate': datetime.datetime(1075, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1079</td></tr>
# {'id': '/wiki/Dangereuse_de_l%27Isle_Bouchard', 'birthDate': datetime.datetime(1079, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1060</span></td></tr>
# {'id': '/wiki/Berthold_I,_Duke_of_Swabia', 'birthDate': datetime.datetime(1060, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1045</td></tr>
# {'id': '/wiki/Otto_I_of_Olomouc', 'birthDate': datetime.datetime(1045, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><span style="display:none">(<span class="bday">1071-10-22</span>)</span>22 October 1071</td></tr>
# {'id': '/wiki/William_IX,_Duke_of_Aquitaine', 'birthDate': datetime.datetime(1071, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">c.1224-7</td></tr>
# {'id': '/wiki/Isabella_of_Lusignan', 'birthDate': datetime.datetime(1224, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1065</span></td></tr>
# {'id': '/wiki/Bertha_of_Rheinfelden', 'birthDate': datetime.datetime(1065, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1271</td></tr>
# {'id': '/wiki/Blanche_of_Brittany', 'birthDate': datetime.datetime(1271, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1009?<sup class="reference" id="cite_ref-6"><a href="#cite_note-6">[Note 1]</a></sup></td></tr>
# {'id': '/wiki/Thorfinn_the_Mighty', 'birthDate': datetime.datetime(1009, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">December 1127</td></tr>
# {'id': '/wiki/Henry_I,_Count_of_Champagne', 'birthDate': datetime.datetime(1127, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1023</span></td></tr>
# {'id': '/wiki/Otto,_Count_of_Savoy', 'birthDate': datetime.datetime(1023, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">April 1240</td></tr>
# {'id': '/wiki/Simon_de_Montfort_the_Younger', 'birthDate': datetime.datetime(1240, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 1090</td></tr>
# {'id': '/wiki/Douce_I,_Countess_of_Provence', 'birthDate': datetime.datetime(1090, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 931</td></tr>
# {'id': '/wiki/Taksony_of_Hungary', 'birthDate': datetime.datetime(931, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">16 April 1045</td></tr>
# {'id': '/wiki/Mieszko_Kazimierzowic', 'birthDate': datetime.datetime(1045, 4, 16, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1285</td></tr>
# {'id': '/wiki/Margaret_of_Artois', 'birthDate': datetime.datetime(1285, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">16 January 1245<br/>London, England</td></tr>
# {'id': '/wiki/Edmund_Crouchback', 'birthDate': datetime.datetime(1245, 1, 16, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">25 July 1261</td></tr>
# {'id': '/wiki/Arthur_II,_Duke_of_Brittany', 'birthDate': datetime.datetime(1261, 7, 25, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1310</td></tr>
# {'id': '/wiki/Joan_of_%C3%89vreux', 'birthDate': datetime.datetime(1310, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr> 1227</td></tr>
# {'id': '/wiki/William_de_Valence,_1st_Earl_of_Pembroke', 'birthDate': datetime.datetime(1227, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1114</td></tr>
# {'id': '/wiki/Henry_of_Scotland', 'birthDate': datetime.datetime(1114, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">c. 1065</td></tr>
# {'id': '/wiki/Henry_I_the_Long,_Margrave_of_the_Nordmark', 'birthDate': datetime.datetime(1065, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1075</span></td></tr>
# {'id': '/wiki/Sob%C4%9Bslav_I,_Duke_of_Bohemia', 'birthDate': datetime.datetime(1075, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1180</span></td></tr>
# {'id': '/wiki/Garsenda,_Countess_of_Forcalquier', 'birthDate': datetime.datetime(1180, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1130</td></tr>
# {'id': '/wiki/Theobald_V,_Count_of_Blois', 'birthDate': datetime.datetime(1130, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 954<sup class="reference" id="cite_ref-weir_2-2"><a href="#cite_note-weir-2">[2]</a></sup></td></tr>
# {'id': '/wiki/Malcolm_II_of_Scotland', 'birthDate': datetime.datetime(954, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 1142<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup></td></tr>
# {'id': '/wiki/William_the_Lion', 'birthDate': datetime.datetime(1142, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 1217/1218</td></tr>
# {'id': '/wiki/John_I,_Duke_of_Brittany', 'birthDate': datetime.datetime(1217, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1154</td></tr>
# {'id': '/wiki/Robert_II,_Count_of_Dreux', 'birthDate': datetime.datetime(1154, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">before 1010</td></tr>
# {'id': '/wiki/Amaury_I_de_Montfort', 'birthDate': datetime.datetime(1010, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 990</span></td></tr>
# {'id': '/wiki/Adelina_of_Holland', 'birthDate': datetime.datetime(990, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><div class="nickname" style="display:inline">Guillaume de Montfort</div><br/>Before 1087<br/><div class="birthplace" style="display:inline">Yves</div></td></tr>
# {'id': '/wiki/Guillaume_de_Montfort_(bishop_of_Paris)', 'birthDate': datetime.datetime(1087, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1160<br/><span class="birthplace">France</span></td></tr>
# {'id': '/wiki/Alice_of_Courtenay', 'birthDate': datetime.datetime(1160, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1175</td></tr>
# {'id': '/wiki/Otto_IV,_Holy_Roman_Emperor', 'birthDate': datetime.datetime(1175, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">c. 1194/1207<br/><span class="birthplace">Leinster</span></td></tr>
# {'id': '/wiki/Gilbert_Marshal,_4th_Earl_of_Pembroke', 'birthDate': datetime.datetime(1194, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1136–1140</td></tr>
# {'id': '/wiki/Constance_of_Castile', 'birthDate': datetime.datetime(1136, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1287</td></tr>
# {'id': '/wiki/Robert_III_of_Artois', 'birthDate': datetime.datetime(1287, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1125</span></td></tr>
# {'id': '/wiki/Adelaide_of_Vohburg', 'birthDate': datetime.datetime(1125, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">18 April 1115<br/><span class="birthplace">Germany</span></td></tr>
# {'id': '/wiki/Gertrude_of_S%C3%BCpplingenburg', 'birthDate': datetime.datetime(1115, 4, 18, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 1191</td></tr>
# {'id': '/wiki/Joan,_Lady_of_Wales', 'birthDate': datetime.datetime(1191, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1171</td></tr>
# {'id': '/wiki/Agnes_of_France,_Byzantine_Empress', 'birthDate': datetime.datetime(1171, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1152<br/>Huntingdon, Huntingdonshire, England</td></tr>
# {'id': '/wiki/David,_Earl_of_Huntingdon', 'birthDate': datetime.datetime(1152, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1226</td></tr>
# {'id': '/wiki/Blanche_of_Navarre,_Duchess_of_Brittany', 'birthDate': datetime.datetime(1226, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">c. 1065</td></tr>
# {'id': '/wiki/Agnes_of_Rheinfelden', 'birthDate': datetime.datetime(1065, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1070</td></tr>
# {'id': '/wiki/Ramiro_S%C3%A1nchez', 'birthDate': datetime.datetime(1070, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">955</td></tr>
# {'id': '/wiki/Lutgardis_of_Luxemburg', 'birthDate': datetime.datetime(955, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1182–4</span></td></tr>
# {'id': '/wiki/Eleanor,_Fair_Maid_of_Brittany', 'birthDate': datetime.datetime(1182, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">4 October 1160</td></tr>
# {'id': '/wiki/Alys_of_France,_Countess_of_Vexin', 'birthDate': datetime.datetime(1160, 10, 4, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">5 September 1187<br/>Paris, France</td></tr>
# {'id': '/wiki/Louis_VIII_of_France', 'birthDate': datetime.datetime(1187, 9, 5, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">20 March 1263</td></tr>
# {'id': '/wiki/Yolande_of_Dreux,_Queen_of_Scotland', 'birthDate': datetime.datetime(1263, 3, 20, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">4 May 1152</td></tr>
# {'id': '/wiki/Peter_of_Barcelona', 'birthDate': datetime.datetime(1152, 5, 4, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1152/55</td></tr>
# {'id': '/wiki/Gertrude_of_Bavaria', 'birthDate': datetime.datetime(1152, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 990</span></td></tr>
# {'id': '/wiki/Matilda_of_Swabia', 'birthDate': datetime.datetime(990, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><span style="display:none">(<span class="bday">1276-05-03</span>)</span>3 May 1276</td></tr>
# {'id': '/wiki/Louis,_Count_of_%C3%89vreux', 'birthDate': datetime.datetime(1276, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">969</td></tr>
# {'id': '/wiki/William_V,_Duke_of_Aquitaine', 'birthDate': datetime.datetime(969, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 1158</td></tr>
# {'id': '/wiki/Ramon_Berenguer_III,_Count_of_Provence', 'birthDate': datetime.datetime(1158, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1143/5</td></tr>
# {'id': '/wiki/Beatrice_I,_Countess_of_Burgundy', 'birthDate': datetime.datetime(1143, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 1183</td></tr>
# {'id': '/wiki/Hugh_X_of_Lusignan', 'birthDate': datetime.datetime(1183, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 1065</td></tr>
# {'id': '/wiki/Vladislaus_I', 'birthDate': datetime.datetime(1065, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1075</td></tr>
# {'id': '/wiki/Gisela_of_Burgundy,_Marchioness_of_Montferrat', 'birthDate': datetime.datetime(1075, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1139 or 1148</td></tr>
# {'id': '/wiki/Stephanie_Alfonso_of_Castile', 'birthDate': datetime.datetime(1139, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1155</span></td></tr>
# {'id': '/wiki/Hermann_I,_Landgrave_of_Thuringia', 'birthDate': datetime.datetime(1155, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">c. 1025</td></tr>
# {'id': '/wiki/Lothair_Udo_II,_Margrave_of_the_Nordmark', 'birthDate': datetime.datetime(1025, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">November 1238<br/><div class="birthplace" style="display:inline">Kingdom of England</div></td></tr>
# {'id': '/wiki/Henry_de_Montfort', 'birthDate': datetime.datetime(1238, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">late 1081<br/>Paris, France</td></tr>
# {'id': '/wiki/Louis_VI_of_France', 'birthDate': datetime.datetime(1081, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1050</span></td></tr>
# {'id': '/wiki/Olaf_I_of_Denmark', 'birthDate': datetime.datetime(1050, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1268</td></tr>
# {'id': '/wiki/Marie_of_Brittany,_Countess_of_Saint-Pol', 'birthDate': datetime.datetime(1268, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1287<br/><span class="birthplace">Chaillot</span></td></tr>
# {'id': '/wiki/Guy_de_Penthi%C3%A8vre', 'birthDate': datetime.datetime(1287, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1090</td></tr>
# {'id': '/wiki/Theobald_II,_Count_of_Champagne', 'birthDate': datetime.datetime(1090, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1025</span></td></tr>
# {'id': '/wiki/Rudolf_of_Rheinfelden', 'birthDate': datetime.datetime(1025, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 1200</td></tr>
# {'id': '/wiki/Andrew_III,_Baron_of_Vitr%C3%A9', 'birthDate': datetime.datetime(1200, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr> 1068</td></tr>
# {'id': '/wiki/Simon_II_de_Montfort', 'birthDate': datetime.datetime(1068, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 1170</td></tr>
# {'id': '/wiki/Ermengarde_de_Beaumont', 'birthDate': datetime.datetime(1170, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 950</span></td></tr>
# {'id': '/wiki/Emma_of_Blois', 'birthDate': datetime.datetime(950, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1171</td></tr>
# {'id': '/wiki/Matilda_of_Chester,_Countess_of_Huntingdon', 'birthDate': datetime.datetime(1171, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1140</span></td></tr>
# {'id': '/wiki/Richeza_of_Poland,_Queen_of_Castile', 'birthDate': datetime.datetime(1140, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1019</td></tr>
# {'id': '/wiki/Pons,_Count_of_Toulouse', 'birthDate': datetime.datetime(1019, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1204</span></td></tr>
# {'id': '/wiki/Henry_Raspe', 'birthDate': datetime.datetime(1204, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1025</span></td></tr>
# {'id': '/wiki/William_VIII,_Duke_of_Aquitaine', 'birthDate': datetime.datetime(1025, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1192</td></tr>
# {'id': '/wiki/Maud_Marshal', 'birthDate': datetime.datetime(1192, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1173</span></td></tr>
# {'id': '/wiki/Henry_V,_Count_Palatine_of_the_Rhine', 'birthDate': datetime.datetime(1173, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1145</td></tr>
# {'id': '/wiki/Aoife_MacMurrough', 'birthDate': datetime.datetime(1145, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">Norway</td></tr>
# {'id': '/wiki/Gunnhildr_Sveinsd%C3%B3ttir', 'birthDate': None, 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1065</td></tr>
# {'id': '/wiki/Humbert_II,_Count_of_Savoy', 'birthDate': datetime.datetime(1065, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1128</td></tr>
# {'id': '/wiki/Louis_II,_Landgrave_of_Thuringia', 'birthDate': datetime.datetime(1128, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1020</td></tr>
# {'id': '/wiki/William_I,_Count_of_Burgundy', 'birthDate': datetime.datetime(1020, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1040</span></td></tr>
# {'id': '/wiki/Harald_Hen', 'birthDate': datetime.datetime(1040, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">8 March 1286<br/>Château de Champtoceaux</td></tr>
# {'id': '/wiki/John_III,_Duke_of_Brittany', 'birthDate': datetime.datetime(1286, 3, 8, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1184</td></tr>
# {'id': '/wiki/Jutta_of_Thuringia', 'birthDate': datetime.datetime(1184, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr> 1138</td></tr>
# {'id': '/wiki/Conan_IV,_Duke_of_Brittany', 'birthDate': datetime.datetime(1138, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1120</span></td></tr>
# {'id': '/wiki/Ada_de_Warenne', 'birthDate': datetime.datetime(1120, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1081</td></tr>
# {'id': '/wiki/Rudolf_I,_Count_of_Bregenz', 'birthDate': datetime.datetime(1081, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1291</td></tr>
# {'id': '/wiki/Marie_of_Artois', 'birthDate': datetime.datetime(1291, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1072</td></tr>
# {'id': '/wiki/Wulfhilde_of_Saxony', 'birthDate': datetime.datetime(1072, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1130/35</td></tr>
# {'id': '/wiki/Beatrice_of_Rethel', 'birthDate': datetime.datetime(1130, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1201</td></tr>
# {'id': '/wiki/Agnes_of_the_Palatinate', 'birthDate': datetime.datetime(1201, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">c. 950</td></tr>
# {'id': '/wiki/Otto_I,_Duke_of_Carinthia', 'birthDate': datetime.datetime(950, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1087</span></td></tr>
# {'id': '/wiki/Reginald_III,_Count_of_Burgundy', 'birthDate': datetime.datetime(1087, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">unknown (before 1076)</td></tr>
# {'id': '/wiki/Margareta_Hasbj%C3%B6rnsdatter', 'birthDate': datetime.datetime(1076, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">(?)<br/><span class="birthplace">(?)</span></td></tr>
# {'id': '/wiki/Louis_I,_Landgrave_of_Thuringia', 'birthDate': None, 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">20 January 1259<br/>Burstwick, Yorkshire, England</td></tr>
# {'id': '/wiki/Aveline_de_Forz,_Countess_of_Aumale', 'birthDate': datetime.datetime(1259, 1, 20, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1123</span></td></tr>
# {'id': '/wiki/Robert_I,_Count_of_Dreux', 'birthDate': datetime.datetime(1123, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">before 1003</td></tr>
# {'id': '/wiki/Judith_of_Schweinfurt', 'birthDate': datetime.datetime(1003, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr> 1266</td></tr>
# {'id': '/wiki/John_of_Brittany,_Earl_of_Richmond', 'birthDate': datetime.datetime(1266, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1200</span></td></tr>
# {'id': '/wiki/Countess_Palatine_Irmengard_of_the_Rhine', 'birthDate': datetime.datetime(1200, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr> 1296</td></tr>
# {'id': '/wiki/Blanche_of_Burgundy', 'birthDate': datetime.datetime(1296, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1042</td></tr>
# {'id': '/wiki/Louis_the_Springer', 'birthDate': datetime.datetime(1042, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">Between 1105 and 1107</td></tr>
# {'id': '/wiki/Adelaide_of_Hungary_(d._1140)', 'birthDate': datetime.datetime(1105, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr> 1218</td></tr>
# {'id': '/wiki/Enzo_of_Sardinia', 'birthDate': datetime.datetime(1218, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1200</td></tr>
# {'id': '/wiki/Eleanor_of_Castile_(died_1244)', 'birthDate': datetime.datetime(1200, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">November 1269</td></tr>
# {'id': '/wiki/Philip_of_Artois', 'birthDate': datetime.datetime(1269, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1204</td></tr>
# {'id': '/wiki/Berengaria_of_Le%C3%B3n', 'birthDate': datetime.datetime(1204, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1098</td></tr>
# {'id': '/wiki/Hedwig_of_Gudensberg', 'birthDate': datetime.datetime(1098, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><span class="birthplace">Normandy</span></td></tr>
# {'id': '/wiki/Judith_d%27%C3%89vreux', 'birthDate': None, 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">September 1156</td></tr>
# ...
# {'id': '/wiki/Simon_II_de_Montfort', 'birthDate': datetime.datetime(1068, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 1170</td></tr>
# {'id': '/wiki/Ermengarde_de_Beaumont', 'birthDate': datetime.datetime(1170, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 950</span></td></tr>
# {'id': '/wiki/Emma_of_Blois', 'birthDate': datetime.datetime(950, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1171</td></tr>
# {'id': '/wiki/Matilda_of_Chester,_Countess_of_Huntingdon', 'birthDate': datetime.datetime(1171, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1140</span></td></tr>
# {'id': '/wiki/Richeza_of_Poland,_Queen_of_Castile', 'birthDate': datetime.datetime(1140, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1019</td></tr>
# {'id': '/wiki/Pons,_Count_of_Toulouse', 'birthDate': datetime.datetime(1019, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1204</span></td></tr>
# {'id': '/wiki/Henry_Raspe', 'birthDate': datetime.datetime(1204, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1025</span></td></tr>
# {'id': '/wiki/William_VIII,_Duke_of_Aquitaine', 'birthDate': datetime.datetime(1025, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1192</td></tr>
# {'id': '/wiki/Maud_Marshal', 'birthDate': datetime.datetime(1192, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1173</span></td></tr>
# {'id': '/wiki/Henry_V,_Count_Palatine_of_the_Rhine', 'birthDate': datetime.datetime(1173, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1145</td></tr>
# {'id': '/wiki/Aoife_MacMurrough', 'birthDate': datetime.datetime(1145, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">Norway</td></tr>
# {'id': '/wiki/Gunnhildr_Sveinsd%C3%B3ttir', 'birthDate': None, 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1065</td></tr>
# {'id': '/wiki/Humbert_II,_Count_of_Savoy', 'birthDate': datetime.datetime(1065, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1128</td></tr>
# {'id': '/wiki/Louis_II,_Landgrave_of_Thuringia', 'birthDate': datetime.datetime(1128, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1020</td></tr>
# {'id': '/wiki/William_I,_Count_of_Burgundy', 'birthDate': datetime.datetime(1020, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1040</span></td></tr>
# {'id': '/wiki/Harald_Hen', 'birthDate': datetime.datetime(1040, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">8 March 1286<br/>Château de Champtoceaux</td></tr>
# {'id': '/wiki/John_III,_Duke_of_Brittany', 'birthDate': datetime.datetime(1286, 3, 8, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1184</td></tr>
# {'id': '/wiki/Jutta_of_Thuringia', 'birthDate': datetime.datetime(1184, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr> 1138</td></tr>
# {'id': '/wiki/Conan_IV,_Duke_of_Brittany', 'birthDate': datetime.datetime(1138, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1120</span></td></tr>
# {'id': '/wiki/Ada_de_Warenne', 'birthDate': datetime.datetime(1120, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1081</td></tr>
# {'id': '/wiki/Rudolf_I,_Count_of_Bregenz', 'birthDate': datetime.datetime(1081, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1291</td></tr>
# {'id': '/wiki/Marie_of_Artois', 'birthDate': datetime.datetime(1291, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1072</td></tr>
# {'id': '/wiki/Wulfhilde_of_Saxony', 'birthDate': datetime.datetime(1072, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1130/35</td></tr>
# {'id': '/wiki/Beatrice_of_Rethel', 'birthDate': datetime.datetime(1130, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1201</td></tr>
# {'id': '/wiki/Agnes_of_the_Palatinate', 'birthDate': datetime.datetime(1201, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">c. 950</td></tr>
# {'id': '/wiki/Otto_I,_Duke_of_Carinthia', 'birthDate': datetime.datetime(950, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1087</span></td></tr>
# {'id': '/wiki/Reginald_III,_Count_of_Burgundy', 'birthDate': datetime.datetime(1087, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">unknown (before 1076)</td></tr>
# {'id': '/wiki/Margareta_Hasbj%C3%B6rnsdatter', 'birthDate': datetime.datetime(1076, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">(?)<br/><span class="birthplace">(?)</span></td></tr>
# {'id': '/wiki/Louis_I,_Landgrave_of_Thuringia', 'birthDate': None, 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">20 January 1259<br/>Burstwick, Yorkshire, England</td></tr>
# {'id': '/wiki/Aveline_de_Forz,_Countess_of_Aumale', 'birthDate': datetime.datetime(1259, 1, 20, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1123</span></td></tr>
# {'id': '/wiki/Robert_I,_Count_of_Dreux', 'birthDate': datetime.datetime(1123, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">before 1003</td></tr>
# {'id': '/wiki/Judith_of_Schweinfurt', 'birthDate': datetime.datetime(1003, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr> 1266</td></tr>
# {'id': '/wiki/John_of_Brittany,_Earl_of_Richmond', 'birthDate': datetime.datetime(1266, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1200</span></td></tr>
# {'id': '/wiki/Countess_Palatine_Irmengard_of_the_Rhine', 'birthDate': datetime.datetime(1200, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr> 1296</td></tr>
# {'id': '/wiki/Blanche_of_Burgundy', 'birthDate': datetime.datetime(1296, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1042</td></tr>
# {'id': '/wiki/Louis_the_Springer', 'birthDate': datetime.datetime(1042, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">Between 1105 and 1107</td></tr>
# {'id': '/wiki/Adelaide_of_Hungary_(d._1140)', 'birthDate': datetime.datetime(1105, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr> 1218</td></tr>
# {'id': '/wiki/Enzo_of_Sardinia', 'birthDate': datetime.datetime(1218, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1200</td></tr>
# {'id': '/wiki/Eleanor_of_Castile_(died_1244)', 'birthDate': datetime.datetime(1200, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">November 1269</td></tr>
# {'id': '/wiki/Philip_of_Artois', 'birthDate': datetime.datetime(1269, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1204</td></tr>
# {'id': '/wiki/Berengaria_of_Le%C3%B3n', 'birthDate': datetime.datetime(1204, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1098</td></tr>
# {'id': '/wiki/Hedwig_of_Gudensberg', 'birthDate': datetime.datetime(1098, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><span class="birthplace">Normandy</span></td></tr>
# {'id': '/wiki/Judith_d%27%C3%89vreux', 'birthDate': None, 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">September 1156</td></tr>
# {'id': '/wiki/Isaac_II_Angelos', 'birthDate': datetime.datetime(1156, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1048</span></td></tr>
# {'id': '/wiki/Peter_I,_Count_of_Savoy', 'birthDate': datetime.datetime(1048, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1303</td></tr>
# {'id': '/wiki/Marie_of_%C3%89vreux', 'birthDate': datetime.datetime(1303, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1151 or 1152</td></tr>
# {'id': '/wiki/Louis_III,_Landgrave_of_Thuringia', 'birthDate': datetime.datetime(1151, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 1087/1089</td></tr>
# {'id': '/wiki/Richenza_of_Northeim', 'birthDate': datetime.datetime(1087, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">29 August 1116</td></tr>
# {'id': '/wiki/Philip_of_France_(1116%E2%80%931131)', 'birthDate': datetime.datetime(1116, 8, 29, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1085</span></td></tr>
# {'id': '/wiki/Elizabeth_of_Vermandois,_Countess_of_Leicester', 'birthDate': datetime.datetime(1085, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr> 880 or <abbr title="circa">c.</abbr> 903</td></tr>
# {'id': '/wiki/Zolt%C3%A1n_of_Hungary', 'birthDate': datetime.datetime(880, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1177</span></td></tr>
# {'id': '/wiki/Blanche_of_Navarre,_Countess_of_Champagne', 'birthDate': datetime.datetime(1177, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">1231</td></tr>
# {'id': '/wiki/Philip_of_Castile', 'birthDate': datetime.datetime(1231, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr> 950 or <abbr title="circa">c.</abbr> 980</td></tr>
# {'id': '/wiki/Humbert_I,_Count_of_Savoy', 'birthDate': datetime.datetime(950, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c. 1150</td></tr>
# {'id': '/wiki/Andrew_II,_Baron_of_Vitr%C3%A9', 'birthDate': datetime.datetime(1150, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1020</span></td></tr>
# {'id': '/wiki/Kunigunde_of_Altdorf', 'birthDate': datetime.datetime(1020, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1244</td></tr>
# {'id': '/wiki/Guy_de_Montfort,_Count_of_Nola', 'birthDate': datetime.datetime(1244, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">Philippe Hurepel<br/>September 1200</td></tr>
# {'id': '/wiki/Philip_I,_Count_of_Boulogne', 'birthDate': datetime.datetime(1200, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">11th Century</td></tr>
# {'id': '/wiki/Gottschalk_(Obotrite_prince)', 'birthDate': None, 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data"><abbr title="circa">c.</abbr><span style="white-space:nowrap;"> 1053</span></td></tr>
# {'id': '/wiki/Ramon_Berenguer_II,_Count_of_Barcelona', 'birthDate': datetime.datetime(1053, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">c.1018</td></tr>
# {'id': '/wiki/Sancha_of_Le%C3%B3n', 'birthDate': datetime.datetime(1018, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data">8 May 1046</td></tr>
# {'id': '/wiki/Constance_of_Burgundy', 'birthDate': datetime.datetime(1046, 5, 8, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">937</td></tr>
# {'id': '/wiki/William_IV,_Duke_of_Aquitaine', 'birthDate': datetime.datetime(937, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;"><span class="birthplace">c. 870</span></td></tr>
# {'id': '/wiki/Ebalus,_Duke_of_Aquitaine', 'birthDate': datetime.datetime(870, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1150</td></tr>
# {'id': '/wiki/Baldwin_V,_Count_of_Hainaut', 'birthDate': datetime.datetime(1150, 1, 1, 0, 0), 'birthPlace': None}
# <tr><th class="infobox-label" scope="row">Born</th><td class="infobox-data" style="text-align: left;">1112</td></tr>
# {'id': '/wiki/Mahaut_of_Albon', 'birthDate': datetime.datetime(1112, 1, 1, 0, 0), 'birthPlace': None}

# %%
datetime.strptime('768', '%Y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-5f7343e4f56e> in <module>
# ----> 1 datetime.strptime('768', '%Y')
#
# c:\users\makoa\appdata\local\programs\python\python37\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     575     """Return a class cls instance based on the input string and the
#     576     format string."""
# --> 577     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     578     tzname, gmtoff = tt[-2:]
#     579     args = tt[:6] + (fraction,)
#
# c:\users\makoa\appdata\local\programs\python\python37\lib\_strptime.py in _strptime(data_string, format)
#     357     if not found:
#     358         raise ValueError("time data %r does not match format %r" %
# --> 359                          (data_string, format))
#     360     if len(data_string) != found.end():
#     361         raise ValueError("unconverted data remains: %s" %
#
# ValueError: time data '768' does not match format '%Y'
